# %% [markdown]
# # Image Classifier zur automatisierten Müllklassifizierung und Trennhilfe
#
# **Modul:** Selected Topics of AI <br>
# **Professor:** Prof. Dr. Johannes Maucher <br>
# **Bearbeitet von:** Lars Gerigk (lg107), Julia Ebert (je073), Joel Starkov (js486) <br>
# **Abgabe:** 28.01.2026 <br>

# %% [markdown]
# ## Inhaltsverzeichnis
#
# 1. Problemstellung & Zielsetzung<br>
#
#     1.1. Motivation & Problemanalyse <br>
#     1.2. Ziel <br>
#     1.3. Abgrenzung der Müllkategorien <br>
#
# 2. Installation & Setup <br>
#
#     2.1. Installation (otional) <br>
#     2.2. Imports<br>
#     2.3. Globale Konfigurationen & Utils<br>
#         2.3.1. Reproduzierbarkeit<br>
#         2.3.2. Device-Konfiguration <br>
#         2.3.3. Zentrale Hyperparameter Konfiguration <br>
#
# 10. Quellen
#
# <br>
#
# ---

# %% [markdown]
# ### 1. Problemstellung & Zielsetzung
# #### 1.1. Motivation & Problemanalyse <a id="motivation"></a>
#
# Die korrekte Trennung von Abfällen stellt für viele eine Herausforderung dar. Eine Umfrage von ALBA und Civey aus dem Jahr 2022 zeigt, dass nur 3,8% der Befragten Teilnehmer aus einer Stichprobengröße von 2.502 Menschen ihren Müll nicht trennen. Besonders hervorsticht, dass über 90% der Befragten, darauf achten Papier und Pappe vom Restmüll zu trennen. 87,3 % der Befragten trennen ihre Plastik(-verpackungen) vom Restmüll und 83,8 % trennen ihr Altglas vom Restmüll. Mit 64,4 % Müll trennen die Befragten am wenigsten von Biomüll und Restmüll. Diese Ergebnisse hören sich zunächst vielversprechend an. Allerdings täsuchen diese Ergebnisse, so der ALBA-Chef Eric Schweitzer. Eine Studie des Umweltbundesamtes zeigt auf, dass zwei Drittel des Inhalts der Restmülltonne, getrennt gesammelt und recycelt werden könnte. Zudem sagt Schweitzer aus, dass "Fehlerwürfe" von bis zu 30 Prozent keine Seltenheit ist. Somit werden Ressourcen folglich verbrannt, die die Gesamtkosten für Energie und die Produktion neuer Rohstoffe steigen für die Gesellschaft [1].
#
# Fehlwürfe in der Mülltrennung lassen sich unter anderem auf ein fehlendes grundlegendes Verständnis des Abfalltrennungssystems sowie auf eine unzureichende und nicht einheitliche Aufklärung zurückführen. Die bestehenden Trennregeln sind teilweise komplex und unterscheiden sich je nach Region, was die korrekte Zuordnung einzelner Abfallarten erschwert. Durch die entstandenen Unsicherheiten führen in der Praxis zu erhöhten Fehlwürfen und beeinträchtigen die Effizienz von Recyclingprozessen [2].
#
# Im Folgenden wird ein Anwendungsbeispiel für den Einsatz eines bildbasierten Klassifikationssystems an der Hochschule der Medien (kurz: HdM) vorgestellt. Ziel ist es, die Mülltrennung und damit die Recyclingqualität auf dem Campus zu verbessern. Zu diesem Zweck wird ein Image Classifier entwickelt, der anhand eines aufgenommenen Bildes eines Abfallobjekts dessen Kategorie erkennt und den Nutzer bei der korrekten Entsorgung unterstützt.
#
# Ein möglicher Ausblick besteht darin, Abfallbehälter mit einer integrierten Kamera sowie einem visuellen und auditiven Rückmeldesystem auszustatten. Nach der automatischen Klassifikation gibt das System an der jeweiligen Einwurföffnung ein Signal aus, das anzeigt, in welchen Behälter der Abfall entsorgt werden soll. Durch die Kombination aus visueller und auditiver Rückmeldung kann die Bedienung vereinfacht und gleichzeitig sprachliche sowie visuelle Barrieren reduziert werden. Auf diese Weise könnte das System dazu beitragen, Fehlwürfe zu verringern und die Mülltrennung im Hochschulalltag nachhaltig zu verbessern.

# %% [markdown]
# ### 1.2. Ziel
#
# Ziel dieses Projekts ist die Entwicklung eines Image Classifiers zur automatisierten Erkennung und Zuordnung von Abfallobjekten. Hierfür werden parallel zu den in der Vorlesung behandelten Konzepten und Modellen geeignete Architekturen ausgewählt, implementiert und an die Anforderungen des vorliegenden Anwendungsfalls angepasst. Die entwickelten Modelle werden trainiert, validiert und hinsichtlich ihrer Leistungsfähigkeit systematisch untersucht.
#
# Zur Bewertung der Modellgüte werden etablierte Metriken wie Accuracy, Precision, Recall und F1 Score herangezogen. Die Ergebnisse der einzelnen Modellvarianten werden anschließend miteinander verglichen, um den Einfluss unterschiedlicher Architekturen, Trainingsstrategien und Hyperparameter auf die Klassifikationsleistung zu analysieren. Auf diese Weise soll ein Modell identifiziert werden, das für die automatisierte Müllklassifikation eine hohe Erkennungsleistung sowie eine robuste Generalisierungsfähigkeit aufweist.
#
# Ziel der Vorgehensweise ist es, durch strukturierte Umsetzung, fundierte Evaluation und gezielte Anpassung der Modellarchitektur ein Klassifikationsmodell zu entwickeln, das einen Beitrag zur Reduktion von Fehlwürfen in der Mülltrennung leisten kann.

# %% [markdown]
# ### 1.3. Abgrenzung der Müllkategorien
#
# <b>Hinweis:</b> Wir wollen uns bewusst auf den typischen Müll beschränken, der im Alltag an der Hochschule der Medien anfällt. Daher beziehen wir bei der Klassifikation an der HdM vorhandenen Entsorgungsmöglichkeiten.
#
# <b>Unser Modell klassifiziert erkannte Objekte in eine der folgenden fünf Kategorien:</b>
#
# <table style="width:100%; border-collapse: collapse; margin-right:20px;">
#   <tr>
#     <th>Kategorie</th>
#     <th>Beschreibung</th>
#   </tr>
#
#   <tr>
#     <td>Pfand</td>
#     <td>
#       Diese Kategorie umfasst pfandpflichtige Getränkeverpackungen. Dazu zählen insbesondere:
#       <ul>
#         <li>Einweg Plastikflaschen</li>
#         <li>Sowohl mit als auch ohne sichtbare Pfandkennzeichnung</li>
#         <li>Auf Grund begrenzter Verfügbarkeit geeigneter Trainingsdaten werden zusätzlich Bilder aus Ländern ohne Pfandsystem verwendet</li>
#         <li>Getränkedosen</li>
#       </ul>
#       Glasflaschen werden bewusst nicht dieser Kategorie zugeordnet, obwohl sie ebenfalls pfandpflichtig sein können.
#       Der Grund hierfür liegt darin, dass Glasflaschen an der Hochschule der Medien nicht über den klassischen Pfandbehälter entsorgt werden.
#     </td>
#   </tr>
#
#   <tr>
#     <td>Restmüll</td>
#     <td>
#       In diese Kategorie fallen Abfälle, die weder recycelbar sind noch einer anderen Kategorie eindeutig zugeordnet werden können. Beispiele sind:
#       <ul>
#         <li>Stark verschmutzte oder beschichtete Materialien</li>
#         <li>Essensreste</li>
#         <li>Nicht trennbare Verbundmaterialien</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Papier</td>
#     <td>
#       Diese Kategorie umfasst saubere und trockene Papierprodukte, die für das Recycling geeignet sind. Dazu gehören:
#       <ul>
#         <li>Papierblätter und Hefte</li>
#         <li>Kartonverpackungen ohne starke Verschmutzung</li>
#         <li>Papiertüten</li>
#       </ul>
#       Nicht enthalten sind beschichtete oder stark verschmutzte Papiermaterialien, da diese nicht dem Papierrecycling zugeführt werden können.
#     </td>
#   </tr>
#
#   <tr>
#     <td>Verpackungen</td>
#     <td>
#       Diese Kategorie beinhaltet recycelbare Verpackungsmaterialien, zum Beispiel:
#       <ul>
#         <li>Kunststoffverpackungen von Lebensmitteln</li>
#         <li>Joghurtbecher, Folien und Plastikschalen</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Sonstiges</td>
#     <td>
#       Für diese Kategorie sind alle Objekte vorgesehen, die nicht zu den oben genannten Müllarten gehören oder an der Hochschule der Medien nicht im regulären Müll entsorgt werden dürfen.
#       <ul>
#         <li>Batterien und Elektroschrott</li>
#         <li>Glasflaschen</li>
#         <li>Gegenstände, die kein Müll sind, zum Beispiel Taschen, Bücher oder Technik</li>
#       </ul>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### 2. Installation & Setup

# %% [markdown]
# #### 2.1. Installation (optional)
#
# Bevor der eigentliche Code ausgeführt wird, müssen alle notwendigen Dependecies installiert werden, die für das Laden der Daten, deren Analyse sowie das Training und die Auswertung der Modelle erforderlich sind. Sofern die genannten Pakete noch nicht installiert sind, können sie direkt innerhalb dieses Notebooks installiert werden. Für eine lokale Ausführung wird empfohlen, die Abhängigkeiten über eine Conda-Umgebung zu verwalten.

# %%
# %pip install numpy
# %pip install scipy
# %pip install matplotlib
# %pip install pandas
# %pip install scikit-learn
# %pip install torch
# %pip install torchvision
# %pip install wandb
# %pip install torchsummary
# %pip install seaborn
# Out:
# Requirement already satisfied: numpy in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scipy) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (2.9.1)
# Requirement already satisfied: filelock in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchvision in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (0.24.1)
# Requirement already satisfied: numpy in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: torch==2.9.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torchvision) (2.9.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: filelock in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from sympy>=1.13.3->torch==2.9.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from jinja2->torch==2.9.1->torchvision) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wandb in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (0.23.1)
# Requirement already satisfied: click>=8.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (3.1.46)
# Requirement already satisfied: packaging in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (6.33.4)
# Requirement already satisfied: pydantic<3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (2.12.5)
# Requirement already satisfied: pyyaml in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (2.49.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2025.11.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchsummary in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 2.2. Imports
#
# In diesem Abschnitt werden alle grundlegenden Abhängigkeiten für die nachfolgenden Abschnitte zentral definiert und importiert.

# %%
import numpy as np
import scipy.io as io
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader, ConcatDataset


from torchvision import datasets, models, transforms
from torchsummary import summary

import wandb 
import itertools

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# #### 2.3. Globale Konfiguration & Utils
#
# In diesem Abschnitt werden zentrale Konfigurationsparameter sowie wiederverwendbare Hilfsfunktionen definiert, welche in den nachfolgenden Kapiteln verwendet werden.
#
# ##### 2.3.1 Reproduzierbarkeit
#
# Um verschiedene Ergebnisse zwischen unterschiedlichen Durchläufen zu verhindern und eine faire Vergleichbarkeit der untersuchten Modelle zu gewährleisten, werden alle relevanten Zufallsgeneratoren explizit bestimmt.

# %%
def set_seed(seed=23):
    np.random.seed(seed)
    torch.manual_seed(seed) 
    torch.cuda.manual_seed_all(seed)
    
    print(f"Random seed set to: {seed}")
    return torch.Generator().manual_seed(seed)

# %%
set_seed(23)
# Out:
# Random seed set to: 23

# %% [markdown]
# ##### 2.3.2. Device-Konfiguration
#
# Die ermittelte Rechenumgebung wird zentral gespeichert und in allen Trainings- und Evaltuationsschritten verwendet.

# %%
def get_device():
    if torch.cuda.is_available():
        device = "cuda"
    elif torch.backends.mps.is_available():
        device = "mps"
    else:
        device = "cpu"
        
    print(f"Using device: {device}")
    return device

# %% [markdown]
# ##### 2.3.3. Zentrale Hyperparameter Konfiguration

# %% [markdown]
# Zur systematischen Protokollierung von allen Experimenten, Hyperparametern und Ergebnissen wird in diesem Projekt das Tool Weights & Biases (kurz: wandb) eingesetzt.
# <br>
# Für eine flexible Nutzung wird zwischen Online- und Offline Mode unterschieden um die Nutzung des Notebooks auch ohne Internetzugang zu ermöglichen.

# %%
USE_WANDB = True

WANDB_PROJECT = "Müll Klassifikation"

if USE_WANDB:
    wandb.login()
    print("Logged in to Weights & Biases")
else:
    print("Weights & Biases logging is disabled")
# Out:
# Logged in to Weights & Biases

# %% [markdown]
# ##### 2.3.4. Allgemeine Konfigurationen

# %%
image_size = 32
num_workers = 2
channel = 3
extern_file_path = "./extern-data"
custom_file_path = "./custom-data"
all_file_path = "./all-data"

train_ratio = 0.7
val_ratio = 0.15
seed = 23
generator = set_seed(seed)
device = get_device()
# Out:
# Random seed set to: 23
# Using device: cuda

# %% [markdown]
# ##### 2.3.5. Konfigurationen der Modelarchitekturen

# %% [markdown]
# Konfiguration für das **MLP**:

# %%
config_mlp = dict(
    model_type = 'MLP',
    batch_size = 16,
    learning_rate = 0.1,
    epochs = 15,
    hidden_dim = 512,
    dropout = 0.2
)

# %% [markdown]
# Konfiguration für das **CNN**:

# %%
config_cnn = dict(
    model_type = 'CNN',
    batch_size = 16,
    learning_rate = 0.01,
    epochs = 30,
    hidden_dim_1 = 1024, 
    dropout = 0.2
)

# %% [markdown]
# Konfiguration für das **Transfer Learning**:

# %%
config_transfer_vgg = {
    "scratch": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_FROM_SCRATCH',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "pretrained": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_PRETRAINED',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "finetune": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_FINETUNE',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 15, 
        hidden_dim = 128,
        dropout = 0.2,
    )
}

# %%
config_transfer_rn = {
    "scratch": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_FROM_SCRATCH',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "pretrained": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_PRETRAINED',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "finetune": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_FINETUNE',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 15, 
        hidden_dim = 128,
        dropout = 0.2,
    )
}

# %% [markdown]
# ### 3. Datenerfassung & Aufbereitung
#
# In diesem Kapitel wird beschrieben, wie die für das Projekt verwendeten Bilddaten erhoben, organisiert und für die weitere Verarbeitung vorbereitet wurden.
#
# #### 3.1. Herkunft der Datensätze
#
# Um ein robustes und verallgemeinerungsfähiges Modell zu trainieren, ist eine ausreichend große und qualitativ hochwertige Datenbasis erforderlich. Für die Beschaffung öffentlich zugänglicher Trainingsdaten wurde die Online Plattform Kaggle genutzt, welche eine Vielzahl kuratierter Datensätze bereitstellt.
#
# #### 3.1.1. Externer Datensatz
#
# Zu Beginn haben wir uns dafür entschieden mit dem Datenset **"Garbage Classification"** von Mostafa Mohamed der Plattform Kaggle zu arbeiten. Jedoch zeigte sich schnell, dass die Klassenverteilung sehr unsausgeglichen war. Einige Kategorien waren so deutlich überpräsentiert, während andere nur sehr wenige Bilder enthielten, so dass unsere Modelle kaum bis garkeine Verbesserung der Accuracy in allen Durchläufen zeigten.
# <br>
# Um dieser Problematik entgegenzuwirken und eine bessere Grundlage für das Modelltraining zu schaffen, haben wir zusätzlich weitere Datensätze hinzugezogen.
#
# #### Die verwendeten Datensätze im Überblick:
#
# <table style="width:100%; border-collapse: collapse; margin-right:20px;">
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Quelle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Restmüll, Papier</td>
#       <td>
#         M. Abla, <i>Garbage Classification (12 classes)</i>, Kaggle dataset, 2020.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/mostafaabla/garbage-classification.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Pfandflaschen</td>
#       <td>
#         S. Kumar Sah, <i>Plastic Bottles Image Dataset</i>, Kaggle dataset, 2021.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/siddharthkumarsah/plastic-bottles-image-dataset.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Kaffeebecher</td>
#       <td>
#         V. Lanz, <i>Plastic and Paper Cups Synthetic Image Dataset</i>, Kaggle dataset, 2021.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/vencerlanz09/plastic-and-paper-cups-synthetic-image-dataset.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Plastik</td>
#       <td>
#         H. Kandoi, <i>Dataset for Visual Plastic Type Recognition</i>, Kaggle dataset, 2024.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/harshitkandoi7850/dataset-for-visual-plastic-type-recognition.<br>
#         Zugriff: 20.12.2025.<br><br>
#         N. Bagga, <i>Plastic Images</i>, Kaggle dataset, 2023.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/nandinibagga/plastic-images.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Dosen</td>
#       <td>
#         T. Yasser, <i>Drinks Cans</i>, Kaggle dataset, 2023.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/tarekyasser63/drinks-cans.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# #### 3.1.2. Eigener Datensatz
#
# Ergänzend zu dem externen Datensatz wurde ein eigener Bilddatensatz erstellt, um die Trainingsdaten gezielt zu erweitern und an die spezifische Aufgabenstellung anzupassen. Hierfür wurden pro Kategorie etwa 200 eigene Bilder aufgenommen und in ein eigenes Datenset integriert.
#
# Die aufgenommenen Bilder wurden bewusst nicht unter idealisierten Bedingungen erstellt. Stattdessen wurde darauf geachtet, verschiedene Lichtverhältnisse, unterschiedliche Hintergrundstrukturen sowie teilweise Hände oder andere Objekte im Bild zuzulassen. Ziel dieser Vorgehensweise war es, ein möglichst realitätsnahes und vielfältiges Datenset zu erzeugen.
#
# Durch diese gezielte Variation lernt das Modell nicht nur idealisierte Beispielbilder, sondern wird bereits während des Trainings mit komplexeren und störbehafteten Szenen konfrontiert. Dies fördert die Robustheit des Modells gegenüber realen Einsatzbedingungen und verbessert seine Fähigkeit zur Generalisierung auf bisher unbekannte Bilder.
#
# #### 3.2. Zusammenführung und manuelle Strukturierung
#
# Ein besonderer Aufwand entstand bei der Verarbeitung plastikbezogener Daten. Da die meisten öffentlichen Datensätze dazu nicht aus Deutschland stammen und das Konzept von Pfandflaschen dort nicht existiert. <br> Daher mussten wir diese Bilder manuell durchsuchen und Plastikflaschen in eine eigene Kategorie Pfand einordnen, um alles optimal an unser Anwendungsszenario der HDM anzupassen.
# <br>
# Auch bei den den restlichen Datensätzen war eine manuelle Überprüfung notwendig, da viele Bilder für unser Szenario ungeignet waren, da sie nicht dem praktischen Anwendungsfall "Müll wird vor eine Kamera gehalten" entsprachen. Beispielsweise gab es Aufnahmen von Landstraßen, an deren Rändern Plastik in Gräben liegt oder Bilder von verstreutem Müll in Sträuchern und am Meer. Solche Bilder wurden konsequent aussortiert.
# <br><br>
# Nach dem Download der Datensätze wurden die Bilddaten manuell zusammengeführt und in eine einheitliche Ordnerstruktur überführt. Dabei wurde darauf geachtet, dass jede Klasse eine ähnliche Anzahl an Bildern enthält. Ziel war es, pro Kategorie etwa 2000 Bilder zu verwenden um eine gleichmäßige Klassenverteilung zu erreichen und damit optimale Voraussetzungen für das Training der Modelle zu schaffen.
#
# #### 3.3. Datensetanalyse
#
# !!!!
#
# #### 3.4. Ausgangsstruktur der Daten
#
# Wenn die Datensätze bereits vorab manuell in separate Trainings- und Validierungsordner aufgeteilt werden, entsteht ein höherer organisatorischer Aufwand und ein erhöhtes Risiko für inkonsistente Datenstrukturen. Stattdessen wurden in diesem Projekt alle Bilder in einer einheitlichen Verzeichnisstruktur abgelegt, bei der jede Klasse als eigenes Unterverzeichnis vorliegt. Die eigentliche Aufteilung in Trainings und Validierungsdaten erfolgt in diesem Jupyter Notebook.
#
# Zweitens ermöglicht die programmatische Aufteilung eine flexible Anpassung der Splitverhältnisse, ohne dass Dateien manuell verschoben oder dupliziert werden müssen. Drittens wird die Reproduzierbarkeit verbessert, da die Datenteilung durch einen festen Zufallsseed exakt wiederholbar durchgeführt werden kann.
#
# Im folgenden ist die Datenstruktur zu erkennen:
#
# Externer Bilddatensatz (Kaggle)
#
# ```
# extern-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```
#
#
# Eigener Bilddatensatz (selbst erhoben)
#
# ```
# custom-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```
#
# Alles Bilddatensätze (Kaggle + selbst erhoben)
#
# ```
# all-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```

# %% [markdown]
# ### 3.4. Datenaufbereitung
# #### 3.4.1. Import der Bilder

# %%
def load_data(file_path):
    full_dataset = datasets.ImageFolder(
        root=file_path
    )
    return full_dataset

# %% [markdown]
# #### 3.4.2. Bildverarbeitung
#
# In dieser Methode werden seperate Pipelines für Training und Validierung festgelegt. Dabei werden alle Bilder auf eine feste Größe skaliert und anschließend quadratisch aus der Mitte zugeschnitten und in ein für das Modell lesbares Tensor-Format umgewandelt.

# %%
def build_transforms(image_size):
    data_transforms = {
        'train': transforms.Compose([
            transforms.Resize(image_size),
            transforms.CenterCrop(image_size),
            transforms.RandomRotation(degrees=(0, 360)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ToTensor(),
        ]),
        'val': transforms.Compose([
            transforms.Resize(image_size),
            transforms.CenterCrop(image_size),
            transforms.ToTensor(),
        ])
    }
    return data_transforms

# %% [markdown]
# Mithilfe dieser Funktion wird eine zufällige Aufteilung der Indizes eines Datensatzes in die Gruppen "Training" und "Validierung" eingeteilt.

# %%
def split_indices(dataset, train_ratio, val_ratio):
    total_size = len(dataset)
    
    train_size = int(train_ratio * total_size)
    val_size = total_size - train_size
    
    train_indices, val_indices = random_split(
        range(total_size),
        [train_size, val_size],
        generator=generator
    )
    
    return train_indices, val_indices

# %% [markdown]
# Basiernd auf den Indizes der Methode davor werden hier die Datasets und Subsets der Trainings- und Validierungsdaten erstellt.

# %%
def build_dataset(file_path, data_transforms, train_indices, val_indices):
    train_dataset_base = datasets.ImageFolder(
        root=file_path,
        transform=data_transforms['train']
    )

    val_dataset_base = datasets.ImageFolder(
        root=file_path,
        transform=data_transforms['val']
    )

    train_dataset = torch.utils.data.Subset(
        train_dataset_base,
        train_indices
    )

    val_dataset = torch.utils.data.Subset(
        val_dataset_base,
        val_indices
    )

    return train_dataset, val_dataset

# %% [markdown]
# Anhand der Datasets werden hier die Dataloader erstellt. Dabei wird nicht nur das Datenset, sondern auch die Batchgröße und die Anzahl der Worker-Prozesse als Parameter übergeben.
#
# Dabei ist es besonders darauf zu achten, dass die Trainingsdaten in jeder Epoche neu gemischt werden (shuffle = True). Das verhindert, dass das Modell die Reihenfolge der Bilder auswendig lernt.
#
# Während der Validierung ist die Reihenfolge egal, daher kann auf das Mischen verzichtet werden.

# %%
def build_dataloaders(train_dataset, val_dataset, batch_size, num_workers):
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    return train_loader, val_loader

# %% [markdown]
# Diese Funktion ermittelt die Klassenverteilung des Datensatzes. Zuerst werden die Kategorienamen extrahiert. Danach iteriert die Funktion über alle Labels, ordnet diese ihren Klarnamen zu und zählt deren Häufigkeit in einem Dictionary.

# %%
def count_classes(dataset):
    img_classes = {}
    class_names = dataset.classes

    for _, label in dataset:
        class_name = class_names[int(label)]

        if class_name not in img_classes:
            img_classes[class_name] = 0

        img_classes[class_name] += 1

    return img_classes

# %% [markdown]
# Diese Methode ist die zentrale Steuerungseinheit für die gesamte Datenvorbereitung.
#
# Sie lädt zuerst die Datensätze anhand des mitgegebenen Filepaths und ermittelt bereits zu Beginn die Anzahl der Bilder, die Anzahl der Klassen, die Namen der Klassen und die Klassenverteilung. Diese werden zu Beginn ausgegeben, sodass man frühzeitig die Daten kontrollieren und Ungleichgewichte erkennen kann.
#
# Anschließend werden die oben bereits beschriebenen Funktionen aufgerufen um die Daten zu transformieren und zu splitten. Danach werden die Datasets und Dataloaders erstellt.
#
# Zuletzt wird als Sicherheitscheck die Batchgröße, Bildform und Beispiellabels ausgegeben, um so überprüfen zu können, ob die Funktionen erfolgreich aufgerufen wurden.
#
# Zudem wird hier bereits der erste Bilddatensatz geladen (extern-data)

# %%
def prepare_data(file_path):
    full_dataset = load_data(file_path)
    class_count = len(full_dataset.classes)
    image_count = len(full_dataset)
    image_classes = count_classes(full_dataset)

    print("\n=== Datensatzübersicht ===")
    print(f"Anzahl Bilder gesamt: {image_count}")
    print(f"Anzahl Klassen: {class_count}")
    print(f"Klassen: {full_dataset.classes}")

    print("\nKlassenverteilung (gesamt):")
    for cls, cnt in image_classes.items():
        print(f"  {cls:<20}: {cnt}")

    data_transforms = build_transforms(image_size)

    train_indices, val_indices = split_indices(
        full_dataset,
        train_ratio,
        val_ratio
    )

    train_dataset, val_dataset = build_dataset(
        file_path,
        data_transforms,
        train_indices,
        val_indices,
    )

    train_loader, val_loader = build_dataloaders(
        train_dataset,
        val_dataset,
        config_mlp['batch_size'],
        num_workers
    )

    return full_dataset, train_loader, val_loader, class_count, image_classes

extern_full_dataset, extern_train_loader, extern_val_loader, extern_class_count, extern_image_classes = prepare_data(extern_file_path)

images, labels = next(iter(extern_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {images.shape[0]}")
print(f"Bildform          : {tuple(images.shape[1:])}")
print(f"Label-Beispiel    : {labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 10391
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 2145
#   paper               : 1941
#   residual waste      : 2291
#   returnable bottle   : 2013
#   unauthorized waste  : 2001
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [4, 0, 0, 3, 2, 2, 3, 2, 2, 3, 2, 2, 0, 0, 4, 2]

# %% [markdown]
# Laden des zweiten Bilddatensatzes (custom-data)

# %%
custom_full_dataset, custom_train_loader, custom_val_loader, custom_class_count, custom_image_classes = prepare_data(custom_file_path)

custom_images, custom_labels = next(iter(custom_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {custom_images.shape[0]}")
print(f"Bildform          : {tuple(custom_images.shape[1:])}")
print(f"Label-Beispiel    : {custom_labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 1196
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 237
#   paper               : 247
#   residual waste      : 222
#   returnable bottle   : 244
#   unauthorized waste  : 246
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [3, 1, 0, 2, 0, 2, 0, 0, 3, 2, 4, 1, 2, 1, 0, 2]

# %% [markdown]
# Laden des dritten Bilddatensatzes (all-data)

# %%
all_full_dataset, all_train_loader, all_val_loader, all_class_count, all_image_classes = prepare_data(all_file_path)

all_images, all_labels = next(iter(all_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {all_images.shape[0]}")
print(f"Bildform          : {tuple(all_images.shape[1:])}")
print(f"Label-Beispiel    : {all_labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 11587
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 2382
#   paper               : 2188
#   residual waste      : 2513
#   returnable bottle   : 2257
#   unauthorized waste  : 2247
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [3, 0, 0, 3, 4, 0, 2, 2, 4, 3, 1, 3, 2, 0, 1, 1]

# %% [markdown]
# Ähnlich zu der Funktion oben zählt diese Funktion wie viele Bilder jeder Klasse in einem bestimmten Subset eines Datensatzes enthalten sind. Dabei wird ebenfalls ein Wörterbuch mit allen Klassennamen und dem Startwert 0 erstellt.
#
# Anschließend werden alle Indizes in dem Subset durchgegangen. Für jedes Bild wird das zugehörige Label angeschaut und der Zähler der passenden Klasse wird um 1 erhöht.

# %%
def count_classes_subset(subset, class_names):
    counts = {name: 0 for name in class_names}
    for idx in subset.indices:
        _, label = subset.dataset.samples[idx]
        counts[class_names[label]] += 1
    return counts

# %% [markdown]
# Diese Funktion visualisiert eine Klassenverteilung als Balkendiagramm.
#
# Sie erstellt zuerst eine neue Grafik und zeichnet danach für jede Klasse einen Balken, dessen Höhe der Anzahl der Bilder entspricht. Titel sowie Beschriftungen für x- und y-Achse werden ebenfalls gesetzt. Zuletzt wird das Diagramm angezeigt.

# %%
def print_class_distribution(img_classes, title, xlabel, ylabel):
    plt.figure(figsize=(10,5))
    plt.bar(img_classes.keys(), img_classes.values())
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %% [markdown]
# Zählen und Visualisieren der Extern-Subsets.

# %%
# --- Train ---
train_dist = count_classes_subset(extern_train_loader.dataset, extern_full_dataset.classes)
print_class_distribution(
    train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
val_dist = count_classes_subset(extern_val_loader.dataset, extern_full_dataset.classes)
print_class_distribution(
    val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %% [markdown]
# Zählen und Visualisieren der Custom-Subsets.

# %%
# --- Train ---
custom_train_dist = count_classes_subset(custom_train_loader.dataset, custom_full_dataset.classes)
print_class_distribution(
    custom_train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
custom_val_dist = count_classes_subset(custom_val_loader.dataset, custom_full_dataset.classes)
print_class_distribution(
    custom_val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %% [markdown]
# Zählen und Visualisieren der All-Subsets.

# %%
# --- Train ---
all_train_dist = count_classes_subset(all_train_loader.dataset, all_full_dataset.classes)
print_class_distribution(
    all_train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
all_val_dist = count_classes_subset(all_val_loader.dataset, all_full_dataset.classes)
print_class_distribution(
    all_val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %% [markdown]
# Hier werden zufällige Bilder aus einem Datenset inklusive ihrer Klassennamen visualisiert.

# %%
def show_random_samples(dataset): 
    figure = plt.figure(figsize=(10, 10))
    cols, rows = 6, 1
    class_names = extern_full_dataset.classes  

    for i in range(1, rows * cols + 1):
        sample_idx = torch.randint(len(dataset), size=(1,)).item()
        img, label = dataset[sample_idx]

        img = img.permute(1, 2, 0)
        class_name = class_names[int(label)]

        figure.add_subplot(rows, cols, i)
        plt.axis("off")
        plt.title(class_name)
        plt.imshow(img)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Anzeige zufälliger Bilder des Extern-Datasets

# %%
# --- Train ---
show_random_samples(extern_train_loader.dataset)

# --- Validation ---
show_random_samples(extern_val_loader.dataset)

# %% [markdown]
# Anzeige zufälliger Bilder des Custom-Datasets

# %%
show_random_samples(custom_train_loader.dataset)
show_random_samples(custom_val_loader.dataset)

# %% [markdown]
# Anzeige zufälliger Bilder des All-Datasets

# %%
show_random_samples(all_train_loader.dataset)
show_random_samples(all_val_loader.dataset)

# %% [markdown]
# ## Architekturen definieren
#
# 1. MLP
# 3. CNN - Eigenen Feature Extractor und Classifier
# 4. Komplexes CNN
# 2. Transfer Learning <br>
#     2.1. From scratch <br>
#     2.2. Pretrained<br>
#     2.3. Fine Tune <br>

# %% [markdown]
# ### Multi Layer Perceptron

# %% [markdown]
# Die Klasse `MLP` implementiert ein **Multilayer Perceptron (MLP)** zur Klassifikation von Bilddaten.
# Das Modell besteht aus einer vollständig verbundenen Hidden-Schicht mit Dropout-Regularisierung
# sowie einer Ausgabeschicht zur Vorhersage der Klassenwahrscheinlichkeiten.
#
# Die Implementierung basiert auf **PyTorch** und erbt von `torch.nn.Module`.
#
# ---
#
# ##### Zweck
#
# Das MLP dient als **einfaches neuronales Basismodell**, um Bilddaten nach vorheriger
# Serialisierung (Flattening) zu klassifizieren.
# Es eignet sich insbesondere:
# - als Vergleichsmodell zu komplexeren Architekturen (z. B. CNNs),
# - für Experimente mit Fully-Connected-Netzen,
# - für kleinere Datensätze oder als Lernbeispiel.
#
# ---

# %%
class MLP(nn.Module):
    def __init__(self, config):
        super(MLP, self).__init__()
        self.d1 = nn.Linear(channel * image_size * image_size, config.hidden_dim)
        self.dropout = nn.Dropout(p=config.dropout)
        self.d2 = nn.Linear(config.hidden_dim, extern_class_count)
    
    def forward(self, x):
        x = x.flatten(start_dim = 1) #serialize 3dim input

        x = self.d1(x)
        x = torch.relu(x)
        x = self.dropout(x)

        raw_scores = self.d2(x)
        output_predictions = torch.softmax(raw_scores , dim=1)   

        return output_predictions

# %% [markdown]
# ### CNN

# %% [markdown]
# Die Klasse `CNN` implementiert ein **Convolutional Neural Network (CNN)** zur Bildklassifikation.
# Das Modell nutzt mehrere Faltungs- und Pooling-Schichten zur Extraktion räumlicher Merkmale
# sowie vollständig verbundene Schichten zur Klassifikation.
#
# Die Implementierung basiert auf **PyTorch** und erbt von `torch.nn.Module`.
#
# ---
#
# #### Zweck
#
# Das CNN ist für die **automatische Merkmalsextraktion aus Bilddaten** konzipiert.
# Im Gegensatz zu einem MLP nutzt es die räumliche Struktur der Bilder und eignet sich daher
# besonders gut für visuelle Klassifikationsaufgaben.
#
# Typische Einsatzbereiche:
# - Bildklassifikation
# - Vergleich mit einfacheren Baseline-Modellen (z. B. MLP)
# - Experimente mit Regularisierung (Dropout, Batch Normalization)
#
# ---

# %%
class CNN(nn.Module):
    def __init__(self, config):
        super(CNN, self).__init__()
        self.drop=nn.Dropout2d(config.dropout)
        self.dropfc=nn.Dropout(config.dropout)
        self.conv1 = nn.Conv2d(channel, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(512*2*2, config.hidden_dim_1)
        self.fc2 = nn.Linear(config.hidden_dim_1, extern_class_count)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.drop(self.conv1(x)))))
        x = self.pool(F.relu(self.bn2(self.drop(self.conv2(x)))))
        x = self.pool(F.relu(self.bn3(self.drop(self.conv3(x)))))
        x = self.pool(F.relu(self.bn4(self.drop(self.conv4(x)))))
        x = x.view(-1, 512*2*2)
        x = F.relu(self.dropfc(self.fc1(x)))
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Transfer Learning
#
# ### VGG16 Model

# %% [markdown]
# Die Klasse `VGG16` implementiert ein **auf VGG16 basierendes Convolutional Neural Network**
# für die Bildklassifikation. Je nach Konfiguration kann das Modell
# - **von Grund auf neu trainiert**,
# - **als eingefrorenes, vortrainiertes Modell genutzt**
# - oder **feinjustiert (Fine-Tuning)** werden.
#
# Die Implementierung nutzt das vortrainierte **VGG16-Modell aus `torchvision.models`**
# und passt die Architektur an die Zielklassen des Datensatzes an.
#
# ---
#
# #### Zweck
#
# Dieses Modell dient zur **leistungsstarken Bildklassifikation** unter Nutzung von
# **Transfer Learning**. Durch die Wiederverwendung vortrainierter Gewichte
# (konzipiert für ImageNet) kann auch bei kleineren Datensätzen eine hohe
# Generalisierungsleistung erreicht werden.
#
# Typische Einsatzszenarien:
# - Transfer Learning
# - Fine-Tuning vortrainierter CNNs
# - Vergleich mit selbst implementierten CNN-Architekturen
#
# ---

# %%
class VGG16(nn.Module):
    def __init__(self, config):
        super(VGG16, self).__init__()
        self.config = config
        
        if config.model_subtype == "TRAIN_FROM_SCRATCH":
            self.model = models.vgg16(pretrained=False)
            for param in self.model.parameters():
                param.requires_grad = True
        elif config.model_subtype == "TRAIN_PRETRAINED":
            self.model = models.vgg16(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = False
        elif config.model_subtype == "TRAIN_FINETUNE":
            self.model = models.vgg16(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = True
        else:
            raise ValueError(f"Unknown model_subtype {config.model_subtype}")
        
        self.model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

        self.model.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, config.hidden_dim),
            nn.ReLU(),
            nn.Dropout(config.dropout),
            nn.Linear(config.hidden_dim, extern_class_count)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### ResNet50
#
# Die Klasse `ResNet50` implementiert ein **auf ResNet50 basierendes Deep Convolutional Neural Network**
# zur Bildklassifikation. Ähnlich zur `VGG16`-Klasse nutzt dieses Modell **Transfer Learning**
# und erlaubt verschiedene Trainingsstrategien, unterscheidet sich jedoch grundlegend in seiner
# Architektur durch die Verwendung von **Residual Connections**.
#
# Die Implementierung basiert auf dem vortrainierten **ResNet50-Modell aus `torchvision.models`**.
#
# ---
#
# #### Zweck
#
# Das ResNet50-Modell wird eingesetzt, um:
# - die Leistungsfähigkeit moderner, tiefer CNN-Architekturen zu evaluieren,
# - **VGG16 und ResNet50 direkt miteinander zu vergleichen**,
# - die Auswirkungen von Architekturentscheidungen (Tiefe, Residual Connections)
#   auf Trainingsstabilität und Generalisierung zu analysieren.
#
# Insbesondere steht hier der **Vergleich zwischen klassischen CNNs (VGG16) und Residual Networks**
# im Fokus der Untersuchung.
#
# ---

# %%
class ResNet50(nn.Module):
    def __init__(self, config):
        super(ResNet50, self).__init__()
        self.config = config
        
        if config.model_subtype == "TRAIN_FROM_SCRATCH":
            self.model = models.resnet50(pretrained=False) 
            for param in self.model.parameters():
                param.requires_grad = True

        elif config.model_subtype == "TRAIN_PRETRAINED":
            self.model = models.resnet50(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = False

        elif config.model_subtype == "TRAIN_FINETUNE":
            self.model = models.resnet50(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = True
        else:
            raise ValueError(f"Unknown model_subtype {config.model_subtype}")

        num_ftrs = self.model.fc.in_features 

        self.model.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(num_ftrs, config.hidden_dim), 
            nn.ReLU(),
            nn.Dropout(config.dropout),
            nn.Linear(config.hidden_dim, extern_class_count)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Funktion `get_model`
#
# Die Funktion `get_model` ist eine **zentrale Factory-Funktion** zur Initialisierung
# von Modellen, Optimierern und Verlustfunktionen.
# Sie kapselt die gesamte Modellkonfiguration und stellt sicher, dass
# alle Experimente konsistent und vergleichbar durchgeführt werden.
#
# ---
#
# #### Zweck
#
# Diese Funktion dient dazu:
# - unterschiedliche Modellarchitekturen **einheitlich zu initialisieren**,
# - passende Optimierer abhängig vom Modelltyp zu wählen,
# - eine gemeinsame Verlustfunktion zu definieren,
# - die Modelle automatisch auf das Zielgerät (CPU/GPU) zu verschieben,
# - eine übersichtliche Modellzusammenfassung auszugeben.
#
# Dadurch wird ein **fairer Vergleich zwischen MLP, CNN, VGG16 und ResNet50**
# ermöglicht, ohne Code-Duplikation oder inkonsistente Trainingspipelines.
#
# ---

# %%
def get_model(config):
    print(config)
    if config.model_type == "MLP":
        model = MLP(config) 
        optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "CNN":
        model = CNN(config) 
        optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "TRANSFER_VGG":
        model = VGG16(config);  
        optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "TRANSFER_RN":
        model = ResNet50(config);  
        optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()
    else:
        raise ValueError(f"Unknown model_type {config.model_type}")
    
    model = model.to(device)
    summary(model, input_size=(channel, image_size, image_size))

    return model, optimizer, loss_fn

# %% [markdown]
# #### Trainings Funktionen

# %%
def get_accuracy(output, target, batch_size):
    prediction=torch.max(output, 1)[1].view(target.size())
    corrects = (prediction.data == target.data).sum()
    accuracy = 100.0 * corrects / batch_size
    return accuracy.item()

# %%
def train_step(model, config, optimizer, loss_fn, train_loader): 
    loss_value = 0.0
    accuracy_value = 0.0


    for i, (images, labels) in enumerate(train_loader):
        model.train()

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_value += loss.detach().item()
        accuracy_value += get_accuracy(outputs, labels, config.batch_size)

    loss_avg = loss_value / i
    accuracy_avg = accuracy_value / i

    return loss_avg, accuracy_avg

# %%
def val_step(model, config, loss_fn, val_loader):
    loss_value = 0.0
    accuracy_value = 0.0

    with torch.no_grad():
        for i, (images, labels) in enumerate(val_loader):
            model.eval()

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = loss_fn(outputs, labels)

            loss_value += loss.detach().item()
            accuracy_value += get_accuracy(outputs, labels, config.batch_size)

    loss_avg = loss_value / i
    accuracy_avg = accuracy_value / i

    return loss_avg, accuracy_avg

# %%
def print_results(num_epochs, train_accuracy, val_accuracy, model, val_loader, full_dataset):

    # print training and validation accuracy plot
    plt.figure(figsize=(12,8))
    plt.plot(range(num_epochs),train_accuracy,"r",label="training accuracy")
    plt.plot(range(num_epochs),val_accuracy,"b",label="validation accuracy")
    plt.xlabel("epoch")
    plt.grid(True)
    plt.legend()
    plt.show()

    # evaluate on validation set
    y_true = []
    y_pred = []

    model.eval()
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # print classification report 
    print(classification_report(y_true, y_pred))

    # print confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=full_dataset.classes, yticklabels=full_dataset.classes)
    plt.xlabel('Vorhergesagte Klasse (Prediction)')
    plt.ylabel('Wahre Klasse (True Label)')
    plt.title('Confusion Matrix: Was wird womit verwechselt?')
    plt.show()

# %%
def run_training_loop(name, model, config, optimizer, loss_fn, train_loader, val_loader, full_dataset ):
    print(f"Start training for {name} with {config.epochs} epochs...") 
    
    model = model.to(device) 

    history = {
        'train_loss': [],
        'train_accuracy': [],
        'val_loss': [],
        'val_accuracy': []
    }

    for epoch in range(config.epochs):
        
        train_loss_avg, train_accuracy_avg = train_step(model, config, optimizer, loss_fn, train_loader)
        val_loss_avg, val_accuracy_avg = val_step(model, config, loss_fn, val_loader)

        history['train_loss'].append(train_loss_avg)
        history['train_accuracy'].append(train_accuracy_avg)
        history['val_loss'].append(val_loss_avg)
        history['val_accuracy'].append(val_accuracy_avg)

        print(f"Epoch [{epoch+1}/{config.epochs}], "
              f"Train Loss: {train_loss_avg:.4f}, Train Acc: {train_accuracy_avg:.2f}%, "
              f"Val Loss: {val_loss_avg:.4f}, Val Acc: {val_accuracy_avg:.2f}%")
        
        if USE_WANDB:
            wandb.log({
                "train_loss": train_loss_avg,
                "train_accuracy": train_accuracy_avg,
                "val_loss": val_loss_avg,
                "val_accuracy": val_accuracy_avg
            })
    
    print_results(config.epochs, history['train_accuracy'], history['val_accuracy'], model, val_loader , full_dataset)

# %%
def model_pipeline(name, config):
    
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, extern_train_loader, extern_val_loader, extern_full_dataset)

# %%
model_pipeline("MLP", config_mlp)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_000816-wzlsvqwy</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/wzlsvqwy' target="_blank">radiant-brook-73</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/wzlsvqwy' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/wzlsvqwy</a>
# {'model_type': 'MLP', 'batch_size': 16, 'learning_rate': 0.1, 'epochs': 15, 'hidden_dim': 512, 'dropout': 0.2}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]       1,573,376
#            Dropout-2                  [-1, 512]               0
#             Linear-3                    [-1, 5]           2,565
# ================================================================
# Total params: 1,575,941
# Trainable params: 1,575,941
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.01
# Params size (MB): 6.01
# Estimated Total Size (MB): 6.03
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5744, Train Acc: 29.13%, Val Loss: 1.5521, Val Acc: 33.76%
# Epoch [2/15], Train Loss: 1.5434, Train Acc: 32.60%, Val Loss: 1.5472, Val Acc: 35.41%
# Epoch [3/15], Train Loss: 1.5314, Train Acc: 34.84%, Val Loss: 1.6672, Val Acc: 23.26%
# Epoch [4/15], Train Loss: 1.5202, Train Acc: 36.62%, Val Loss: 1.5042, Val Acc: 38.82%
# Epoch [5/15], Train Loss: 1.5216, Train Acc: 36.67%, Val Loss: 1.5515, Val Acc: 33.63%
# Epoch [6/15], Train Loss: 1.5155, Train Acc: 36.91%, Val Loss: 1.5032, Val Acc: 38.98%
# Epoch [7/15], Train Loss: 1.5105, Train Acc: 37.71%, Val Loss: 1.5417, Val Acc: 35.02%
# Epoch [8/15], Train Loss: 1.5020, Train Acc: 38.17%, Val Loss: 1.4657, Val Acc: 43.65%
# Epoch [9/15], Train Loss: 1.4999, Train Acc: 38.82%, Val Loss: 1.5166, Val Acc: 38.76%
# Epoch [10/15], Train Loss: 1.4947, Train Acc: 39.41%, Val Loss: 1.4886, Val Acc: 41.27%
# Epoch [11/15], Train Loss: 1.4956, Train Acc: 39.52%, Val Loss: 1.5144, Val Acc: 37.44%
# Epoch [12/15], Train Loss: 1.5020, Train Acc: 38.82%, Val Loss: 1.4679, Val Acc: 43.88%
# Epoch [13/15], Train Loss: 1.4911, Train Acc: 39.87%, Val Loss: 1.4856, Val Acc: 41.40%
# Epoch [14/15], Train Loss: 1.4918, Train Acc: 39.83%, Val Loss: 1.5363, Val Acc: 36.69%
# Epoch [15/15], Train Loss: 1.4893, Train Acc: 40.32%, Val Loss: 1.4865, Val Acc: 40.95%
#               precision    recall  f1-score   support
#
#            0       0.61      0.32      0.42       661
#            1       0.49      0.12      0.19       565
#            2       0.50      0.27      0.35       721
#            3       0.36      0.74      0.48       580
#            4       0.35      0.63      0.45       591
#
#     accuracy                           0.41      3118
#    macro avg       0.46      0.41      0.38      3118
# weighted avg       0.47      0.41      0.38      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▅▆▆▆▆▇▇▇█▇███</td></tr><tr><td>train_loss</td><td>█▅▄▄▄▃▃▂▂▁▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▅▅▁▆▅▆▅█▆▇▆█▇▆▇</td></tr><tr><td>val_loss</td><td>▄▄█▂▄▂▄▁▃▂▃▁▂▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>40.32214</td></tr><tr><td>train_loss</td><td>1.48926</td></tr><tr><td>val_accuracy</td><td>40.94716</td></tr><tr><td>val_loss</td><td>1.48647</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">radiant-brook-73</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/wzlsvqwy' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/wzlsvqwy</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_000816-wzlsvqwy/logs</code>

# %%
model_pipeline("CNN", config_cnn)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_001411-8k7hjvoq</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8k7hjvoq' target="_blank">vivid-valley-74</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8k7hjvoq' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8k7hjvoq</a>
# {'model_type': 'CNN', 'batch_size': 16, 'learning_rate': 0.01, 'epochs': 30, 'hidden_dim_1': 1024, 'dropout': 0.2}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#          Dropout2d-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          Dropout2d-6          [-1, 128, 16, 16]               0
#        BatchNorm2d-7          [-1, 128, 16, 16]             256
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#             Conv2d-9            [-1, 256, 8, 8]         295,168
#         Dropout2d-10            [-1, 256, 8, 8]               0
#       BatchNorm2d-11            [-1, 256, 8, 8]             512
#         MaxPool2d-12            [-1, 256, 4, 4]               0
#            Conv2d-13            [-1, 512, 4, 4]       1,180,160
#         Dropout2d-14            [-1, 512, 4, 4]               0
#       BatchNorm2d-15            [-1, 512, 4, 4]           1,024
#         MaxPool2d-16            [-1, 512, 2, 2]               0
#            Linear-17                 [-1, 1024]       2,098,176
#           Dropout-18                 [-1, 1024]               0
#            Linear-19                    [-1, 5]           5,125
# ================================================================
# Total params: 3,656,197
# Trainable params: 3,656,197
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.06
# Params size (MB): 13.95
# Estimated Total Size (MB): 17.02
# ----------------------------------------------------------------
# Start training for CNN with 30 epochs...
# Epoch [1/30], Train Loss: 1.4664, Train Acc: 36.83%, Val Loss: 1.4526, Val Acc: 41.43%
# Epoch [2/30], Train Loss: 1.3275, Train Acc: 46.82%, Val Loss: 1.3412, Val Acc: 47.07%
# Epoch [3/30], Train Loss: 1.2572, Train Acc: 51.05%, Val Loss: 1.3646, Val Acc: 43.33%
# Epoch [4/30], Train Loss: 1.2244, Train Acc: 52.45%, Val Loss: 1.2123, Val Acc: 52.67%
# Epoch [5/30], Train Loss: 1.2005, Train Acc: 52.95%, Val Loss: 1.2066, Val Acc: 52.71%
# Epoch [6/30], Train Loss: 1.1797, Train Acc: 54.20%, Val Loss: 1.2722, Val Acc: 51.64%
# Epoch [7/30], Train Loss: 1.1585, Train Acc: 55.30%, Val Loss: 1.1906, Val Acc: 54.86%
# Epoch [8/30], Train Loss: 1.1477, Train Acc: 56.33%, Val Loss: 1.2037, Val Acc: 51.48%
# Epoch [9/30], Train Loss: 1.1427, Train Acc: 56.35%, Val Loss: 1.1563, Val Acc: 56.44%
# Epoch [10/30], Train Loss: 1.1261, Train Acc: 56.97%, Val Loss: 1.1466, Val Acc: 56.06%
# Epoch [11/30], Train Loss: 1.1168, Train Acc: 56.21%, Val Loss: 1.0590, Val Acc: 60.73%
# Epoch [12/30], Train Loss: 1.1046, Train Acc: 57.39%, Val Loss: 1.0976, Val Acc: 58.41%
# Epoch [13/30], Train Loss: 1.0989, Train Acc: 57.46%, Val Loss: 1.0855, Val Acc: 58.57%
# Epoch [14/30], Train Loss: 1.0793, Train Acc: 58.71%, Val Loss: 1.1220, Val Acc: 57.54%
# Epoch [15/30], Train Loss: 1.0789, Train Acc: 59.11%, Val Loss: 1.1164, Val Acc: 57.02%
# Epoch [16/30], Train Loss: 1.0679, Train Acc: 58.88%, Val Loss: 1.1410, Val Acc: 57.80%
# Epoch [17/30], Train Loss: 1.0569, Train Acc: 59.90%, Val Loss: 1.0955, Val Acc: 58.80%
# Epoch [18/30], Train Loss: 1.0479, Train Acc: 59.39%, Val Loss: 1.0586, Val Acc: 60.60%
# Epoch [19/30], Train Loss: 1.0419, Train Acc: 60.24%, Val Loss: 1.0273, Val Acc: 61.98%
# Epoch [20/30], Train Loss: 1.0434, Train Acc: 59.93%, Val Loss: 1.0399, Val Acc: 61.79%
# Epoch [21/30], Train Loss: 1.0302, Train Acc: 60.71%, Val Loss: 1.0387, Val Acc: 60.79%
# Epoch [22/30], Train Loss: 1.0183, Train Acc: 60.70%, Val Loss: 1.0573, Val Acc: 60.76%
# Epoch [23/30], Train Loss: 1.0175, Train Acc: 61.63%, Val Loss: 1.0081, Val Acc: 62.76%
# Epoch [24/30], Train Loss: 1.0169, Train Acc: 61.50%, Val Loss: 1.0222, Val Acc: 63.08%
# Epoch [25/30], Train Loss: 1.0176, Train Acc: 61.22%, Val Loss: 0.9362, Val Acc: 65.24%
# Epoch [26/30], Train Loss: 1.0008, Train Acc: 61.88%, Val Loss: 0.9394, Val Acc: 65.05%
# Epoch [27/30], Train Loss: 0.9930, Train Acc: 61.70%, Val Loss: 1.0242, Val Acc: 63.14%
# Epoch [28/30], Train Loss: 0.9916, Train Acc: 62.50%, Val Loss: 0.9837, Val Acc: 63.43%
# Epoch [29/30], Train Loss: 0.9821, Train Acc: 63.11%, Val Loss: 0.9857, Val Acc: 64.88%
# Epoch [30/30], Train Loss: 0.9788, Train Acc: 62.35%, Val Loss: 0.9581, Val Acc: 64.82%
#               precision    recall  f1-score   support
#
#            0       0.55      0.72      0.62       661
#            1       0.63      0.62      0.62       565
#            2       0.72      0.54      0.62       721
#            3       0.69      0.79      0.74       580
#            4       0.68      0.58      0.62       591
#
#     accuracy                           0.65      3118
#    macro avg       0.65      0.65      0.65      3118
# weighted avg       0.66      0.65      0.64      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇██▇█████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▂▄▄▄▅▄▅▅▇▆▆▆▆▆▆▇▇▇▇▇▇▇██▇▇██</td></tr><tr><td>val_loss</td><td>█▆▇▅▅▆▄▅▄▄▃▃▃▄▃▄▃▃▂▂▂▃▂▂▁▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>62.34857</td></tr><tr><td>train_loss</td><td>0.97876</td></tr><tr><td>val_accuracy</td><td>64.81959</td></tr><tr><td>val_loss</td><td>0.95809</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vivid-valley-74</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8k7hjvoq' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8k7hjvoq</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_001411-8k7hjvoq/logs</code>

# %%
model_pipeline("Transfer Learning - From Scratch", config_transfer_vgg["scratch"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_002543-01l8jh9o</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/01l8jh9o' target="_blank">likely-paper-75</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/01l8jh9o' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/01l8jh9o</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FROM_SCRATCH', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - From Scratch with 30 epochs...
# Epoch [1/30], Train Loss: 1.5941, Train Acc: 23.10%, Val Loss: 1.5276, Val Acc: 28.93%
# Epoch [2/30], Train Loss: 1.4940, Train Acc: 29.32%, Val Loss: 1.4744, Val Acc: 31.96%
# Epoch [3/30], Train Loss: 1.4448, Train Acc: 32.71%, Val Loss: 1.4424, Val Acc: 31.35%
# Epoch [4/30], Train Loss: 1.4133, Train Acc: 34.42%, Val Loss: 1.3579, Val Acc: 39.79%
# Epoch [5/30], Train Loss: 1.3460, Train Acc: 41.46%, Val Loss: 1.3073, Val Acc: 44.56%
# Epoch [6/30], Train Loss: 1.2978, Train Acc: 44.22%, Val Loss: 1.2356, Val Acc: 48.03%
# Epoch [7/30], Train Loss: 1.2275, Train Acc: 50.92%, Val Loss: 1.1681, Val Acc: 56.19%
# Epoch [8/30], Train Loss: 1.1680, Train Acc: 54.78%, Val Loss: 1.1216, Val Acc: 58.47%
# Epoch [9/30], Train Loss: 1.1282, Train Acc: 56.72%, Val Loss: 1.0624, Val Acc: 60.08%
# Epoch [10/30], Train Loss: 1.0973, Train Acc: 58.14%, Val Loss: 1.0927, Val Acc: 58.05%
# Epoch [11/30], Train Loss: 1.0747, Train Acc: 59.53%, Val Loss: 1.0170, Val Acc: 61.95%
# Epoch [12/30], Train Loss: 1.0412, Train Acc: 60.77%, Val Loss: 0.9902, Val Acc: 63.95%
# Epoch [13/30], Train Loss: 1.0144, Train Acc: 62.16%, Val Loss: 1.0183, Val Acc: 62.53%
# Epoch [14/30], Train Loss: 0.9795, Train Acc: 64.03%, Val Loss: 0.9978, Val Acc: 62.73%
# Epoch [15/30], Train Loss: 0.9859, Train Acc: 63.57%, Val Loss: 0.9755, Val Acc: 63.60%
# Epoch [16/30], Train Loss: 0.9499, Train Acc: 64.84%, Val Loss: 0.9823, Val Acc: 63.47%
# Epoch [17/30], Train Loss: 0.9312, Train Acc: 65.51%, Val Loss: 0.9670, Val Acc: 65.17%
# Epoch [18/30], Train Loss: 0.9110, Train Acc: 66.04%, Val Loss: 0.9307, Val Acc: 66.66%
# Epoch [19/30], Train Loss: 0.8973, Train Acc: 67.04%, Val Loss: 0.8941, Val Acc: 67.75%
# Epoch [20/30], Train Loss: 0.8881, Train Acc: 67.58%, Val Loss: 0.8725, Val Acc: 68.62%
# Epoch [21/30], Train Loss: 0.8654, Train Acc: 68.53%, Val Loss: 0.9192, Val Acc: 66.49%
# Epoch [22/30], Train Loss: 0.8421, Train Acc: 69.42%, Val Loss: 0.8523, Val Acc: 69.78%
# Epoch [23/30], Train Loss: 0.8352, Train Acc: 69.53%, Val Loss: 0.8632, Val Acc: 68.56%
# Epoch [24/30], Train Loss: 0.8171, Train Acc: 70.35%, Val Loss: 0.8938, Val Acc: 68.91%
# Epoch [25/30], Train Loss: 0.7980, Train Acc: 70.93%, Val Loss: 0.8694, Val Acc: 69.30%
# Epoch [26/30], Train Loss: 0.7836, Train Acc: 71.35%, Val Loss: 0.8536, Val Acc: 70.14%
# Epoch [27/30], Train Loss: 0.7727, Train Acc: 71.20%, Val Loss: 0.8651, Val Acc: 69.27%
# Epoch [28/30], Train Loss: 0.7570, Train Acc: 72.52%, Val Loss: 0.9472, Val Acc: 64.40%
# Epoch [29/30], Train Loss: 0.7376, Train Acc: 73.27%, Val Loss: 0.8467, Val Acc: 69.65%
# Epoch [30/30], Train Loss: 0.7241, Train Acc: 73.97%, Val Loss: 0.8321, Val Acc: 70.91%
#               precision    recall  f1-score   support
#
#            0       0.74      0.61      0.67       661
#            1       0.71      0.72      0.71       565
#            2       0.65      0.77      0.70       721
#            3       0.74      0.84      0.79       580
#            4       0.72      0.60      0.65       591
#
#     accuracy                           0.71      3118
#    macro avg       0.71      0.71      0.70      3118
# weighted avg       0.71      0.71      0.70      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▂▃▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>train_loss</td><td>█▇▇▇▆▆▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▁▃▄▄▆▆▆▆▇▇▇▇▇▇▇▇▇█▇██████▇██</td></tr><tr><td>val_loss</td><td>█▇▇▆▆▅▄▄▃▄▃▃▃▃▂▃▂▂▂▁▂▁▁▂▁▁▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>73.96751</td></tr><tr><td>train_loss</td><td>0.72413</td></tr><tr><td>val_accuracy</td><td>70.90851</td></tr><tr><td>val_loss</td><td>0.83208</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">likely-paper-75</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/01l8jh9o' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/01l8jh9o</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_002543-01l8jh9o/logs</code>

# %%
model_pipeline("Transfer Learning - Pretrained", config_transfer_vgg["pretrained"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_003702-hrv1obsl</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hrv1obsl' target="_blank">unique-leaf-76</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hrv1obsl' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hrv1obsl</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_PRETRAINED', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 66,309
# Non-trainable params: 14,714,688
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - Pretrained with 30 epochs...
# Epoch [1/30], Train Loss: 1.4816, Train Acc: 38.84%, Val Loss: 1.3805, Val Acc: 44.17%
# Epoch [2/30], Train Loss: 1.3230, Train Acc: 48.11%, Val Loss: 1.2785, Val Acc: 48.65%
# Epoch [3/30], Train Loss: 1.2576, Train Acc: 51.31%, Val Loss: 1.2272, Val Acc: 50.74%
# Epoch [4/30], Train Loss: 1.2125, Train Acc: 52.67%, Val Loss: 1.2012, Val Acc: 51.55%
# Epoch [5/30], Train Loss: 1.1902, Train Acc: 53.73%, Val Loss: 1.1761, Val Acc: 52.84%
# Epoch [6/30], Train Loss: 1.1668, Train Acc: 55.05%, Val Loss: 1.1665, Val Acc: 52.32%
# Epoch [7/30], Train Loss: 1.1451, Train Acc: 55.38%, Val Loss: 1.1448, Val Acc: 54.19%
# Epoch [8/30], Train Loss: 1.1380, Train Acc: 56.14%, Val Loss: 1.1444, Val Acc: 53.48%
# Epoch [9/30], Train Loss: 1.1244, Train Acc: 56.92%, Val Loss: 1.1325, Val Acc: 54.09%
# Epoch [10/30], Train Loss: 1.1135, Train Acc: 57.56%, Val Loss: 1.1181, Val Acc: 55.06%
# Epoch [11/30], Train Loss: 1.1064, Train Acc: 57.10%, Val Loss: 1.1201, Val Acc: 54.83%
# Epoch [12/30], Train Loss: 1.0980, Train Acc: 57.59%, Val Loss: 1.1027, Val Acc: 55.90%
# Epoch [13/30], Train Loss: 1.1043, Train Acc: 57.79%, Val Loss: 1.1037, Val Acc: 56.38%
# Epoch [14/30], Train Loss: 1.0886, Train Acc: 58.03%, Val Loss: 1.0921, Val Acc: 57.09%
# Epoch [15/30], Train Loss: 1.0920, Train Acc: 57.65%, Val Loss: 1.0880, Val Acc: 58.02%
# Epoch [16/30], Train Loss: 1.0784, Train Acc: 58.74%, Val Loss: 1.0821, Val Acc: 57.76%
# Epoch [17/30], Train Loss: 1.0709, Train Acc: 59.49%, Val Loss: 1.0813, Val Acc: 58.18%
# Epoch [18/30], Train Loss: 1.0614, Train Acc: 59.73%, Val Loss: 1.0768, Val Acc: 58.25%
# Epoch [19/30], Train Loss: 1.0654, Train Acc: 59.14%, Val Loss: 1.0781, Val Acc: 58.22%
# Epoch [20/30], Train Loss: 1.0585, Train Acc: 59.29%, Val Loss: 1.0727, Val Acc: 58.44%
# Epoch [21/30], Train Loss: 1.0513, Train Acc: 60.12%, Val Loss: 1.0574, Val Acc: 59.44%
# Epoch [22/30], Train Loss: 1.0512, Train Acc: 59.36%, Val Loss: 1.0591, Val Acc: 59.66%
# Epoch [23/30], Train Loss: 1.0377, Train Acc: 59.65%, Val Loss: 1.0477, Val Acc: 60.12%
# Epoch [24/30], Train Loss: 1.0367, Train Acc: 60.28%, Val Loss: 1.0482, Val Acc: 60.24%
# Epoch [25/30], Train Loss: 1.0407, Train Acc: 60.20%, Val Loss: 1.0420, Val Acc: 60.02%
# Epoch [26/30], Train Loss: 1.0343, Train Acc: 60.34%, Val Loss: 1.0399, Val Acc: 59.54%
# Epoch [27/30], Train Loss: 1.0306, Train Acc: 61.00%, Val Loss: 1.0425, Val Acc: 59.92%
# Epoch [28/30], Train Loss: 1.0430, Train Acc: 60.04%, Val Loss: 1.0356, Val Acc: 60.15%
# Epoch [29/30], Train Loss: 1.0146, Train Acc: 60.82%, Val Loss: 1.0376, Val Acc: 60.18%
# Epoch [30/30], Train Loss: 1.0230, Train Acc: 61.44%, Val Loss: 1.0351, Val Acc: 60.02%
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52       661
#            1       0.60      0.62      0.61       565
#            2       0.66      0.65      0.66       721
#            3       0.64      0.62      0.63       580
#            4       0.53      0.60      0.56       591
#
#     accuracy                           0.60      3118
#    macro avg       0.60      0.60      0.60      3118
# weighted avg       0.60      0.60      0.60      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇█▇▇███████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇██████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>61.43998</td></tr><tr><td>train_loss</td><td>1.02305</td></tr><tr><td>val_accuracy</td><td>60.01933</td></tr><tr><td>val_loss</td><td>1.03507</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">unique-leaf-76</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hrv1obsl' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hrv1obsl</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_003702-hrv1obsl/logs</code>

# %%
model_pipeline("Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_004809-w4l7clia</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w4l7clia' target="_blank">youthful-armadillo-77</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w4l7clia' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w4l7clia</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - Finetune with 15 epochs...
# Epoch [1/15], Train Loss: 1.1728, Train Acc: 53.68%, Val Loss: 0.8918, Val Acc: 68.20%
# Epoch [2/15], Train Loss: 0.8818, Train Acc: 67.47%, Val Loss: 0.8255, Val Acc: 70.49%
# Epoch [3/15], Train Loss: 0.7779, Train Acc: 71.76%, Val Loss: 0.8108, Val Acc: 69.81%
# Epoch [4/15], Train Loss: 0.7221, Train Acc: 73.98%, Val Loss: 0.7276, Val Acc: 73.65%
# Epoch [5/15], Train Loss: 0.6693, Train Acc: 75.80%, Val Loss: 0.6773, Val Acc: 77.32%
# Epoch [6/15], Train Loss: 0.6280, Train Acc: 77.44%, Val Loss: 0.6369, Val Acc: 78.19%
# Epoch [7/15], Train Loss: 0.5787, Train Acc: 78.92%, Val Loss: 0.6065, Val Acc: 78.83%
# Epoch [8/15], Train Loss: 0.5440, Train Acc: 80.88%, Val Loss: 0.5749, Val Acc: 80.67%
# Epoch [9/15], Train Loss: 0.5119, Train Acc: 81.97%, Val Loss: 0.5585, Val Acc: 80.57%
# Epoch [10/15], Train Loss: 0.4675, Train Acc: 83.69%, Val Loss: 0.6239, Val Acc: 79.32%
# Epoch [11/15], Train Loss: 0.4515, Train Acc: 83.34%, Val Loss: 0.5337, Val Acc: 82.15%
# Epoch [12/15], Train Loss: 0.4250, Train Acc: 84.90%, Val Loss: 0.5812, Val Acc: 82.02%
# Epoch [13/15], Train Loss: 0.4028, Train Acc: 85.45%, Val Loss: 0.6018, Val Acc: 80.15%
# Epoch [14/15], Train Loss: 0.3839, Train Acc: 86.74%, Val Loss: 0.5523, Val Acc: 82.12%
# Epoch [15/15], Train Loss: 0.3610, Train Acc: 87.38%, Val Loss: 0.5373, Val Acc: 82.44%
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81       661
#            1       0.84      0.84      0.84       565
#            2       0.87      0.77      0.82       721
#            3       0.77      0.96      0.85       580
#            4       0.82      0.76      0.79       591
#
#     accuracy                           0.82      3118
#    macro avg       0.82      0.82      0.82      3118
# weighted avg       0.82      0.82      0.82      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▅▅▄▄▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▂▄▅▆▆▇▇▆██▇██</td></tr><tr><td>val_loss</td><td>█▇▆▅▄▃▂▂▁▃▁▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>87.3761</td></tr><tr><td>train_loss</td><td>0.36102</td></tr><tr><td>val_accuracy</td><td>82.44201</td></tr><tr><td>val_loss</td><td>0.53734</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">youthful-armadillo-77</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w4l7clia' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w4l7clia</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_004809-w4l7clia/logs</code>

# %%
def custom_model_pipeline(name, config):
    
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, custom_train_loader, custom_val_loader, custom_full_dataset)

# %%
custom_model_pipeline("Custom Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_005352-ii26aotp</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ii26aotp' target="_blank">vital-smoke-78</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ii26aotp' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ii26aotp</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Custom Transfer Learning - Finetune with 15 epochs...
# Epoch [1/15], Train Loss: 1.6355, Train Acc: 23.80%, Val Loss: 1.6640, Val Acc: 25.57%
# Epoch [2/15], Train Loss: 1.5620, Train Acc: 31.97%, Val Loss: 1.4052, Val Acc: 45.45%
# Epoch [3/15], Train Loss: 1.4467, Train Acc: 41.11%, Val Loss: 1.5533, Val Acc: 42.90%
# Epoch [4/15], Train Loss: 1.3911, Train Acc: 42.79%, Val Loss: 1.3275, Val Acc: 52.84%
# Epoch [5/15], Train Loss: 1.3117, Train Acc: 50.24%, Val Loss: 1.1838, Val Acc: 58.24%
# Epoch [6/15], Train Loss: 1.1883, Train Acc: 52.16%, Val Loss: 1.3660, Val Acc: 44.89%
# Epoch [7/15], Train Loss: 1.1495, Train Acc: 53.61%, Val Loss: 1.1938, Val Acc: 57.95%
# Epoch [8/15], Train Loss: 1.1204, Train Acc: 56.61%, Val Loss: 1.1009, Val Acc: 60.51%
# Epoch [9/15], Train Loss: 1.0153, Train Acc: 63.10%, Val Loss: 1.0850, Val Acc: 61.36%
# Epoch [10/15], Train Loss: 0.9769, Train Acc: 63.10%, Val Loss: 1.0522, Val Acc: 65.06%
# Epoch [11/15], Train Loss: 0.9309, Train Acc: 67.31%, Val Loss: 1.0316, Val Acc: 63.64%
# Epoch [12/15], Train Loss: 0.9077, Train Acc: 66.59%, Val Loss: 1.1494, Val Acc: 64.77%
# Epoch [13/15], Train Loss: 0.8275, Train Acc: 69.23%, Val Loss: 1.0704, Val Acc: 63.92%
# Epoch [14/15], Train Loss: 0.8154, Train Acc: 71.75%, Val Loss: 1.0581, Val Acc: 65.06%
# Epoch [15/15], Train Loss: 0.7309, Train Acc: 74.04%, Val Loss: 1.0747, Val Acc: 62.78%
#               precision    recall  f1-score   support
#
#            0       0.47      0.65      0.54        72
#            1       0.71      0.41      0.52        66
#            2       0.87      0.57      0.69        79
#            3       0.69      0.69      0.69        68
#            4       0.55      0.74      0.63        74
#
#     accuracy                           0.62       359
#    macro avg       0.66      0.61      0.61       359
# weighted avg       0.66      0.62      0.62       359
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▃▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>train_loss</td><td>█▇▇▆▅▅▄▄▃▃▃▂▂▂▁</td></tr><tr><td>val_accuracy</td><td>▁▅▄▆▇▄▇▇▇██████</td></tr><tr><td>val_loss</td><td>█▅▇▄▃▅▃▂▂▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>74.03846</td></tr><tr><td>train_loss</td><td>0.73086</td></tr><tr><td>val_accuracy</td><td>62.78409</td></tr><tr><td>val_loss</td><td>1.07473</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vital-smoke-78</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ii26aotp' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ii26aotp</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_005352-ii26aotp/logs</code>

# %% [markdown]
# ## Alle Daten

# %%
def all_model_pipeline(name, config):
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, all_train_loader, all_val_loader, all_full_dataset)

# %%
all_model_pipeline("Custom Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_005450-ozgmhjqf</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ozgmhjqf' target="_blank">lucky-lion-79</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ozgmhjqf' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ozgmhjqf</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Custom Transfer Learning - Finetune with 15 epochs...
# Epoch [1/15], Train Loss: 1.2332, Train Acc: 50.88%, Val Loss: 0.9951, Val Acc: 63.59%
# Epoch [2/15], Train Loss: 0.9925, Train Acc: 63.11%, Val Loss: 0.8941, Val Acc: 66.91%
# Epoch [3/15], Train Loss: 0.8721, Train Acc: 68.32%, Val Loss: 0.8621, Val Acc: 69.50%
# Epoch [4/15], Train Loss: 0.8064, Train Acc: 70.90%, Val Loss: 0.7687, Val Acc: 72.58%
# Epoch [5/15], Train Loss: 0.7588, Train Acc: 72.48%, Val Loss: 0.7065, Val Acc: 75.43%
# Epoch [6/15], Train Loss: 0.7102, Train Acc: 74.35%, Val Loss: 0.6872, Val Acc: 75.43%
# Epoch [7/15], Train Loss: 0.6693, Train Acc: 76.28%, Val Loss: 0.6916, Val Acc: 75.63%
# Epoch [8/15], Train Loss: 0.6123, Train Acc: 77.99%, Val Loss: 0.6756, Val Acc: 75.84%
# Epoch [9/15], Train Loss: 0.5906, Train Acc: 78.59%, Val Loss: 0.6572, Val Acc: 76.04%
# Epoch [10/15], Train Loss: 0.5585, Train Acc: 79.79%, Val Loss: 0.6597, Val Acc: 76.41%
# Epoch [11/15], Train Loss: 0.5243, Train Acc: 81.20%, Val Loss: 0.6407, Val Acc: 79.52%
# Epoch [12/15], Train Loss: 0.5033, Train Acc: 82.11%, Val Loss: 0.6206, Val Acc: 78.05%
# Epoch [13/15], Train Loss: 0.4657, Train Acc: 83.19%, Val Loss: 0.6696, Val Acc: 77.88%
# Epoch [14/15], Train Loss: 0.4308, Train Acc: 84.88%, Val Loss: 0.6358, Val Acc: 78.28%
# Epoch [15/15], Train Loss: 0.4234, Train Acc: 84.72%, Val Loss: 0.6505, Val Acc: 77.88%
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.74       698
#            1       0.78      0.82      0.80       650
#            2       0.82      0.76      0.79       723
#            3       0.79      0.90      0.84       709
#            4       0.75      0.70      0.72       697
#
#     accuracy                           0.78      3477
#    macro avg       0.78      0.78      0.78      3477
# weighted avg       0.78      0.78      0.78      3477
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▅▅▅▆▆▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▅▆▆▆▆▆▇█▇▇▇▇</td></tr><tr><td>val_loss</td><td>█▆▆▄▃▂▂▂▂▂▁▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>84.72085</td></tr><tr><td>train_loss</td><td>0.42343</td></tr><tr><td>val_accuracy</td><td>77.88018</td></tr><tr><td>val_loss</td><td>0.65051</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lucky-lion-79</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ozgmhjqf' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ozgmhjqf</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_005450-ozgmhjqf/logs</code>

# %% [markdown]
# ## Finetuning with Custom Data and ResNet50

# %%
custom_model_pipeline("Custom Data Transfer Learning with ResNet50", config_transfer_rn["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_010126-lq1kivpt</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/lq1kivpt' target="_blank">fluent-snowflake-80</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/lq1kivpt' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/lq1kivpt</a>
# {'model_type': 'TRANSFER_RN', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]           4,096
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-12            [-1, 256, 8, 8]             512
#            Conv2d-13            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-14            [-1, 256, 8, 8]             512
#              ReLU-15            [-1, 256, 8, 8]               0
#        Bottleneck-16            [-1, 256, 8, 8]               0
#            Conv2d-17             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-18             [-1, 64, 8, 8]             128
#              ReLU-19             [-1, 64, 8, 8]               0
#            Conv2d-20             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-21             [-1, 64, 8, 8]             128
#              ReLU-22             [-1, 64, 8, 8]               0
#            Conv2d-23            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-24            [-1, 256, 8, 8]             512
#              ReLU-25            [-1, 256, 8, 8]               0
#        Bottleneck-26            [-1, 256, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-28             [-1, 64, 8, 8]             128
#              ReLU-29             [-1, 64, 8, 8]               0
#            Conv2d-30             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-31             [-1, 64, 8, 8]             128
#              ReLU-32             [-1, 64, 8, 8]               0
#            Conv2d-33            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-34            [-1, 256, 8, 8]             512
#              ReLU-35            [-1, 256, 8, 8]               0
#        Bottleneck-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 128, 8, 8]          32,768
#       BatchNorm2d-38            [-1, 128, 8, 8]             256
#              ReLU-39            [-1, 128, 8, 8]               0
#            Conv2d-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#            Conv2d-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#            Conv2d-45            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-46            [-1, 512, 4, 4]           1,024
#              ReLU-47            [-1, 512, 4, 4]               0
#        Bottleneck-48            [-1, 512, 4, 4]               0
#            Conv2d-49            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#            Conv2d-52            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-53            [-1, 128, 4, 4]             256
#              ReLU-54            [-1, 128, 4, 4]               0
#            Conv2d-55            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 512, 4, 4]           1,024
#              ReLU-57            [-1, 512, 4, 4]               0
#        Bottleneck-58            [-1, 512, 4, 4]               0
#            Conv2d-59            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-60            [-1, 128, 4, 4]             256
#              ReLU-61            [-1, 128, 4, 4]               0
#            Conv2d-62            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-63            [-1, 128, 4, 4]             256
#              ReLU-64            [-1, 128, 4, 4]               0
#            Conv2d-65            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-66            [-1, 512, 4, 4]           1,024
#              ReLU-67            [-1, 512, 4, 4]               0
#        Bottleneck-68            [-1, 512, 4, 4]               0
#            Conv2d-69            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-70            [-1, 128, 4, 4]             256
#              ReLU-71            [-1, 128, 4, 4]               0
#            Conv2d-72            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-73            [-1, 128, 4, 4]             256
#              ReLU-74            [-1, 128, 4, 4]               0
#            Conv2d-75            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-76            [-1, 512, 4, 4]           1,024
#              ReLU-77            [-1, 512, 4, 4]               0
#        Bottleneck-78            [-1, 512, 4, 4]               0
#            Conv2d-79            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-80            [-1, 256, 4, 4]             512
#              ReLU-81            [-1, 256, 4, 4]               0
#            Conv2d-82            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-83            [-1, 256, 2, 2]             512
#              ReLU-84            [-1, 256, 2, 2]               0
#            Conv2d-85           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-86           [-1, 1024, 2, 2]           2,048
#            Conv2d-87           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-88           [-1, 1024, 2, 2]           2,048
#              ReLU-89           [-1, 1024, 2, 2]               0
#        Bottleneck-90           [-1, 1024, 2, 2]               0
#            Conv2d-91            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-92            [-1, 256, 2, 2]             512
#              ReLU-93            [-1, 256, 2, 2]               0
#            Conv2d-94            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#            Conv2d-97           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-98           [-1, 1024, 2, 2]           2,048
#              ReLU-99           [-1, 1024, 2, 2]               0
#       Bottleneck-100           [-1, 1024, 2, 2]               0
#           Conv2d-101            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-102            [-1, 256, 2, 2]             512
#             ReLU-103            [-1, 256, 2, 2]               0
#           Conv2d-104            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-105            [-1, 256, 2, 2]             512
#             ReLU-106            [-1, 256, 2, 2]               0
#           Conv2d-107           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-108           [-1, 1024, 2, 2]           2,048
#             ReLU-109           [-1, 1024, 2, 2]               0
#       Bottleneck-110           [-1, 1024, 2, 2]               0
#           Conv2d-111            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-112            [-1, 256, 2, 2]             512
#             ReLU-113            [-1, 256, 2, 2]               0
#           Conv2d-114            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-115            [-1, 256, 2, 2]             512
#             ReLU-116            [-1, 256, 2, 2]               0
#           Conv2d-117           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-118           [-1, 1024, 2, 2]           2,048
#             ReLU-119           [-1, 1024, 2, 2]               0
#       Bottleneck-120           [-1, 1024, 2, 2]               0
#           Conv2d-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#           Conv2d-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#           Conv2d-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
#             ReLU-129           [-1, 1024, 2, 2]               0
#       Bottleneck-130           [-1, 1024, 2, 2]               0
#           Conv2d-131            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-132            [-1, 256, 2, 2]             512
#             ReLU-133            [-1, 256, 2, 2]               0
#           Conv2d-134            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-135            [-1, 256, 2, 2]             512
#             ReLU-136            [-1, 256, 2, 2]               0
#           Conv2d-137           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-138           [-1, 1024, 2, 2]           2,048
#             ReLU-139           [-1, 1024, 2, 2]               0
#       Bottleneck-140           [-1, 1024, 2, 2]               0
#           Conv2d-141            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-142            [-1, 512, 2, 2]           1,024
#             ReLU-143            [-1, 512, 2, 2]               0
#           Conv2d-144            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-145            [-1, 512, 1, 1]           1,024
#             ReLU-146            [-1, 512, 1, 1]               0
#           Conv2d-147           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 1, 1]           4,096
#           Conv2d-149           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 1, 1]           4,096
#             ReLU-151           [-1, 2048, 1, 1]               0
#       Bottleneck-152           [-1, 2048, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-154            [-1, 512, 1, 1]           1,024
#             ReLU-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-157            [-1, 512, 1, 1]           1,024
#             ReLU-158            [-1, 512, 1, 1]               0
#           Conv2d-159           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 1, 1]           4,096
#             ReLU-161           [-1, 2048, 1, 1]               0
#       Bottleneck-162           [-1, 2048, 1, 1]               0
#           Conv2d-163            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-164            [-1, 512, 1, 1]           1,024
#             ReLU-165            [-1, 512, 1, 1]               0
#           Conv2d-166            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-167            [-1, 512, 1, 1]           1,024
#             ReLU-168            [-1, 512, 1, 1]               0
#           Conv2d-169           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 1, 1]           4,096
#             ReLU-171           [-1, 2048, 1, 1]               0
#       Bottleneck-172           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#          Flatten-174                 [-1, 2048]               0
#           Linear-175                  [-1, 128]         262,272
#             ReLU-176                  [-1, 128]               0
#          Dropout-177                  [-1, 128]               0
#           Linear-178                    [-1, 5]             645
#           ResNet-179                    [-1, 5]               0
# ================================================================
# Total params: 23,770,949
# Trainable params: 23,770,949
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.88
# Params size (MB): 90.68
# Estimated Total Size (MB): 96.57
# ----------------------------------------------------------------
# Start training for Custom Data Transfer Learning with ResNet50 with 15 epochs...
# Epoch [1/15], Train Loss: 1.6294, Train Acc: 24.28%, Val Loss: 3.6671, Val Acc: 27.27%
# Epoch [2/15], Train Loss: 1.5162, Train Acc: 35.94%, Val Loss: 2.9830, Val Acc: 29.55%
# Epoch [3/15], Train Loss: 1.4378, Train Acc: 42.19%, Val Loss: 2.3062, Val Acc: 32.10%
# Epoch [4/15], Train Loss: 1.3654, Train Acc: 47.12%, Val Loss: 1.8251, Val Acc: 42.90%
# Epoch [5/15], Train Loss: 1.3112, Train Acc: 48.20%, Val Loss: 2.0273, Val Acc: 41.19%
# Epoch [6/15], Train Loss: 1.2470, Train Acc: 51.68%, Val Loss: 5.6898, Val Acc: 36.93%
# Epoch [7/15], Train Loss: 1.1976, Train Acc: 53.61%, Val Loss: 2.5820, Val Acc: 51.99%
# Epoch [8/15], Train Loss: 1.1393, Train Acc: 56.25%, Val Loss: 1.7260, Val Acc: 56.25%
# Epoch [9/15], Train Loss: 1.1179, Train Acc: 58.53%, Val Loss: 1.3529, Val Acc: 57.10%
# Epoch [10/15], Train Loss: 1.0785, Train Acc: 57.57%, Val Loss: 1.2959, Val Acc: 61.93%
# Epoch [11/15], Train Loss: 0.9771, Train Acc: 62.74%, Val Loss: 1.3361, Val Acc: 55.40%
# Epoch [12/15], Train Loss: 0.9905, Train Acc: 66.71%, Val Loss: 1.1449, Val Acc: 62.78%
# Epoch [13/15], Train Loss: 0.9293, Train Acc: 67.31%, Val Loss: 1.0575, Val Acc: 65.91%
# Epoch [14/15], Train Loss: 0.9181, Train Acc: 66.35%, Val Loss: 1.0590, Val Acc: 63.07%
# Epoch [15/15], Train Loss: 0.8709, Train Acc: 68.99%, Val Loss: 0.9909, Val Acc: 67.05%
#               precision    recall  f1-score   support
#
#            0       0.61      0.56      0.58        72
#            1       0.58      0.56      0.57        66
#            2       0.72      0.71      0.71        79
#            3       0.70      0.76      0.73        68
#            4       0.66      0.69      0.68        74
#
#     accuracy                           0.66       359
#    macro avg       0.65      0.66      0.65       359
# weighted avg       0.66      0.66      0.66       359
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▇████</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▄▄▃▃▃▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▂▄▃▃▅▆▆▇▆▇█▇█</td></tr><tr><td>val_loss</td><td>▅▄▃▂▃█▃▂▂▁▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>68.99038</td></tr><tr><td>train_loss</td><td>0.87088</td></tr><tr><td>val_accuracy</td><td>67.04545</td></tr><tr><td>val_loss</td><td>0.99094</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fluent-snowflake-80</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/lq1kivpt' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/lq1kivpt</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_010126-lq1kivpt/logs</code>

# %%
all_model_pipeline("All Data Transfer Learning with ResNet50", config_transfer_rn["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260120_010226-oo6pw71d</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/oo6pw71d' target="_blank">playful-disco-81</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/oo6pw71d' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/oo6pw71d</a>
# {'model_type': 'TRANSFER_RN', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]           4,096
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-12            [-1, 256, 8, 8]             512
#            Conv2d-13            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-14            [-1, 256, 8, 8]             512
#              ReLU-15            [-1, 256, 8, 8]               0
#        Bottleneck-16            [-1, 256, 8, 8]               0
#            Conv2d-17             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-18             [-1, 64, 8, 8]             128
#              ReLU-19             [-1, 64, 8, 8]               0
#            Conv2d-20             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-21             [-1, 64, 8, 8]             128
#              ReLU-22             [-1, 64, 8, 8]               0
#            Conv2d-23            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-24            [-1, 256, 8, 8]             512
#              ReLU-25            [-1, 256, 8, 8]               0
#        Bottleneck-26            [-1, 256, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-28             [-1, 64, 8, 8]             128
#              ReLU-29             [-1, 64, 8, 8]               0
#            Conv2d-30             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-31             [-1, 64, 8, 8]             128
#              ReLU-32             [-1, 64, 8, 8]               0
#            Conv2d-33            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-34            [-1, 256, 8, 8]             512
#              ReLU-35            [-1, 256, 8, 8]               0
#        Bottleneck-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 128, 8, 8]          32,768
#       BatchNorm2d-38            [-1, 128, 8, 8]             256
#              ReLU-39            [-1, 128, 8, 8]               0
#            Conv2d-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#            Conv2d-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#            Conv2d-45            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-46            [-1, 512, 4, 4]           1,024
#              ReLU-47            [-1, 512, 4, 4]               0
#        Bottleneck-48            [-1, 512, 4, 4]               0
#            Conv2d-49            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#            Conv2d-52            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-53            [-1, 128, 4, 4]             256
#              ReLU-54            [-1, 128, 4, 4]               0
#            Conv2d-55            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 512, 4, 4]           1,024
#              ReLU-57            [-1, 512, 4, 4]               0
#        Bottleneck-58            [-1, 512, 4, 4]               0
#            Conv2d-59            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-60            [-1, 128, 4, 4]             256
#              ReLU-61            [-1, 128, 4, 4]               0
#            Conv2d-62            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-63            [-1, 128, 4, 4]             256
#              ReLU-64            [-1, 128, 4, 4]               0
#            Conv2d-65            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-66            [-1, 512, 4, 4]           1,024
#              ReLU-67            [-1, 512, 4, 4]               0
#        Bottleneck-68            [-1, 512, 4, 4]               0
#            Conv2d-69            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-70            [-1, 128, 4, 4]             256
#              ReLU-71            [-1, 128, 4, 4]               0
#            Conv2d-72            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-73            [-1, 128, 4, 4]             256
#              ReLU-74            [-1, 128, 4, 4]               0
#            Conv2d-75            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-76            [-1, 512, 4, 4]           1,024
#              ReLU-77            [-1, 512, 4, 4]               0
#        Bottleneck-78            [-1, 512, 4, 4]               0
#            Conv2d-79            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-80            [-1, 256, 4, 4]             512
#              ReLU-81            [-1, 256, 4, 4]               0
#            Conv2d-82            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-83            [-1, 256, 2, 2]             512
#              ReLU-84            [-1, 256, 2, 2]               0
#            Conv2d-85           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-86           [-1, 1024, 2, 2]           2,048
#            Conv2d-87           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-88           [-1, 1024, 2, 2]           2,048
#              ReLU-89           [-1, 1024, 2, 2]               0
#        Bottleneck-90           [-1, 1024, 2, 2]               0
#            Conv2d-91            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-92            [-1, 256, 2, 2]             512
#              ReLU-93            [-1, 256, 2, 2]               0
#            Conv2d-94            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#            Conv2d-97           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-98           [-1, 1024, 2, 2]           2,048
#              ReLU-99           [-1, 1024, 2, 2]               0
#       Bottleneck-100           [-1, 1024, 2, 2]               0
#           Conv2d-101            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-102            [-1, 256, 2, 2]             512
#             ReLU-103            [-1, 256, 2, 2]               0
#           Conv2d-104            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-105            [-1, 256, 2, 2]             512
#             ReLU-106            [-1, 256, 2, 2]               0
#           Conv2d-107           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-108           [-1, 1024, 2, 2]           2,048
#             ReLU-109           [-1, 1024, 2, 2]               0
#       Bottleneck-110           [-1, 1024, 2, 2]               0
#           Conv2d-111            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-112            [-1, 256, 2, 2]             512
#             ReLU-113            [-1, 256, 2, 2]               0
#           Conv2d-114            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-115            [-1, 256, 2, 2]             512
#             ReLU-116            [-1, 256, 2, 2]               0
#           Conv2d-117           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-118           [-1, 1024, 2, 2]           2,048
#             ReLU-119           [-1, 1024, 2, 2]               0
#       Bottleneck-120           [-1, 1024, 2, 2]               0
#           Conv2d-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#           Conv2d-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#           Conv2d-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
#             ReLU-129           [-1, 1024, 2, 2]               0
#       Bottleneck-130           [-1, 1024, 2, 2]               0
#           Conv2d-131            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-132            [-1, 256, 2, 2]             512
#             ReLU-133            [-1, 256, 2, 2]               0
#           Conv2d-134            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-135            [-1, 256, 2, 2]             512
#             ReLU-136            [-1, 256, 2, 2]               0
#           Conv2d-137           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-138           [-1, 1024, 2, 2]           2,048
#             ReLU-139           [-1, 1024, 2, 2]               0
#       Bottleneck-140           [-1, 1024, 2, 2]               0
#           Conv2d-141            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-142            [-1, 512, 2, 2]           1,024
#             ReLU-143            [-1, 512, 2, 2]               0
#           Conv2d-144            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-145            [-1, 512, 1, 1]           1,024
#             ReLU-146            [-1, 512, 1, 1]               0
#           Conv2d-147           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 1, 1]           4,096
#           Conv2d-149           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 1, 1]           4,096
#             ReLU-151           [-1, 2048, 1, 1]               0
#       Bottleneck-152           [-1, 2048, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-154            [-1, 512, 1, 1]           1,024
#             ReLU-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-157            [-1, 512, 1, 1]           1,024
#             ReLU-158            [-1, 512, 1, 1]               0
#           Conv2d-159           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 1, 1]           4,096
#             ReLU-161           [-1, 2048, 1, 1]               0
#       Bottleneck-162           [-1, 2048, 1, 1]               0
#           Conv2d-163            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-164            [-1, 512, 1, 1]           1,024
#             ReLU-165            [-1, 512, 1, 1]               0
#           Conv2d-166            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-167            [-1, 512, 1, 1]           1,024
#             ReLU-168            [-1, 512, 1, 1]               0
#           Conv2d-169           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 1, 1]           4,096
#             ReLU-171           [-1, 2048, 1, 1]               0
#       Bottleneck-172           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#          Flatten-174                 [-1, 2048]               0
#           Linear-175                  [-1, 128]         262,272
#             ReLU-176                  [-1, 128]               0
#          Dropout-177                  [-1, 128]               0
#           Linear-178                    [-1, 5]             645
#           ResNet-179                    [-1, 5]               0
# ================================================================
# Total params: 23,770,949
# Trainable params: 23,770,949
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.88
# Params size (MB): 90.68
# Estimated Total Size (MB): 96.57
# ----------------------------------------------------------------
# Start training for All Data Transfer Learning with ResNet50 with 15 epochs...
# Epoch [1/15], Train Loss: 1.2955, Train Acc: 47.50%, Val Loss: 2.3996, Val Acc: 52.48%
# Epoch [2/15], Train Loss: 1.0964, Train Acc: 58.93%, Val Loss: 0.9968, Val Acc: 63.48%
# Epoch [3/15], Train Loss: 1.0331, Train Acc: 61.54%, Val Loss: 0.9127, Val Acc: 66.19%
# Epoch [4/15], Train Loss: 0.9691, Train Acc: 64.03%, Val Loss: 0.8019, Val Acc: 71.14%
# Epoch [5/15], Train Loss: 0.9246, Train Acc: 65.93%, Val Loss: 0.7838, Val Acc: 70.88%
# Epoch [6/15], Train Loss: 0.8946, Train Acc: 67.45%, Val Loss: 0.7381, Val Acc: 73.68%
# Epoch [7/15], Train Loss: 0.8567, Train Acc: 69.00%, Val Loss: 0.7084, Val Acc: 74.80%
# Epoch [8/15], Train Loss: 0.8395, Train Acc: 68.85%, Val Loss: 0.7185, Val Acc: 74.40%
# Epoch [9/15], Train Loss: 0.7954, Train Acc: 71.64%, Val Loss: 0.6787, Val Acc: 74.74%
# Epoch [10/15], Train Loss: 0.7762, Train Acc: 72.12%, Val Loss: 0.6621, Val Acc: 76.41%
# Epoch [11/15], Train Loss: 0.7531, Train Acc: 72.89%, Val Loss: 0.6812, Val Acc: 75.52%
# Epoch [12/15], Train Loss: 0.7284, Train Acc: 73.94%, Val Loss: 0.6820, Val Acc: 76.01%
# Epoch [13/15], Train Loss: 0.7018, Train Acc: 75.23%, Val Loss: 0.6721, Val Acc: 75.84%
# Epoch [14/15], Train Loss: 0.6738, Train Acc: 76.32%, Val Loss: 0.6299, Val Acc: 77.25%
# Epoch [15/15], Train Loss: 0.6444, Train Acc: 77.38%, Val Loss: 0.6731, Val Acc: 75.72%
#               precision    recall  f1-score   support
#
#            0       0.79      0.64      0.71       698
#            1       0.81      0.76      0.78       650
#            2       0.70      0.80      0.74       723
#            3       0.81      0.85      0.83       709
#            4       0.70      0.74      0.72       697
#
#     accuracy                           0.76      3477
#    macro avg       0.76      0.76      0.76      3477
# weighted avg       0.76      0.76      0.76      3477
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▄▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▃▃▃▂▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▅▆▆▇▇▇▇██████</td></tr><tr><td>val_loss</td><td>█▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>77.38389</td></tr><tr><td>train_loss</td><td>0.64438</td></tr><tr><td>val_accuracy</td><td>75.72005</td></tr><tr><td>val_loss</td><td>0.67309</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">playful-disco-81</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/oo6pw71d' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/oo6pw71d</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260120_010226-oo6pw71d/logs</code>

# %% [markdown]
# ### Hyperparameteroptimisation

# %% [markdown]
# Sweep Konfigurationen (Hyperparameter Search-Space):

# %%
parameters_mlp = { 
    'model_type': {
        'value': 'MLP'},
    'epochs': {
        'value': 15}, 
    'batch_size': {
        'values': [16,64]},
    'learning_rate': {
        'values': [0.005,0.01]},  
    'hidden_dim': {
        'values': [32,64]}, 
    'dropout': {
        'values': [0.0,0.3]}
    }

# %%
sweep_config = {
    "method" : "random",
    "parameters" : parameters_mlp
}

# %%
sweep_id=wandb.sweep(sweep_config,project=WANDB_PROJECT)
# Out:
# Create sweep with ID: absoxzpu
# Sweep URL: https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/absoxzpu

# %%
wandb.agent(sweep_id, model_pipeline("MLP", sweep_config), count=10)
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260119_134730-c9kr3t2v</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/c9kr3t2v' target="_blank">brisk-sunset-54</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/c9kr3t2v' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/c9kr3t2v</a>
# {'method': 'random', 'parameters': {'batch_size': {'values': [16, 64]}, 'learning_rate': {'values': [0.005, 0.01]}, 'hidden_dim': {'values': [32, 64]}, 'dropout': {'values': [0, 0.3]}, 'model_type': {'value': 'MLP'}, 'epochs': {'value': 15}}}
# Traceback (most recent call last):
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_config.py", line 165, in __getattr__
#     return self.__getitem__(key)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_config.py", line 130, in __getitem__
#     return self._items[key]
#            ~~~~~~~~~~~^^^^^
# KeyError: 'model_type'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1664/24027547.py", line 6, in model_pipeline
#     model, optimizer, loss_fn = get_model(config)
#                                 ^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1664/1209392619.py", line 3, in get_model
#     if config.model_type == "MLP":
#        ^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_config.py", line 167, in __getattr__
#     raise AttributeError(
# AttributeError: <class 'wandb.sdk.wandb_config.Config'> object has no attribute 'model_type'
#  View run <strong style="color:#cdcd00">brisk-sunset-54</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/c9kr3t2v' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/c9kr3t2v</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260119_134730-c9kr3t2v/logs</code>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_config.py:165, in Config.__getattr__(self, key)
#     164 try:
# --> 165     return self.__getitem__(key)
#     166 except KeyError as ke:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_config.py:130, in Config.__getitem__(self, key)
#     129 def __getitem__(self, key):
# --> 130     return self._items[key]
#
# KeyError: 'model_type'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 wandb.agent(sweep_id, model_pipeline("MLP", sweep_config), count=10)
#
# Cell In[38], line 6, in model_pipeline(name, config)
#       3 with wandb.init(project=WANDB_PROJECT, config=config):
#       4     config = wandb.config
# ----> 6     model, optimizer, loss_fn = get_model(config)
#       8     run_training_loop(name, model, config, optimizer, loss_fn, extern_train_loader, extern_val_loader, extern_test_loader, extern_full_dataset)
#
# Cell In[32], line 3, in get_model(config)
#       1 def get_model(config):
#       2     print(config)
# ----> 3     if config.model_type == "MLP":
#       4         model = MLP(config)
#       5         optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_config.py:167, in Config.__getattr__(self, key)
#     165     return self.__getitem__(key)
#     166 except KeyError as ke:
# --> 167     raise AttributeError(
#     168         f"{self.__class__!r} object has no attribute {key!r}"
#     169     ) from ke
#
# AttributeError: <class 'wandb.sdk.wandb_config.Config'> object has no attribute 'model_type'

# %%
wandb.teardown()

# %% [markdown]
# ### Quellen <a id="quellen"></a>
#
# [1] ALBA und Civey, "Gut gemeint: Große Mehrheit trennt den Müll und schadet dennoch dem Klima", Pressemitteilung, 20.07.2022. (Online). Verfügbar: https://www.alba.info/unternehmen/newsroom/pressemitteilungen/detail/gut-gemeint-grosse-mehrheit-trennt-den-muell-und-schadet-dennoch-dem-klima/. (Zugriff: 10.01.2026).
#
# [2] L. Löwe, "Alles durcheinander: Die Unlust beim Mülltrennen", FR.de, 10.01.2019. (Online). Verfügbar: https://www.fr.de/ratgeber/wohnen/alles-durcheinander-unlust-beim-muelltrennen-11106084.html. (Zugriff: 15.01.2026).
