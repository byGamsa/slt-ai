# %% [markdown]
# # Image Classifier zur automatisierten Müllklassifizierung und Trennhilfe
#
# **Modul:** Selected Topics of AI <br>
# **Professor:** Prof. Dr. Johannes Maucher <br>
# **Bearbeitet von:** Lars Gerigk (lg107), Julia Ebert (je073), Joel Starkov (js486) <br>
# **Abgabe:** 28.01.2026 <br>

# %% [markdown]
# ## Inhaltsverzeichnis
#
# 1. Problemstellung & Zielsetzung<br>
#
#     1.1. Motivation & Problemanalyse <br>
#     1.2. Ziel <br>
#     1.3. Abgrenzung der Müllkategorien <br>
#
# 2. Installation & Setup <br>
#
#     2.1. Installation (otional) <br>
#     2.2. Imports<br>
#     2.3. Globale Konfigurationen & Utils<br>
#         2.3.1. Reproduzierbarkeit<br>
#         2.3.2. Device-Konfiguration <br>
#         2.3.3. Zentrale Hyperparameter Konfiguration <br>
#
# 10. Quellen
#
# <br>
#
# ---

# %% [markdown]
# ### 1. Problemstellung & Zielsetzung
# #### 1.1. Motivation & Problemanalyse <a id="motivation"></a>
#
# Die korrekte Trennung von Abfällen stellt für viele eine Herausforderung dar. Eine Umfrage von ALBA und Civey aus dem Jahr 2022 zeigt, dass nur 3,8% der Befragten Teilnehmer aus einer Stichprobengröße von 2.502 Menschen ihren Müll nicht trennen. Besonders hervorsticht, dass über 90% der Befragten, darauf achten Papier und Pappe vom Restmüll zu trennen. 87,3 % der Befragten trennen ihre Plastik(-verpackungen) vom Restmüll und 83,8 % trennen ihr Altglas vom Restmüll. Mit 64,4 % Müll trennen die Befragten am wenigsten von Biomüll und Restmüll. Diese Ergebnisse hören sich zunächst vielversprechend an. Allerdings täsuchen diese Ergebnisse, so der ALBA-Chef Eric Schweitzer. Eine Studie des Umweltbundesamtes zeigt auf, dass zwei Drittel des Inhalts der Restmülltonne, getrennt gesammelt und recycelt werden könnte. Zudem sagt Schweitzer aus, dass "Fehlerwürfe" von bis zu 30 Prozent keine Seltenheit ist. Somit werden Ressourcen folglich verbrannt, die die Gesamtkosten für Energie und die Produktion neuer Rohstoffe steigen für die Gesellschaft [1].
#
# Fehlwürfe in der Mülltrennung lassen sich unter anderem auf ein fehlendes grundlegendes Verständnis des Abfalltrennungssystems sowie auf eine unzureichende und nicht einheitliche Aufklärung zurückführen. Die bestehenden Trennregeln sind teilweise komplex und unterscheiden sich je nach Region, was die korrekte Zuordnung einzelner Abfallarten erschwert. Durch die entstandenen Unsicherheiten führen in der Praxis zu erhöhten Fehlwürfen und beeinträchtigen die Effizienz von Recyclingprozessen [2].
#
# Im Folgenden wird ein Anwendungsbeispiel für den Einsatz eines bildbasierten Klassifikationssystems an der Hochschule der Medien (kurz: HdM) vorgestellt. Ziel ist es, die Mülltrennung und damit die Recyclingqualität auf dem Campus zu verbessern. Zu diesem Zweck wird ein Image Classifier entwickelt, der anhand eines aufgenommenen Bildes eines Abfallobjekts dessen Kategorie erkennt und den Nutzer bei der korrekten Entsorgung unterstützt.
#
# Ein möglicher Ausblick besteht darin, Abfallbehälter mit einer integrierten Kamera sowie einem visuellen und auditiven Rückmeldesystem auszustatten. Nach der automatischen Klassifikation gibt das System an der jeweiligen Einwurföffnung ein Signal aus, das anzeigt, in welchen Behälter der Abfall entsorgt werden soll. Durch die Kombination aus visueller und auditiver Rückmeldung kann die Bedienung vereinfacht und gleichzeitig sprachliche sowie visuelle Barrieren reduziert werden. Auf diese Weise könnte das System dazu beitragen, Fehlwürfe zu verringern und die Mülltrennung im Hochschulalltag nachhaltig zu verbessern.

# %% [markdown]
# ### 1.2. Ziel
#
# Ziel dieses Projekts ist die Entwicklung eines Image Classifiers zur automatisierten Erkennung und Zuordnung von Abfallobjekten. Hierfür werden parallel zu den in der Vorlesung behandelten Konzepten und Modellen geeignete Architekturen ausgewählt, implementiert und an die Anforderungen des vorliegenden Anwendungsfalls angepasst. Die entwickelten Modelle werden trainiert, validiert und hinsichtlich ihrer Leistungsfähigkeit systematisch untersucht.
#
# Zur Bewertung der Modellgüte werden etablierte Metriken wie Accuracy, Precision, Recall und F1 Score herangezogen. Die Ergebnisse der einzelnen Modellvarianten werden anschließend miteinander verglichen, um den Einfluss unterschiedlicher Architekturen, Trainingsstrategien und Hyperparameter auf die Klassifikationsleistung zu analysieren. Auf diese Weise soll ein Modell identifiziert werden, das für die automatisierte Müllklassifikation eine hohe Erkennungsleistung sowie eine robuste Generalisierungsfähigkeit aufweist.
#
# Ziel der Vorgehensweise ist es, durch strukturierte Umsetzung, fundierte Evaluation und gezielte Anpassung der Modellarchitektur ein Klassifikationsmodell zu entwickeln, das einen Beitrag zur Reduktion von Fehlwürfen in der Mülltrennung leisten kann.

# %% [markdown]
# ### 1.3. Abgrenzung der Müllkategorien
#
# <b>Hinweis:</b> Wir wollen uns bewusst auf den typischen Müll beschränken, der im Alltag an der Hochschule der Medien anfällt. Daher beziehen wir bei der Klassifikation an der HdM vorhandenen Entsorgungsmöglichkeiten.
#
# <b>Unser Modell klassifiziert erkannte Objekte in eine der folgenden fünf Kategorien:</b>
#
# <table style="width:100%; border-collapse: collapse; margin-right:20px;">
#   <tr>
#     <th>Kategorie</th>
#     <th>Beschreibung</th>
#   </tr>
#
#   <tr>
#     <td>Pfand</td>
#     <td>
#       Diese Kategorie umfasst pfandpflichtige Getränkeverpackungen. Dazu zählen insbesondere:
#       <ul>
#         <li>Einweg Plastikflaschen</li>
#         <li>Sowohl mit als auch ohne sichtbare Pfandkennzeichnung</li>
#         <li>Auf Grund begrenzter Verfügbarkeit geeigneter Trainingsdaten werden zusätzlich Bilder aus Ländern ohne Pfandsystem verwendet</li>
#         <li>Getränkedosen</li>
#       </ul>
#       Glasflaschen werden bewusst nicht dieser Kategorie zugeordnet, obwohl sie ebenfalls pfandpflichtig sein können.
#       Der Grund hierfür liegt darin, dass Glasflaschen an der Hochschule der Medien nicht über den klassischen Pfandbehälter entsorgt werden.
#     </td>
#   </tr>
#
#   <tr>
#     <td>Restmüll</td>
#     <td>
#       In diese Kategorie fallen Abfälle, die weder recycelbar sind noch einer anderen Kategorie eindeutig zugeordnet werden können. Beispiele sind:
#       <ul>
#         <li>Stark verschmutzte oder beschichtete Materialien</li>
#         <li>Essensreste</li>
#         <li>Nicht trennbare Verbundmaterialien</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Papier</td>
#     <td>
#       Diese Kategorie umfasst saubere und trockene Papierprodukte, die für das Recycling geeignet sind. Dazu gehören:
#       <ul>
#         <li>Papierblätter und Hefte</li>
#         <li>Kartonverpackungen ohne starke Verschmutzung</li>
#         <li>Papiertüten</li>
#       </ul>
#       Nicht enthalten sind beschichtete oder stark verschmutzte Papiermaterialien, da diese nicht dem Papierrecycling zugeführt werden können.
#     </td>
#   </tr>
#
#   <tr>
#     <td>Verpackungen</td>
#     <td>
#       Diese Kategorie beinhaltet recycelbare Verpackungsmaterialien, zum Beispiel:
#       <ul>
#         <li>Kunststoffverpackungen von Lebensmitteln</li>
#         <li>Joghurtbecher, Folien und Plastikschalen</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Sonstiges</td>
#     <td>
#       Für diese Kategorie sind alle Objekte vorgesehen, die nicht zu den oben genannten Müllarten gehören oder an der Hochschule der Medien nicht im regulären Müll entsorgt werden dürfen.
#       <ul>
#         <li>Batterien und Elektroschrott</li>
#         <li>Glasflaschen</li>
#         <li>Gegenstände, die kein Müll sind, zum Beispiel Taschen, Bücher oder Technik</li>
#       </ul>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### 2. Installation & Setup

# %% [markdown]
# #### 2.1. Installation (optional)
#
# Bevor der eigentliche Code ausgeführt wird, müssen alle notwendigen Dependecies installiert werden, die für das Laden der Daten, deren Analyse sowie das Training und die Auswertung der Modelle erforderlich sind. Sofern die genannten Pakete noch nicht installiert sind, können sie direkt innerhalb dieses Notebooks installiert werden. Für eine lokale Ausführung wird empfohlen, die Abhängigkeiten über eine Conda-Umgebung zu verwalten.

# %%
# %pip install numpy
# %pip install scipy
# %pip install matplotlib
# %pip install pandas
# %pip install scikit-learn
# %pip install torch
# %pip install torchvision
# %pip install wandb
# %pip install torchsummary
# %pip install seaborn
# Out:
# Requirement already satisfied: numpy in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scipy) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (2.9.1)
# Requirement already satisfied: filelock in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchvision in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (0.24.1)
# Requirement already satisfied: numpy in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: torch==2.9.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torchvision) (2.9.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: filelock in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (2025.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from torch==2.9.1->torchvision) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from sympy>=1.13.3->torch==2.9.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from jinja2->torch==2.9.1->torchvision) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wandb in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (0.23.1)
# Requirement already satisfied: click>=8.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (3.1.46)
# Requirement already satisfied: packaging in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (6.33.4)
# Requirement already satisfied: pydantic<3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (2.12.5)
# Requirement already satisfied: pyyaml in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (2.49.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2025.11.12)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchsummary in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 2.2. Imports
#
# In diesem Abschnitt werden alle grundlegenden Abhängigkeiten für die nachfolgenden Abschnitte zentral definiert und importiert.

# %%
import numpy as np
import scipy.io as io
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader, ConcatDataset


from torchvision import datasets, models, transforms
from torchsummary import summary

import wandb 
import itertools

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# #### 2.3. Globale Konfiguration & Utils
#
# In diesem Abschnitt werden zentrale Konfigurationsparameter sowie wiederverwendbare Hilfsfunktionen definiert, welche in den nachfolgenden Kapiteln verwendet werden.
#
# ##### 2.3.1 Reproduzierbarkeit
#
# Um verschiedene Ergebnisse zwischen unterschiedlichen Durchläufen zu verhindern und eine faire Vergleichbarkeit der untersuchten Modelle zu gewährleisten, werden alle relevanten Zufallsgeneratoren explizit bestimmt.

# %%
def set_seed(seed=23):
    np.random.seed(seed)
    torch.manual_seed(seed) 
    torch.cuda.manual_seed_all(seed)
    
    print(f"Random seed set to: {seed}")
    return torch.Generator().manual_seed(seed)

# %%
set_seed(23)
# Out:
# Random seed set to: 23

# %% [markdown]
# ##### 2.3.2. Device-Konfiguration
#
# Die ermittelte Rechenumgebung wird zentral gespeichert und in allen Trainings- und Evaltuationsschritten verwendet.

# %%
def get_device():
    if torch.cuda.is_available():
        device = "cuda"
    elif torch.backends.mps.is_available():
        device = "mps"
    else:
        device = "cpu"
        
    print(f"Using device: {device}")
    return device

# %% [markdown]
# ##### 2.3.3. Zentrale Hyperparameter Konfiguration

# %% [markdown]
# Zur systematischen Protokollierung von allen Experimenten, Hyperparametern und Ergebnissen wird in diesem Projekt das Tool Weights & Biases (kurz: wandb) eingesetzt.
# <br>
# Für eine flexible Nutzung wird zwischen Online- und Offline Mode unterschieden um die Nutzung des Notebooks auch ohne Internetzugang zu ermöglichen.

# %%
USE_WANDB = True

WANDB_PROJECT = "Müll Klassifikation"

if USE_WANDB:
    wandb.login()
    print("Logged in to Weights & Biases")
else:
    print("Weights & Biases logging is disabled")
# Out:
# wandb: Currently logged in as: joel-starkov (sltai) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Logged in to Weights & Biases

# %% [markdown]
# ##### 2.3.4. Allgemeine Konfigurationen

# %%
image_size = 32
num_workers = 2
channel = 3
extern_file_path = "./extern-data"
custom_file_path = "./custom-data"
all_file_path = "./all-data"

train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

seed = 23
generator = set_seed(seed)
device = get_device()
# Out:
# Random seed set to: 23
# Using device: cuda

# %% [markdown]
# ##### 2.3.5. Konfigurationen der Modelarchitekturen

# %% [markdown]
# Konfiguration für das **MLP**:

# %%
config_mlp = dict(
    model_type = 'MLP',
    batch_size = 16,
    learning_rate = 0.1,
    epochs = 15,
    hidden_dim = 512,
    dropout = 0.2
)

# %% [markdown]
# Konfiguration für das **CNN**:

# %%
config_cnn = dict(
    model_type = 'CNN',
    batch_size = 16,
    learning_rate = 0.01,
    epochs = 30,
    hidden_dim_1 = 1024, 
    dropout = 0.2
)

# %% [markdown]
# Konfiguration für das **Transfer Learning**:

# %%
config_transfer_vgg = {
    "scratch": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_FROM_SCRATCH',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "pretrained": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_PRETRAINED',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "finetune": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_FINETUNE',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    )
}

# %%
config_transfer_rn = {
    "scratch": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_FROM_SCRATCH',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "pretrained": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_PRETRAINED',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "finetune": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_FINETUNE',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    )
}

# %% [markdown]
# ### 3. Datenerfassung & Aufbereitung
#
# In diesem Kapitel wird beschrieben, wie die für das Projekt verwendeten Bilddaten erhoben, organisiert und für die weitere Verarbeitung vorbereitet wurden.
#
# #### 3.1. Herkunft der Datensätze
#
# Um ein robustes und verallgemeinerungsfähiges Modell zu trainieren, ist eine ausreichend große und qualitativ hochwertige Datenbasis erforderlich. Für die Beschaffung öffentlich zugänglicher Trainingsdaten wurde die Online Plattform Kaggle genutzt, welche eine Vielzahl kuratierter Datensätze bereitstellt.
#
# #### 3.1.1. Externer Datensatz
#
# Zu Beginn haben wir uns dafür entschieden mit dem Datenset **"Garbage Classification"** von Mostafa Mohamed der Plattform Kaggle zu arbeiten. Jedoch zeigte sich schnell, dass die Klassenverteilung sehr unsausgeglichen war. Einige Kategorien waren so deutlich überpräsentiert, während andere nur sehr wenige Bilder enthielten, so dass unsere Modelle kaum bis garkeine Verbesserung der Accuracy in allen Durchläufen zeigten.
# <br>
# Um dieser Problematik entgegenzuwirken und eine bessere Grundlage für das Modelltraining zu schaffen, haben wir zusätzlich weitere Datensätze hinzugezogen.
#
# #### Die verwendeten Datensätze im Überblick:
#
# <table style="width:100%; border-collapse: collapse; margin-right:20px;">
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Quelle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Restmüll, Papier</td>
#       <td>
#         M. Abla, <i>Garbage Classification (12 classes)</i>, Kaggle dataset, 2020.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/mostafaabla/garbage-classification.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Pfandflaschen</td>
#       <td>
#         S. Kumar Sah, <i>Plastic Bottles Image Dataset</i>, Kaggle dataset, 2021.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/siddharthkumarsah/plastic-bottles-image-dataset.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Kaffeebecher</td>
#       <td>
#         V. Lanz, <i>Plastic and Paper Cups Synthetic Image Dataset</i>, Kaggle dataset, 2021.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/vencerlanz09/plastic-and-paper-cups-synthetic-image-dataset.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Plastik</td>
#       <td>
#         H. Kandoi, <i>Dataset for Visual Plastic Type Recognition</i>, Kaggle dataset, 2024.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/harshitkandoi7850/dataset-for-visual-plastic-type-recognition.<br>
#         Zugriff: 20.12.2025.<br><br>
#         N. Bagga, <i>Plastic Images</i>, Kaggle dataset, 2023.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/nandinibagga/plastic-images.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Dosen</td>
#       <td>
#         T. Yasser, <i>Drinks Cans</i>, Kaggle dataset, 2023.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/tarekyasser63/drinks-cans.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# #### 3.1.2. Eigener Datensatz
#
# Ergänzend zu dem externen Datensatz wurde ein eigener Bilddatensatz erstellt, um die Trainingsdaten gezielt zu erweitern und an die spezifische Aufgabenstellung anzupassen. Hierfür wurden pro Kategorie etwa 200 eigene Bilder aufgenommen und in ein eigenes Datenset integriert.
#
# Die aufgenommenen Bilder wurden bewusst nicht unter idealisierten Bedingungen erstellt. Stattdessen wurde darauf geachtet, verschiedene Lichtverhältnisse, unterschiedliche Hintergrundstrukturen sowie teilweise Hände oder andere Objekte im Bild zuzulassen. Ziel dieser Vorgehensweise war es, ein möglichst realitätsnahes und vielfältiges Datenset zu erzeugen.
#
# Durch diese gezielte Variation lernt das Modell nicht nur idealisierte Beispielbilder, sondern wird bereits während des Trainings mit komplexeren und störbehafteten Szenen konfrontiert. Dies fördert die Robustheit des Modells gegenüber realen Einsatzbedingungen und verbessert seine Fähigkeit zur Generalisierung auf bisher unbekannte Bilder.
#
# #### 3.2. Zusammenführung und manuelle Strukturierung
#
# Ein besonderer Aufwand entstand bei der Verarbeitung plastikbezogener Daten. Da die meisten öffentlichen Datensätze dazu nicht aus Deutschland stammen und das Konzept von Pfandflaschen dort nicht existiert. <br> Daher mussten wir diese Bilder manuell durchsuchen und Plastikflaschen in eine eigene Kategorie Pfand einordnen, um alles optimal an unser Anwendungsszenario der HDM anzupassen.
# <br>
# Auch bei den den restlichen Datensätzen war eine manuelle Überprüfung notwendig, da viele Bilder für unser Szenario ungeignet waren, da sie nicht dem praktischen Anwendungsfall "Müll wird vor eine Kamera gehalten" entsprachen. Beispielsweise gab es Aufnahmen von Landstraßen, an deren Rändern Plastik in Gräben liegt oder Bilder von verstreutem Müll in Sträuchern und am Meer. Solche Bilder wurden konsequent aussortiert.
# <br><br>
# Nach dem Download der Datensätze wurden die Bilddaten manuell zusammengeführt und in eine einheitliche Ordnerstruktur überführt. Dabei wurde darauf geachtet, dass jede Klasse eine ähnliche Anzahl an Bildern enthält. Ziel war es, pro Kategorie etwa 2000 Bilder zu verwenden um eine gleichmäßige Klassenverteilung zu erreichen und damit optimale Voraussetzungen für das Training der Modelle zu schaffen.
#
# #### 3.3. Datensetanalyse
#
# !!!!
#
# #### 3.4. Ausgangsstruktur der Daten
#
# Wenn die Datensätze bereits vorab manuell in separate Trainings-, Validierungs- und Testordner aufgeteilt werden, entsteht ein höherer organisatorischer Aufwand und ein erhöhtes Risiko für inkonsistente Datenstrukturen. Stattdessen wurden in diesem Projekt alle Bilder in einer einheitlichen Verzeichnisstruktur abgelegt, bei der jede Klasse als eigenes Unterverzeichnis vorliegt. Die eigentliche Aufteilung in Trainings, Validierungs und Testdaten erfolgt in diesem Jupyter Notebook.
#
# Zweitens ermöglicht die programmatische Aufteilung eine flexible Anpassung der Splitverhältnisse, ohne dass Dateien manuell verschoben oder dupliziert werden müssen. Drittens wird die Reproduzierbarkeit verbessert, da die Datenteilung durch einen festen Zufallsseed exakt wiederholbar durchgeführt werden kann.
#
# Im folgenden ist die Datenstruktur zu erkennen:
#
# Externer Bilddatensatz (Kaggle)
#
# ```
# extern-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```
#
#
# Eigener Bilddatensatz (selbst erhoben)
#
# ```
# custom-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```

# %% [markdown]
# ### 3.4. Datenaufbereitung
# #### 3.4.1. Import der Bilder

# %%
def load_data(file_path):
    full_dataset = datasets.ImageFolder(
        root=file_path
    )
    return full_dataset

# %%
def build_transforms(image_size):
    data_transforms = {
        'train': transforms.Compose([
            transforms.Resize(image_size),
            transforms.CenterCrop(image_size),
            transforms.RandomRotation(degrees=(0, 360)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ToTensor(),
        ]),
        'val': transforms.Compose([
            transforms.Resize(image_size),
            transforms.CenterCrop(image_size),
            transforms.ToTensor(),
        ]),
        'test': transforms.Compose([
            transforms.Resize(image_size),
            transforms.CenterCrop(image_size),
            transforms.ToTensor(),
        ])
    }
    return data_transforms

# %%
def split_indices(dataset, train_ratio, val_ratio):
    total_size = len(dataset)
    
    train_size = int(train_ratio * total_size)
    val_size = int(val_ratio * total_size)
    test_size = total_size - train_size - val_size
    
    train_indices, val_indices, test_indices = random_split(
        range(total_size),
        [train_size, val_size, test_size],
        generator=generator
    )
    
    return train_indices, val_indices, test_indices

# %%
def build_dataset(file_path, data_transforms, train_indices, val_indices, test_indices):
    train_dataset_base = datasets.ImageFolder(
        root=file_path,
        transform=data_transforms['train']
    )

    val_dataset_base = datasets.ImageFolder(
        root=file_path,
        transform=data_transforms['val']
    )

    test_dataset_base = datasets.ImageFolder(
        root=file_path,
        transform=data_transforms['test']
    )

    train_dataset = torch.utils.data.Subset(
        train_dataset_base,
        train_indices
    )

    val_dataset = torch.utils.data.Subset(
        val_dataset_base,
        val_indices
    )

    test_dataset = torch.utils.data.Subset(
        test_dataset_base,
        test_indices
    )   

    return train_dataset, val_dataset, test_dataset

# %%
def build_dataloaders(train_dataset, val_dataset, test_dataset, batch_size, num_workers):
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    return train_loader, val_loader, test_loader

# %%
def count_classes(dataset):
    img_classes = {}
    class_names = dataset.classes

    for _, label in dataset:
        class_name = class_names[int(label)]

        if class_name not in img_classes:
            img_classes[class_name] = 0

        img_classes[class_name] += 1

    return img_classes

# %%
def prepare_data(file_path):
    full_dataset = load_data(file_path)
    class_count = len(full_dataset.classes)
    image_count = len(full_dataset)
    image_classes = count_classes(full_dataset)

    print("\n=== Datensatzübersicht ===")
    print(f"Anzahl Bilder gesamt: {image_count}")
    print(f"Anzahl Klassen: {class_count}")
    print(f"Klassen: {full_dataset.classes}")

    print("\nKlassenverteilung (gesamt):")
    for cls, cnt in image_classes.items():
        print(f"  {cls:<20}: {cnt}")

    data_transforms = build_transforms(image_size)

    train_indices, val_indices, test_indices = split_indices(
        full_dataset,
        train_ratio,
        val_ratio
    )

    train_dataset, val_dataset, test_dataset = build_dataset(
        file_path,
        data_transforms,
        train_indices,
        val_indices,
        test_indices
    )

    train_loader, val_loader, test_loader = build_dataloaders(
        train_dataset,
        val_dataset,
        test_dataset,
        config_mlp['batch_size'],
        num_workers
    )

    return full_dataset, train_loader, val_loader, test_loader, class_count, image_classes

extern_full_dataset, extern_train_loader, extern_val_loader, extern_test_loader, extern_class_count, extern_image_classes = prepare_data(extern_file_path)

images, labels = next(iter(extern_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {images.shape[0]}")
print(f"Bildform          : {tuple(images.shape[1:])}")
print(f"Label-Beispiel    : {labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 10391
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 2145
#   paper               : 1941
#   residual waste      : 2291
#   returnable bottle   : 2013
#   unauthorized waste  : 2001
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [4, 0, 0, 3, 2, 2, 3, 2, 2, 3, 2, 2, 0, 0, 4, 2]

# %%
custom_full_dataset, custom_train_loader, custom_val_loader, custom_test_loader, custom_class_count, custom_image_classes = prepare_data(custom_file_path)

custom_images, custom_labels = next(iter(custom_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {custom_images.shape[0]}")
print(f"Bildform          : {tuple(custom_images.shape[1:])}")
print(f"Label-Beispiel    : {custom_labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 1196
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 237
#   paper               : 247
#   residual waste      : 222
#   returnable bottle   : 244
#   unauthorized waste  : 246
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [3, 1, 0, 2, 0, 2, 0, 0, 3, 2, 4, 1, 2, 1, 0, 2]

# %%
all_full_dataset, all_train_loader, all_val_loader, all_test_loader, all_class_count, all_image_classes = prepare_data(all_file_path)

all_images, all_labels = next(iter(all_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {all_images.shape[0]}")
print(f"Bildform          : {tuple(all_images.shape[1:])}")
print(f"Label-Beispiel    : {all_labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 11587
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 2382
#   paper               : 2188
#   residual waste      : 2513
#   returnable bottle   : 2257
#   unauthorized waste  : 2247
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [3, 0, 0, 3, 4, 0, 2, 2, 4, 3, 1, 3, 2, 0, 1, 1]

# %%
def count_classes_subset(subset, class_names):
    counts = {name: 0 for name in class_names}
    for idx in subset.indices:
        _, label = subset.dataset.samples[idx]
        counts[class_names[label]] += 1
    return counts

# %%
def print_class_distribution(img_classes, title, xlabel, ylabel):
    plt.figure(figsize=(10,5))
    plt.bar(img_classes.keys(), img_classes.values())
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# --- Train ---
train_dist = count_classes_subset(extern_train_loader.dataset, extern_full_dataset.classes)
print_class_distribution(
    train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
val_dist = count_classes_subset(extern_val_loader.dataset, extern_full_dataset.classes)
print_class_distribution(
    val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Test ---
test_dist = count_classes_subset(extern_test_loader.dataset, extern_full_dataset.classes)
print_class_distribution(
    test_dist,
    title="Klassenverteilung - Test",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %%
# --- Train ---
custom_train_dist = count_classes_subset(custom_train_loader.dataset, custom_full_dataset.classes)
print_class_distribution(
    custom_train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
custom_val_dist = count_classes_subset(custom_val_loader.dataset, custom_full_dataset.classes)
print_class_distribution(
    custom_val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Test ---
custom_test_dist = count_classes_subset(custom_test_loader.dataset, custom_full_dataset.classes)
print_class_distribution(
    custom_test_dist,
    title="Klassenverteilung - Test",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %%
def show_random_samples(dataset): 
    figure = plt.figure(figsize=(10, 10))
    cols, rows = 6, 1
    class_names = extern_full_dataset.classes  

    for i in range(1, rows * cols + 1):
        sample_idx = torch.randint(len(dataset), size=(1,)).item()
        img, label = dataset[sample_idx]

        img = img.permute(1, 2, 0)
        class_name = class_names[int(label)]

        figure.add_subplot(rows, cols, i)
        plt.axis("off")
        plt.title(class_name)
        plt.imshow(img)

    plt.tight_layout()
    plt.show()

# %%
# --- Train ---
show_random_samples(extern_train_loader.dataset)

# --- Validation ---
show_random_samples(extern_val_loader.dataset)

# --- Test ---
show_random_samples(extern_test_loader.dataset)

# %%
show_random_samples(custom_train_loader.dataset)
show_random_samples(custom_val_loader.dataset)
show_random_samples(custom_test_loader.dataset)

# %% [markdown]
# ## Architekturen definieren
#
# 1. MLP
# 3. CNN - Eigenen Feature Extractor und Classifier
# 4. Komplexes CNN
# 2. Transfer Learning <br>
#     2.1. From scratch <br>
#     2.2. Pretrained<br>
#     2.3. Fine Tune <br>

# %% [markdown]
# ### Multi Layer Perceptron

# %%
class MLP(nn.Module):
    def __init__(self, config):
        super(MLP, self).__init__()
        self.d1 = nn.Linear(channel * image_size * image_size, config.hidden_dim)
        self.dropout = nn.Dropout(p=config.dropout)
        self.d2 = nn.Linear(config.hidden_dim, extern_class_count)
    
    def forward(self, x):
        x = x.flatten(start_dim = 1) #serialize 3dim input

        x = self.d1(x)
        x = torch.relu(x)
        x = self.dropout(x)

        raw_scores = self.d2(x)
        output_predictions = torch.softmax(raw_scores , dim=1)   

        return output_predictions

# %% [markdown]
# #### CNN

# %%
class CNN(nn.Module):
    def __init__(self, config):
        super(CNN, self).__init__()
        self.drop=nn.Dropout2d(config.dropout)
        self.dropfc=nn.Dropout(config.dropout)
        self.conv1 = nn.Conv2d(channel, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(512*2*2, config.hidden_dim_1)
        self.fc2 = nn.Linear(config.hidden_dim_1, extern_class_count)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.drop(self.conv1(x)))))
        x = self.pool(F.relu(self.bn2(self.drop(self.conv2(x)))))
        x = self.pool(F.relu(self.bn3(self.drop(self.conv3(x)))))
        x = self.pool(F.relu(self.bn4(self.drop(self.conv4(x)))))
        x = x.view(-1, 512*2*2)
        x = F.relu(self.dropfc(self.fc1(x)))
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Transfer Learning
#
# !!! Wir nutzen das VGG16 Model

# %%
class VGG16(nn.Module):
    def __init__(self, config):
        super(VGG16, self).__init__()
        self.config = config
        
        if config.model_subtype == "TRAIN_FROM_SCRATCH":
            self.model = models.vgg16(pretrained=False)
            for param in self.model.parameters():
                param.requires_grad = True
        elif config.model_subtype == "TRAIN_PRETRAINED":
            self.model = models.vgg16(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = False
        elif config.model_subtype == "TRAIN_FINETUNE":
            self.model = models.vgg16(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = True
        else:
            raise ValueError(f"Unknown model_subtype {config.model_subtype}")
        
        self.model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

        self.model.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, config.hidden_dim),
            nn.ReLU(),
            nn.Dropout(config.dropout),
            nn.Linear(config.hidden_dim, extern_class_count)
        )

    def forward(self, x):
        return self.model(x)

# %%
class ResNet50(nn.Module):
    def __init__(self, config):
        super(ResNet50, self).__init__()
        self.config = config
        
        if config.model_subtype == "TRAIN_FROM_SCRATCH":
            self.model = models.resnet50(pretrained=False) 
            for param in self.model.parameters():
                param.requires_grad = True

        elif config.model_subtype == "TRAIN_PRETRAINED":
            self.model = models.resnet50(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = False

        elif config.model_subtype == "TRAIN_FINETUNE":
            self.model = models.resnet50(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = True
        else:
            raise ValueError(f"Unknown model_subtype {config.model_subtype}")

        num_ftrs = self.model.fc.in_features 

        self.model.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(num_ftrs, config.hidden_dim), 
            nn.ReLU(),
            nn.Dropout(config.dropout),
            nn.Linear(config.hidden_dim, extern_class_count)
        )

    def forward(self, x):
        return self.model(x)

# %%
def get_model(config):
    print(config)
    if config.model_type == "MLP":
        model = MLP(config) 
        optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "CNN":
        model = CNN(config) 
        optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "TRANSFER_VGG":
        model = VGG16(config);  
        optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "TRANSFER_RN":
        model = ResNet50(config);  
        optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()
    else:
        raise ValueError(f"Unknown model_type {config.model_type}")
    
    model = model.to(device)
    summary(model, input_size=(channel, image_size, image_size))

    return model, optimizer, loss_fn

# %% [markdown]
# #### Trainings Funktionen

# %%
def get_accuracy(output, target, batch_size):
    prediction=torch.max(output, 1)[1].view(target.size())
    corrects = (prediction.data == target.data).sum()
    accuracy = 100.0 * corrects / batch_size
    return accuracy.item()

# %%
def train_step(model, config, optimizer, loss_fn, train_loader): 
    loss_value = 0.0
    accuracy_value = 0.0


    for i, (images, labels) in enumerate(train_loader):
        model.train()

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_value += loss.detach().item()
        accuracy_value += get_accuracy(outputs, labels, config.batch_size)

    loss_avg = loss_value / i
    accuracy_avg = accuracy_value / i

    return loss_avg, accuracy_avg

# %%
def val_step(model, config, loss_fn, val_loader):
    loss_value = 0.0
    accuracy_value = 0.0

    with torch.no_grad():
        for i, (images, labels) in enumerate(val_loader):
            model.eval()

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = loss_fn(outputs, labels)

            loss_value += loss.detach().item()
            accuracy_value += get_accuracy(outputs, labels, config.batch_size)

    loss_avg = loss_value / i
    accuracy_avg = accuracy_value / i

    return loss_avg, accuracy_avg

# %%
def print_results(num_epochs, train_accuracy, val_accuracy, model, test_loader, full_dataset):

    # print training and validation accuracy plot
    plt.figure(figsize=(12,8))
    plt.plot(range(num_epochs),train_accuracy,"r",label="training accuracy")
    plt.plot(range(num_epochs),val_accuracy,"b",label="validation accuracy")
    plt.xlabel("epoch")
    plt.grid(True)
    plt.legend()
    plt.show()

    # evaluate on validation set
    y_true = []
    y_pred = []

    model.eval()
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # print classification report 
    print(classification_report(y_true, y_pred))

    # print confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=full_dataset.classes, yticklabels=full_dataset.classes)
    plt.xlabel('Vorhergesagte Klasse (Prediction)')
    plt.ylabel('Wahre Klasse (True Label)')
    plt.title('Confusion Matrix: Was wird womit verwechselt?')
    plt.show()

# %%
def run_training_loop(name, model, config, optimizer, loss_fn, train_loader, val_loader, test_loader, full_dataset ):
    print(f"Start training for {name} with {config.epochs} epochs...") 
    
    model = model.to(device) 

    history = {
        'train_loss': [],
        'train_accuracy': [],
        'val_loss': [],
        'val_accuracy': []
    }

    for epoch in range(config.epochs):
        
        train_loss_avg, train_accuracy_avg = train_step(model, config, optimizer, loss_fn, train_loader)
        val_loss_avg, val_accuracy_avg = val_step(model, config, loss_fn, val_loader)

        history['train_loss'].append(train_loss_avg)
        history['train_accuracy'].append(train_accuracy_avg)
        history['val_loss'].append(val_loss_avg)
        history['val_accuracy'].append(val_accuracy_avg)

        print(f"Epoch [{epoch+1}/{config.epochs}], "
              f"Train Loss: {train_loss_avg:.4f}, Train Acc: {train_accuracy_avg:.2f}%, "
              f"Val Loss: {val_loss_avg:.4f}, Val Acc: {val_accuracy_avg:.2f}%")
        
        if USE_WANDB:
            wandb.log({
                "train_loss": train_loss_avg,
                "train_accuracy": train_accuracy_avg,
                "val_loss": val_loss_avg,
                "val_accuracy": val_accuracy_avg
            })
    
    print_results(config.epochs, history['train_accuracy'], history['val_accuracy'], model, test_loader, full_dataset)

# %%
def model_pipeline(name, config):
    
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, extern_train_loader, extern_val_loader, extern_test_loader, extern_full_dataset)

# %%
model_pipeline("MLP", config_mlp)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260118_230906-v978xlft</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/v978xlft' target="_blank">dark-star-37</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/v978xlft' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/v978xlft</a>
# {'model_type': 'MLP', 'batch_size': 16, 'learning_rate': 0.1, 'epochs': 15, 'hidden_dim': 512, 'dropout': 0.2}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]       1,573,376
#            Dropout-2                  [-1, 512]               0
#             Linear-3                    [-1, 5]           2,565
# ================================================================
# Total params: 1,575,941
# Trainable params: 1,575,941
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.01
# Params size (MB): 6.01
# Estimated Total Size (MB): 6.03
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5781, Train Acc: 28.29%, Val Loss: 1.5752, Val Acc: 33.83%
# Epoch [2/15], Train Loss: 1.5459, Train Acc: 32.94%, Val Loss: 1.5610, Val Acc: 32.99%
# Epoch [3/15], Train Loss: 1.5306, Train Acc: 34.68%, Val Loss: 1.5692, Val Acc: 32.35%
# Epoch [4/15], Train Loss: 1.5241, Train Acc: 36.36%, Val Loss: 1.4851, Val Acc: 42.46%
# Epoch [5/15], Train Loss: 1.5139, Train Acc: 37.16%, Val Loss: 1.5651, Val Acc: 33.96%
# Epoch [6/15], Train Loss: 1.5137, Train Acc: 37.44%, Val Loss: 1.5138, Val Acc: 37.82%
# Epoch [7/15], Train Loss: 1.5121, Train Acc: 37.43%, Val Loss: 1.4612, Val Acc: 44.39%
# Epoch [8/15], Train Loss: 1.5051, Train Acc: 38.66%, Val Loss: 1.4896, Val Acc: 42.20%
# Epoch [9/15], Train Loss: 1.5046, Train Acc: 38.63%, Val Loss: 1.5119, Val Acc: 38.27%
# Epoch [10/15], Train Loss: 1.5015, Train Acc: 38.85%, Val Loss: 1.4866, Val Acc: 42.78%
# Epoch [11/15], Train Loss: 1.4962, Train Acc: 39.18%, Val Loss: 1.4823, Val Acc: 41.49%
# Epoch [12/15], Train Loss: 1.4945, Train Acc: 39.95%, Val Loss: 1.5067, Val Acc: 38.40%
# Epoch [13/15], Train Loss: 1.4932, Train Acc: 39.72%, Val Loss: 1.4866, Val Acc: 41.30%
# Epoch [14/15], Train Loss: 1.4885, Train Acc: 40.27%, Val Loss: 1.5827, Val Acc: 31.77%
# Epoch [15/15], Train Loss: 1.4902, Train Acc: 40.24%, Val Loss: 1.5595, Val Acc: 34.73%
#               precision    recall  f1-score   support
#
#            0       0.65      0.27      0.38       335
#            1       0.22      0.87      0.35       285
#            2       0.55      0.20      0.30       368
#            3       0.57      0.13      0.21       270
#            4       0.55      0.18      0.27       302
#
#     accuracy                           0.32      1560
#    macro avg       0.51      0.33      0.30      1560
# weighted avg       0.51      0.32      0.31      1560
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▅▆▆▆▆▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▅▄▄▃▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▂▁▇▂▄█▇▅▇▆▅▆▁▃</td></tr><tr><td>val_loss</td><td>█▇▇▂▇▄▁▃▄▂▂▄▂█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>40.23954</td></tr><tr><td>train_loss</td><td>1.49023</td></tr><tr><td>val_accuracy</td><td>34.72938</td></tr><tr><td>val_loss</td><td>1.55953</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dark-star-37</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/v978xlft' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/v978xlft</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260118_230906-v978xlft/logs</code>

# %%
model_pipeline("CNN", config_cnn)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260118_231555-cgz1gj3u</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/cgz1gj3u' target="_blank">ethereal-serenity-38</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/cgz1gj3u' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/cgz1gj3u</a>
# {'model_type': 'CNN', 'batch_size': 16, 'learning_rate': 0.01, 'epochs': 30, 'hidden_dim_1': 1024, 'dropout': 0.2}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#          Dropout2d-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          Dropout2d-6          [-1, 128, 16, 16]               0
#        BatchNorm2d-7          [-1, 128, 16, 16]             256
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#             Conv2d-9            [-1, 256, 8, 8]         295,168
#         Dropout2d-10            [-1, 256, 8, 8]               0
#       BatchNorm2d-11            [-1, 256, 8, 8]             512
#         MaxPool2d-12            [-1, 256, 4, 4]               0
#            Conv2d-13            [-1, 512, 4, 4]       1,180,160
#         Dropout2d-14            [-1, 512, 4, 4]               0
#       BatchNorm2d-15            [-1, 512, 4, 4]           1,024
#         MaxPool2d-16            [-1, 512, 2, 2]               0
#            Linear-17                 [-1, 1024]       2,098,176
#           Dropout-18                 [-1, 1024]               0
#            Linear-19                    [-1, 5]           5,125
# ================================================================
# Total params: 3,656,197
# Trainable params: 3,656,197
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.06
# Params size (MB): 13.95
# Estimated Total Size (MB): 17.02
# ----------------------------------------------------------------
# Start training for CNN with 30 epochs...
# Epoch [1/30], Train Loss: 1.4629, Train Acc: 37.47%, Val Loss: 1.4039, Val Acc: 38.02%
# Epoch [2/30], Train Loss: 1.3282, Train Acc: 46.53%, Val Loss: 1.3183, Val Acc: 46.91%
# Epoch [3/30], Train Loss: 1.2619, Train Acc: 49.53%, Val Loss: 1.4012, Val Acc: 42.14%
# Epoch [4/30], Train Loss: 1.2320, Train Acc: 51.62%, Val Loss: 1.2607, Val Acc: 48.07%
# Epoch [5/30], Train Loss: 1.1996, Train Acc: 53.62%, Val Loss: 1.1772, Val Acc: 55.93%
# Epoch [6/30], Train Loss: 1.1838, Train Acc: 53.85%, Val Loss: 1.1170, Val Acc: 58.18%
# Epoch [7/30], Train Loss: 1.1644, Train Acc: 54.52%, Val Loss: 1.2520, Val Acc: 52.96%
# Epoch [8/30], Train Loss: 1.1525, Train Acc: 55.09%, Val Loss: 1.2723, Val Acc: 51.87%
# Epoch [9/30], Train Loss: 1.1383, Train Acc: 56.17%, Val Loss: 1.1803, Val Acc: 52.64%
# Epoch [10/30], Train Loss: 1.1313, Train Acc: 55.60%, Val Loss: 1.1135, Val Acc: 57.09%
# Epoch [11/30], Train Loss: 1.1155, Train Acc: 56.99%, Val Loss: 1.1287, Val Acc: 55.41%
# Epoch [12/30], Train Loss: 1.0973, Train Acc: 57.53%, Val Loss: 1.1073, Val Acc: 58.89%
# Epoch [13/30], Train Loss: 1.0964, Train Acc: 57.78%, Val Loss: 1.0797, Val Acc: 59.73%
# Epoch [14/30], Train Loss: 1.0931, Train Acc: 57.90%, Val Loss: 1.1081, Val Acc: 58.51%
# Epoch [15/30], Train Loss: 1.0814, Train Acc: 58.18%, Val Loss: 1.0987, Val Acc: 58.51%
# Epoch [16/30], Train Loss: 1.0697, Train Acc: 58.60%, Val Loss: 1.0073, Val Acc: 63.27%
# Epoch [17/30], Train Loss: 1.0594, Train Acc: 59.15%, Val Loss: 1.0075, Val Acc: 63.08%
# Epoch [18/30], Train Loss: 1.0509, Train Acc: 59.35%, Val Loss: 1.0036, Val Acc: 62.56%
# Epoch [19/30], Train Loss: 1.0545, Train Acc: 60.08%, Val Loss: 1.0424, Val Acc: 60.57%
# Epoch [20/30], Train Loss: 1.0488, Train Acc: 59.79%, Val Loss: 1.0477, Val Acc: 60.76%
# Epoch [21/30], Train Loss: 1.0226, Train Acc: 61.05%, Val Loss: 1.0460, Val Acc: 61.34%
# Epoch [22/30], Train Loss: 1.0269, Train Acc: 60.21%, Val Loss: 1.0977, Val Acc: 61.66%
# Epoch [23/30], Train Loss: 1.0218, Train Acc: 60.64%, Val Loss: 0.9914, Val Acc: 63.85%
# Epoch [24/30], Train Loss: 1.0152, Train Acc: 60.99%, Val Loss: 0.9754, Val Acc: 65.59%
# Epoch [25/30], Train Loss: 1.0212, Train Acc: 60.93%, Val Loss: 1.0567, Val Acc: 61.60%
# Epoch [26/30], Train Loss: 1.0171, Train Acc: 61.43%, Val Loss: 0.9177, Val Acc: 66.82%
# Epoch [27/30], Train Loss: 0.9899, Train Acc: 62.65%, Val Loss: 0.9543, Val Acc: 65.98%
# Epoch [28/30], Train Loss: 0.9883, Train Acc: 62.53%, Val Loss: 0.9314, Val Acc: 64.76%
# Epoch [29/30], Train Loss: 0.9805, Train Acc: 63.11%, Val Loss: 0.9949, Val Acc: 62.95%
# Epoch [30/30], Train Loss: 0.9841, Train Acc: 62.14%, Val Loss: 1.0203, Val Acc: 61.47%
#               precision    recall  f1-score   support
#
#            0       0.45      0.83      0.58       335
#            1       0.70      0.40      0.51       285
#            2       0.71      0.51      0.60       368
#            3       0.71      0.71      0.71       270
#            4       0.64      0.52      0.57       302
#
#     accuracy                           0.59      1560
#    macro avg       0.64      0.59      0.59      1560
# weighted avg       0.64      0.59      0.59      1560
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▂▃▅▆▅▄▅▆▅▆▆▆▆▇▇▇▆▇▇▇▇█▇██▇▇▇</td></tr><tr><td>val_loss</td><td>█▇█▆▅▄▆▆▅▄▄▄▃▄▄▂▂▂▃▃▃▄▂▂▃▁▂▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>62.14207</td></tr><tr><td>train_loss</td><td>0.98415</td></tr><tr><td>val_accuracy</td><td>61.46907</td></tr><tr><td>val_loss</td><td>1.02028</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-serenity-38</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/cgz1gj3u' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/cgz1gj3u</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260118_231555-cgz1gj3u/logs</code>

# %%
model_pipeline("Transfer Learning - From Scratch", config_transfer_vgg["scratch"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260118_232915-qihxvfdz</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/qihxvfdz' target="_blank">clean-bush-39</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/qihxvfdz' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/qihxvfdz</a>
# {'model_type': 'TRANSFER', 'model_subtype': 'TRAIN_FROM_SCRATCH', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - From Scratch with 30 epochs...

# %%
model_pipeline("Transfer Learning - Pretrained", config_transfer_vgg["pretrained"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260118_200955-92n0ks1l</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/92n0ks1l' target="_blank">azure-shadow-23</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/92n0ks1l' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/92n0ks1l</a>
# {'model_type': 'TRANSFER', 'model_subtype': 'TRAIN_PRETRAINED', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 66,309
# Non-trainable params: 14,714,688
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - Pretrained with 30 epochs...
# Epoch [1/30], Train Loss: 1.4722, Train Acc: 39.14%, Val Loss: 1.3784, Val Acc: 44.97%
# Epoch [2/30], Train Loss: 1.2951, Train Acc: 50.73%, Val Loss: 1.2762, Val Acc: 49.10%
# Epoch [3/30], Train Loss: 1.2274, Train Acc: 52.74%, Val Loss: 1.2553, Val Acc: 49.23%
# Epoch [4/30], Train Loss: 1.1880, Train Acc: 53.90%, Val Loss: 1.2254, Val Acc: 51.22%
# Epoch [5/30], Train Loss: 1.1823, Train Acc: 53.70%, Val Loss: 1.1915, Val Acc: 53.54%
# Epoch [6/30], Train Loss: 1.1597, Train Acc: 55.20%, Val Loss: 1.1789, Val Acc: 54.06%
# Epoch [7/30], Train Loss: 1.1304, Train Acc: 56.80%, Val Loss: 1.1626, Val Acc: 54.96%
# Epoch [8/30], Train Loss: 1.1329, Train Acc: 56.40%, Val Loss: 1.1706, Val Acc: 54.06%
# Epoch [9/30], Train Loss: 1.1160, Train Acc: 57.27%, Val Loss: 1.1542, Val Acc: 55.35%
# Epoch [10/30], Train Loss: 1.0988, Train Acc: 57.85%, Val Loss: 1.1433, Val Acc: 54.83%
# Epoch [11/30], Train Loss: 1.0999, Train Acc: 57.27%, Val Loss: 1.1347, Val Acc: 56.83%
# Epoch [12/30], Train Loss: 1.0847, Train Acc: 58.30%, Val Loss: 1.1240, Val Acc: 57.54%
# Epoch [13/30], Train Loss: 1.0825, Train Acc: 58.37%, Val Loss: 1.1319, Val Acc: 56.57%
# Epoch [14/30], Train Loss: 1.0786, Train Acc: 59.44%, Val Loss: 1.1160, Val Acc: 57.86%
# Epoch [15/30], Train Loss: 1.0673, Train Acc: 59.38%, Val Loss: 1.1069, Val Acc: 58.70%
# Epoch [16/30], Train Loss: 1.0567, Train Acc: 59.62%, Val Loss: 1.1069, Val Acc: 58.31%
# Epoch [17/30], Train Loss: 1.0645, Train Acc: 58.76%, Val Loss: 1.1111, Val Acc: 58.18%
# Epoch [18/30], Train Loss: 1.0598, Train Acc: 59.26%, Val Loss: 1.1103, Val Acc: 57.80%
# Epoch [19/30], Train Loss: 1.0432, Train Acc: 59.76%, Val Loss: 1.1079, Val Acc: 56.83%
# Epoch [20/30], Train Loss: 1.0381, Train Acc: 60.78%, Val Loss: 1.1099, Val Acc: 57.86%
# Epoch [21/30], Train Loss: 1.0368, Train Acc: 61.12%, Val Loss: 1.1023, Val Acc: 57.35%
# Epoch [22/30], Train Loss: 1.0409, Train Acc: 59.88%, Val Loss: 1.1070, Val Acc: 57.47%
# Epoch [23/30], Train Loss: 1.0278, Train Acc: 60.72%, Val Loss: 1.1001, Val Acc: 58.31%
# Epoch [24/30], Train Loss: 1.0265, Train Acc: 61.05%, Val Loss: 1.0919, Val Acc: 58.44%
# Epoch [25/30], Train Loss: 1.0228, Train Acc: 61.05%, Val Loss: 1.0944, Val Acc: 58.12%
# Epoch [26/30], Train Loss: 1.0156, Train Acc: 60.89%, Val Loss: 1.0868, Val Acc: 58.44%
# Epoch [27/30], Train Loss: 1.0171, Train Acc: 60.89%, Val Loss: 1.0919, Val Acc: 58.63%
# Epoch [28/30], Train Loss: 1.0191, Train Acc: 60.31%, Val Loss: 1.0792, Val Acc: 59.15%
# Epoch [29/30], Train Loss: 1.0065, Train Acc: 61.65%, Val Loss: 1.0727, Val Acc: 58.57%
# Epoch [30/30], Train Loss: 1.0109, Train Acc: 61.52%, Val Loss: 1.0717, Val Acc: 58.57%
#               precision    recall  f1-score   support
#
#            0       0.53      0.55      0.54       314
#            1       0.66      0.60      0.63       288
#            2       0.61      0.66      0.63       364
#            3       0.59      0.66      0.62       274
#            4       0.57      0.48      0.52       320
#
#     accuracy                           0.59      1560
#    macro avg       0.59      0.59      0.59      1560
# weighted avg       0.59      0.59      0.59      1560
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██▇████████</td></tr><tr><td>train_loss</td><td>█▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▃▄▅▅▆▅▆▆▇▇▇▇███▇▇▇▇▇██▇█████</td></tr><tr><td>val_loss</td><td>█▆▅▅▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>61.52258</td></tr><tr><td>train_loss</td><td>1.01091</td></tr><tr><td>val_accuracy</td><td>58.56959</td></tr><tr><td>val_loss</td><td>1.07171</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">azure-shadow-23</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/92n0ks1l' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/92n0ks1l</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260118_200955-92n0ks1l\logs</code>

# %%
model_pipeline("Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260118_223256-mgmrmpzt</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/mgmrmpzt' target="_blank">hopeful-darkness-34</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/mgmrmpzt' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/mgmrmpzt</a>
# {'model_type': 'TRANSFER', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - Finetune with 30 epochs...
# Epoch [1/30], Train Loss: 1.1610, Train Acc: 54.86%, Val Loss: 0.8790, Val Acc: 67.75%
# Epoch [2/30], Train Loss: 0.8608, Train Acc: 68.60%, Val Loss: 0.8355, Val Acc: 69.33%
# Epoch [3/30], Train Loss: 0.7738, Train Acc: 72.01%, Val Loss: 0.7088, Val Acc: 73.73%
# Epoch [4/30], Train Loss: 0.7164, Train Acc: 74.86%, Val Loss: 0.6035, Val Acc: 77.63%
# Epoch [5/30], Train Loss: 0.6571, Train Acc: 76.53%, Val Loss: 0.6687, Val Acc: 75.25%
# Epoch [6/30], Train Loss: 0.6146, Train Acc: 77.81%, Val Loss: 0.5400, Val Acc: 80.59%
# Traceback (most recent call last):
#   File "/tmp/ipykernel_48584/409762706.py", line 8, in model_pipeline
#     run_training_loop(name, model, config, optimizer, loss_fn, train_loader, val_loader, test_loader, full_dataset)
#   File "/tmp/ipykernel_48584/3808172084.py", line 23, in run_training_loop
#     train_loss_avg, train_accuracy_avg = train_step(model, config, optimizer, loss_fn, current_train_loader)
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_48584/3207623159.py", line 6, in train_step
#     for i, (images, labels) in enumerate(train_loader):
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 732, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1482, in _next_data
#     idx, data = self._get_data()
#                 ^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1444, in _get_data
#     success, data = self._try_get_data()
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py", line 1275, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/multiprocessing/queues.py", line 113, in get
#     if not self._poll(timeout):
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/multiprocessing/connection.py", line 440, in _poll
#     r = wait([self], timeout)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/multiprocessing/connection.py", line 948, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jstarkov/anaconda3/envs/sltai/lib/python3.11/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 8, in model_pipeline(name, config)
#       6 model, optimizer, loss_fn = get_model(config)
# ----> 8 run_training_loop(name, model, config, optimizer, loss_fn, train_loader, val_loader, test_loader, full_dataset)
#
# Cell In[66], line 23, in run_training_loop(name, model, config, optimizer, loss_fn, train_loader, val_loader, test_loader, full_dataset, train_loader2, val_loader2)
#      21 for epoch in range(config.epochs):
# ---> 23     train_loss_avg, train_accuracy_avg = train_step(model, config, optimizer, loss_fn, current_train_loader)
#      24     val_loss_avg, val_accuracy_avg = val_step(model, config, loss_fn, current_val_loader)
#
# Cell In[59], line 6, in train_step(model, config, optimizer, loss_fn, train_loader)
#       3 accuracy_value = 0.0
# ----> 6 for i, (images, labels) in enumerate(train_loader):
#       7     model.train()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1482, in _MultiProcessingDataLoaderIter._next_data(self)
#    1481 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1482 idx, data = self._get_data()
#    1483 self._tasks_outstanding -= 1
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1444, in _MultiProcessingDataLoaderIter._get_data(self)
#    1443 while True:
# -> 1444     success, data = self._try_get_data()
#    1445     if success:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1275, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1274 try:
# -> 1275     data = self._data_queue.get(timeout=timeout)
#    1276     return (True, data)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     112 timeout = deadline - time.monotonic()
# --> 113 if not self._poll(timeout):
#     114     raise Empty
#
# File ~/anaconda3/envs/sltai/lib/python3.11/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/multiprocessing/connection.py:948, in wait(object_list, timeout)
#     947 while True:
# --> 948     ready = selector.select(timeout)
#     949     if ready:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 model_pipeline("Transfer Learning - Finetune", config_transfer["finetune"])
#
# Cell In[63], line 3, in model_pipeline(name, config)
#       1 def model_pipeline(name, config):
# ----> 3     with wandb.init(project=WANDB_PROJECT, config=config):
#       4         config = wandb.config
#       6         model, optimizer, loss_fn = get_model(config)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:3642, in Run.__exit__(self, exc_type, exc_val, exc_tb)
#    3640     traceback.print_exception(exc_type, exc_val, exc_tb)
#    3641 exit_code = 1 if exception_raised else 0
# -> 3642 self._finish(exit_code=exit_code)
#    3643 return not exception_raised
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:400, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     397     run_id = self._attach_id
#     399 with wb_logging.log_to_run(run_id):
# --> 400     return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2288, in Run._finish(self, exit_code)
#    2285 assert self._wl
#    2287 logger.info(f"finishing run {self._get_path()}")
# -> 2288 with telemetry.context(run=self) as tel:
#    2289     tel.feature.finish = True
#    2291 # Run hooks that need to happen before the last messages to the
#    2292 # internal service, like Jupyter hooks.
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/telemetry.py:42, in _TelemetryObject.__exit__(self, exctype, excinst, exctb)
#      40 if not self._run:
#      41     return
# ---> 42 self._run._telemetry_callback(self._obj)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:752, in Run._telemetry_callback(self, telem_obj)
#     750 self._telemetry_obj.MergeFrom(telem_obj)
#     751 self._telemetry_obj_dirty = True
# --> 752 self._telemetry_flush()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:765, in Run._telemetry_flush(self)
#     763 if serialized == self._telemetry_obj_flushed:
#     764     return
# --> 765 self._backend.interface._publish_telemetry(self._telemetry_obj)
#     766 self._telemetry_obj_flushed = serialized
#     767 self._telemetry_obj_dirty = False
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:103, in InterfaceShared._publish_telemetry(self, telem)
#     101 def _publish_telemetry(self, telem: tpb.TelemetryRecord) -> None:
#     102     rec = self._make_record(telemetry=telem)
# --> 103     self._publish(rec)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/anaconda3/envs/sltai/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/streams.py:392, in StreamWriter.drain(self)
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
# --> 392 await self._protocol._drain_helper()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/streams.py:166, in FlowControlMixin._drain_helper(self)
#     164 async def _drain_helper(self):
#     165     if self._connection_lost:
# --> 166         raise ConnectionResetError('Connection lost')
#     167     if not self._paused:
#     168         return
#
# ConnectionResetError: Connection lost
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x732fa83dce90>> (for post_run_cell), with arguments args (<ExecutionResult object at 732fa83df8d0, execution_count=71 error_before_exec=None error_in_exec=Connection lost info=<ExecutionInfo object at 732fa83deb10, raw_cell="
# model_pipeline("Transfer Learning - Finetune", co.." transformed_cell="model_pipeline("Transfer Learning - Finetune", con.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://wsl%2Bubuntu/home/jstarkov/studium/sltai/slt-ai/M%C3%BCll_Classification_New.ipynb#Y400sdnNjb2RlLXJlbW90ZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:604, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     601     return
#     603 self._logger.info("resuming backend")
# --> 604 self.backend.interface.publish_resume()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:811, in InterfaceBase.publish_resume(self)
#     809 def publish_resume(self) -> None:
#     810     resume = pb.ResumeRequest()
# --> 811     self._publish_resume(resume)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/anaconda3/envs/sltai/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/selector_events.py:1061, in _SelectorSocketTransport.write(self, data)
#    1058 if not self._buffer:
#    1059     # Optimization: try to send now.
#    1060     try:
# -> 1061         n = self._sock.send(data)
#    1062     except (BlockingIOError, InterruptedError):
#    1063         pass
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
def custom_model_pipeline(name, config):
    
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, custom_train_loader, custom_val_loader, custom_test_loader, custom_full_dataset)

# %%
custom_model_pipeline("Custom Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260118_222248-hbpvvenh</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hbpvvenh' target="_blank">earthy-dream-32</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hbpvvenh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hbpvvenh</a>
# {'model_type': 'TRANSFER', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Custom Transfer Learning - Finetune with 30 epochs...
# Epoch [1/30], Train Loss: 1.6309, Train Acc: 23.20%, Val Loss: 1.5537, Val Acc: 32.93%
# Epoch [2/30], Train Loss: 1.5570, Train Acc: 32.09%, Val Loss: 1.5799, Val Acc: 30.29%
# Epoch [3/30], Train Loss: 1.4663, Train Acc: 40.62%, Val Loss: 1.3928, Val Acc: 45.19%
# Epoch [4/30], Train Loss: 1.3683, Train Acc: 45.55%, Val Loss: 1.3206, Val Acc: 49.52%
# Epoch [5/30], Train Loss: 1.3109, Train Acc: 49.52%, Val Loss: 1.3856, Val Acc: 46.15%
# Epoch [6/30], Train Loss: 1.2021, Train Acc: 53.73%, Val Loss: 1.0263, Val Acc: 60.58%
# Epoch [7/30], Train Loss: 1.0648, Train Acc: 61.06%, Val Loss: 1.0934, Val Acc: 59.74%
# Epoch [8/30], Train Loss: 1.0345, Train Acc: 62.86%, Val Loss: 1.0469, Val Acc: 60.70%
# Epoch [9/30], Train Loss: 0.9924, Train Acc: 63.58%, Val Loss: 0.9211, Val Acc: 65.99%
# Epoch [10/30], Train Loss: 0.9031, Train Acc: 68.15%, Val Loss: 0.7959, Val Acc: 70.91%
# Epoch [11/30], Train Loss: 0.8443, Train Acc: 68.99%, Val Loss: 0.7144, Val Acc: 73.80%
# Epoch [12/30], Train Loss: 0.8140, Train Acc: 71.88%, Val Loss: 0.7374, Val Acc: 73.56%
# Epoch [13/30], Train Loss: 0.8058, Train Acc: 70.91%, Val Loss: 0.6999, Val Acc: 76.20%
# Epoch [14/30], Train Loss: 0.7149, Train Acc: 74.28%, Val Loss: 0.6574, Val Acc: 76.68%
# Epoch [15/30], Train Loss: 0.7094, Train Acc: 73.92%, Val Loss: 0.6569, Val Acc: 76.92%
# Epoch [16/30], Train Loss: 0.6516, Train Acc: 77.76%, Val Loss: 0.6603, Val Acc: 77.16%
# Epoch [17/30], Train Loss: 0.6216, Train Acc: 77.40%, Val Loss: 0.6417, Val Acc: 76.68%
# Epoch [18/30], Train Loss: 0.5688, Train Acc: 80.41%, Val Loss: 0.5053, Val Acc: 82.57%
# Epoch [19/30], Train Loss: 0.5310, Train Acc: 82.33%, Val Loss: 0.4511, Val Acc: 84.86%
# Epoch [20/30], Train Loss: 0.4961, Train Acc: 83.89%, Val Loss: 0.4578, Val Acc: 83.89%
# Epoch [21/30], Train Loss: 0.4821, Train Acc: 84.62%, Val Loss: 0.4162, Val Acc: 85.70%
# Epoch [22/30], Train Loss: 0.4567, Train Acc: 85.34%, Val Loss: 0.3789, Val Acc: 87.74%
# Epoch [23/30], Train Loss: 0.4302, Train Acc: 85.34%, Val Loss: 0.5121, Val Acc: 82.45%
# Epoch [24/30], Train Loss: 0.4382, Train Acc: 86.30%, Val Loss: 0.3230, Val Acc: 90.50%
# Epoch [25/30], Train Loss: 0.3856, Train Acc: 87.50%, Val Loss: 0.3273, Val Acc: 88.58%
# Epoch [26/30], Train Loss: 0.3220, Train Acc: 88.70%, Val Loss: 0.3126, Val Acc: 90.14%
# Epoch [27/30], Train Loss: 0.3454, Train Acc: 88.82%, Val Loss: 0.2674, Val Acc: 90.99%
# Epoch [28/30], Train Loss: 0.3089, Train Acc: 89.42%, Val Loss: 0.2048, Val Acc: 92.67%
# Epoch [29/30], Train Loss: 0.3442, Train Acc: 89.30%, Val Loss: 0.2667, Val Acc: 91.71%
# Epoch [30/30], Train Loss: 0.3195, Train Acc: 89.42%, Val Loss: 0.2412, Val Acc: 92.55%
#               precision    recall  f1-score   support
#
#            0       0.59      0.65      0.62        40
#            1       0.66      0.59      0.62        32
#            2       0.86      0.56      0.68        32
#            3       0.74      0.79      0.77        39
#            4       0.61      0.73      0.67        37
#
#     accuracy                           0.67       180
#    macro avg       0.69      0.67      0.67       180
# weighted avg       0.69      0.67      0.67       180
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▃▃▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇█████████</td></tr><tr><td>train_loss</td><td>██▇▇▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▃▃▃▄▄▄▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇███████</td></tr><tr><td>val_loss</td><td>██▇▇▇▅▆▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>89.42308</td></tr><tr><td>train_loss</td><td>0.31952</td></tr><tr><td>val_accuracy</td><td>92.54808</td></tr><tr><td>val_loss</td><td>0.24124</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">earthy-dream-32</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hbpvvenh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/hbpvvenh</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260118_222248-hbpvvenh/logs</code>

# %% [markdown]
# ## Alle Daten

# %%
def all_model_pipeline(name, config):
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, all_train_loader, all_val_loader, all_test_loader, all_full_dataset)

# %%
all_model_pipeline("Custom Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 all_model_pipeline("Custom Transfer Learning - Finetune", config_transfer["finetune"])
#
# Cell In[41], line 2, in all_model_pipeline(name, config)
#       1 def all_model_pipeline(name, config):
# ----> 2     with wandb.init(project=WANDB_PROJECT, config=config):
#       3         config = wandb.config
#       5         model, optimizer, loss_fn = get_model(config)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:1594, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings, anonymous)
#    1591 if wl:
#    1592     wl._get_logger().exception("error in wandb.init()", exc_info=e)
# -> 1594 get_sentry().reraise(e)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/analytics/sentry.py:190, in Sentry.reraise(self, exc)
#     188 _, _, tb = sys.exc_info()
#     189 if tb is not None and hasattr(exc, "with_traceback"):
# --> 190     raise exc.with_traceback(tb)
#     191 raise exc
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:1577, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings, anonymous)
#    1574 if run_settings.x_server_side_derived_summary:
#    1575     init_telemetry.feature.server_side_derived_summary = True
# -> 1577 run = wi.init(run_settings, run_config, run_printer)
#    1579 # Set up automatic Weave integration if Weave is installed
#    1580 weave.setup(run_settings.entity, run_settings.project)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:893, in _WandbInit.init(self, settings, config, run_printer)
#     891 service = self._wl.ensure_service()
#     892 self._logger.info("sending inform_init request")
# --> 893 service.inform_init(
#     894     settings=settings.to_proto(),
#     895     run_id=settings.run_id,  # type: ignore
#     896 )
#     898 backend = Backend(settings=settings, service=service)
#     899 backend.ensure_launched()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_connection.py:221, in ServiceConnection.inform_init(self, settings, run_id)
#     219 request.settings.CopyFrom(settings)
#     220 request._info.stream_id = run_id
# --> 221 self._asyncer.run(
#     222     lambda: self._client.publish(spb.ServerRequest(inform_init=request))
#     223 )
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/anaconda3/envs/sltai/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:73, in ServiceClient._forward_responses(self)
#      71 async def _forward_responses(self) -> None:
#      72     try:
# ---> 73         while response := await self._read_server_response():
#      74             await self._mailbox.deliver(response)
#      76     except Exception:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:87, in ServiceClient._read_server_response(self)
#      85 async def _read_server_response(self) -> spb.ServerResponse | None:
#      86     try:
# ---> 87         header = await self._reader.readexactly(_HEADER_BYTE_INT_LEN)
#      88     except asyncio.IncompleteReadError as e:
#      89         if e.partial:
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/streams.py:750, in StreamReader.readexactly(self, n)
#     747         self._buffer.clear()
#     748         raise exceptions.IncompleteReadError(incomplete, n)
# --> 750     await self._wait_for_data('readexactly')
#     752 if len(self._buffer) == n:
#     753     data = bytes(self._buffer)
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/streams.py:543, in StreamReader._wait_for_data(self, func_name)
#     541 self._waiter = self._loop.create_future()
#     542 try:
# --> 543     await self._waiter
#     544 finally:
#     545     self._waiter = None
#
# File ~/anaconda3/envs/sltai/lib/python3.11/asyncio/selector_events.py:999, in _SelectorSocketTransport._read_ready__data_received(self)
#     997     return
#     998 try:
# --> 999     data = self._sock.recv(self.max_size)
#    1000 except (BlockingIOError, InterruptedError):
#    1001     return
#
# ConnectionResetError: [Errno 104] Connection reset by peer

# %%
custom_model_pipeline("Custom Data Transfer Learning with ResNet50", config_transfer_rn["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/home/jstarkov/studium/sltai/slt-ai/wandb/run-20260119_014047-n629qmx5</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/n629qmx5' target="_blank">neat-silence-44</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/n629qmx5' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/n629qmx5</a>
# {'model_type': 'TRANSFER_RN', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jstarkov/anaconda3/envs/sltai/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]           4,096
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-12            [-1, 256, 8, 8]             512
#            Conv2d-13            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-14            [-1, 256, 8, 8]             512
#              ReLU-15            [-1, 256, 8, 8]               0
#        Bottleneck-16            [-1, 256, 8, 8]               0
#            Conv2d-17             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-18             [-1, 64, 8, 8]             128
#              ReLU-19             [-1, 64, 8, 8]               0
#            Conv2d-20             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-21             [-1, 64, 8, 8]             128
#              ReLU-22             [-1, 64, 8, 8]               0
#            Conv2d-23            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-24            [-1, 256, 8, 8]             512
#              ReLU-25            [-1, 256, 8, 8]               0
#        Bottleneck-26            [-1, 256, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-28             [-1, 64, 8, 8]             128
#              ReLU-29             [-1, 64, 8, 8]               0
#            Conv2d-30             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-31             [-1, 64, 8, 8]             128
#              ReLU-32             [-1, 64, 8, 8]               0
#            Conv2d-33            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-34            [-1, 256, 8, 8]             512
#              ReLU-35            [-1, 256, 8, 8]               0
#        Bottleneck-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 128, 8, 8]          32,768
#       BatchNorm2d-38            [-1, 128, 8, 8]             256
#              ReLU-39            [-1, 128, 8, 8]               0
#            Conv2d-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#            Conv2d-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#            Conv2d-45            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-46            [-1, 512, 4, 4]           1,024
#              ReLU-47            [-1, 512, 4, 4]               0
#        Bottleneck-48            [-1, 512, 4, 4]               0
#            Conv2d-49            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#            Conv2d-52            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-53            [-1, 128, 4, 4]             256
#              ReLU-54            [-1, 128, 4, 4]               0
#            Conv2d-55            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 512, 4, 4]           1,024
#              ReLU-57            [-1, 512, 4, 4]               0
#        Bottleneck-58            [-1, 512, 4, 4]               0
#            Conv2d-59            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-60            [-1, 128, 4, 4]             256
#              ReLU-61            [-1, 128, 4, 4]               0
#            Conv2d-62            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-63            [-1, 128, 4, 4]             256
#              ReLU-64            [-1, 128, 4, 4]               0
#            Conv2d-65            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-66            [-1, 512, 4, 4]           1,024
#              ReLU-67            [-1, 512, 4, 4]               0
#        Bottleneck-68            [-1, 512, 4, 4]               0
#            Conv2d-69            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-70            [-1, 128, 4, 4]             256
#              ReLU-71            [-1, 128, 4, 4]               0
#            Conv2d-72            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-73            [-1, 128, 4, 4]             256
#              ReLU-74            [-1, 128, 4, 4]               0
#            Conv2d-75            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-76            [-1, 512, 4, 4]           1,024
#              ReLU-77            [-1, 512, 4, 4]               0
#        Bottleneck-78            [-1, 512, 4, 4]               0
#            Conv2d-79            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-80            [-1, 256, 4, 4]             512
#              ReLU-81            [-1, 256, 4, 4]               0
#            Conv2d-82            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-83            [-1, 256, 2, 2]             512
#              ReLU-84            [-1, 256, 2, 2]               0
#            Conv2d-85           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-86           [-1, 1024, 2, 2]           2,048
#            Conv2d-87           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-88           [-1, 1024, 2, 2]           2,048
#              ReLU-89           [-1, 1024, 2, 2]               0
#        Bottleneck-90           [-1, 1024, 2, 2]               0
#            Conv2d-91            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-92            [-1, 256, 2, 2]             512
#              ReLU-93            [-1, 256, 2, 2]               0
#            Conv2d-94            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#            Conv2d-97           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-98           [-1, 1024, 2, 2]           2,048
#              ReLU-99           [-1, 1024, 2, 2]               0
#       Bottleneck-100           [-1, 1024, 2, 2]               0
#           Conv2d-101            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-102            [-1, 256, 2, 2]             512
#             ReLU-103            [-1, 256, 2, 2]               0
#           Conv2d-104            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-105            [-1, 256, 2, 2]             512
#             ReLU-106            [-1, 256, 2, 2]               0
#           Conv2d-107           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-108           [-1, 1024, 2, 2]           2,048
#             ReLU-109           [-1, 1024, 2, 2]               0
#       Bottleneck-110           [-1, 1024, 2, 2]               0
#           Conv2d-111            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-112            [-1, 256, 2, 2]             512
#             ReLU-113            [-1, 256, 2, 2]               0
#           Conv2d-114            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-115            [-1, 256, 2, 2]             512
#             ReLU-116            [-1, 256, 2, 2]               0
#           Conv2d-117           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-118           [-1, 1024, 2, 2]           2,048
#             ReLU-119           [-1, 1024, 2, 2]               0
#       Bottleneck-120           [-1, 1024, 2, 2]               0
#           Conv2d-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#           Conv2d-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#           Conv2d-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
#             ReLU-129           [-1, 1024, 2, 2]               0
#       Bottleneck-130           [-1, 1024, 2, 2]               0
#           Conv2d-131            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-132            [-1, 256, 2, 2]             512
#             ReLU-133            [-1, 256, 2, 2]               0
#           Conv2d-134            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-135            [-1, 256, 2, 2]             512
#             ReLU-136            [-1, 256, 2, 2]               0
#           Conv2d-137           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-138           [-1, 1024, 2, 2]           2,048
#             ReLU-139           [-1, 1024, 2, 2]               0
#       Bottleneck-140           [-1, 1024, 2, 2]               0
#           Conv2d-141            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-142            [-1, 512, 2, 2]           1,024
#             ReLU-143            [-1, 512, 2, 2]               0
#           Conv2d-144            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-145            [-1, 512, 1, 1]           1,024
#             ReLU-146            [-1, 512, 1, 1]               0
#           Conv2d-147           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 1, 1]           4,096
#           Conv2d-149           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 1, 1]           4,096
#             ReLU-151           [-1, 2048, 1, 1]               0
#       Bottleneck-152           [-1, 2048, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-154            [-1, 512, 1, 1]           1,024
#             ReLU-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-157            [-1, 512, 1, 1]           1,024
#             ReLU-158            [-1, 512, 1, 1]               0
#           Conv2d-159           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 1, 1]           4,096
#             ReLU-161           [-1, 2048, 1, 1]               0
#       Bottleneck-162           [-1, 2048, 1, 1]               0
#           Conv2d-163            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-164            [-1, 512, 1, 1]           1,024
#             ReLU-165            [-1, 512, 1, 1]               0
#           Conv2d-166            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-167            [-1, 512, 1, 1]           1,024
#             ReLU-168            [-1, 512, 1, 1]               0
#           Conv2d-169           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 1, 1]           4,096
#             ReLU-171           [-1, 2048, 1, 1]               0
#       Bottleneck-172           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#          Flatten-174                 [-1, 2048]               0
#           Linear-175                  [-1, 128]         262,272
#             ReLU-176                  [-1, 128]               0
#          Dropout-177                  [-1, 128]               0
#           Linear-178                    [-1, 5]             645
#           ResNet-179                    [-1, 5]               0
# ================================================================
# Total params: 23,770,949
# Trainable params: 23,770,949
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.88
# Params size (MB): 90.68
# Estimated Total Size (MB): 96.57
# ----------------------------------------------------------------
# Start training for Custom Data Transfer Learning with ResNet50 with 30 epochs...
# Epoch [1/30], Train Loss: 1.6308, Train Acc: 26.44%, Val Loss: 3.1122, Val Acc: 20.45%
# Epoch [2/30], Train Loss: 1.5346, Train Acc: 35.94%, Val Loss: 2.9109, Val Acc: 31.82%
# Epoch [3/30], Train Loss: 1.4449, Train Acc: 41.83%, Val Loss: 1.3900, Val Acc: 47.73%
# Epoch [4/30], Train Loss: 1.3588, Train Acc: 44.95%, Val Loss: 1.3282, Val Acc: 52.84%
# Epoch [5/30], Train Loss: 1.3202, Train Acc: 47.36%, Val Loss: 1.3347, Val Acc: 50.57%
# Epoch [6/30], Train Loss: 1.2192, Train Acc: 52.64%, Val Loss: 1.3496, Val Acc: 48.86%
# Epoch [7/30], Train Loss: 1.2294, Train Acc: 53.37%, Val Loss: 1.2854, Val Acc: 53.41%
# Epoch [8/30], Train Loss: 1.1097, Train Acc: 59.25%, Val Loss: 1.2407, Val Acc: 55.68%
# Epoch [9/30], Train Loss: 1.0627, Train Acc: 61.78%, Val Loss: 1.2563, Val Acc: 56.25%
# Epoch [10/30], Train Loss: 1.0541, Train Acc: 61.06%, Val Loss: 1.3107, Val Acc: 58.52%
# Epoch [11/30], Train Loss: 1.0034, Train Acc: 65.02%, Val Loss: 1.1199, Val Acc: 59.66%
# Epoch [12/30], Train Loss: 0.9857, Train Acc: 63.82%, Val Loss: 1.0542, Val Acc: 61.93%
# Epoch [13/30], Train Loss: 0.9473, Train Acc: 67.43%, Val Loss: 1.1908, Val Acc: 63.07%
# Epoch [14/30], Train Loss: 0.9099, Train Acc: 67.19%, Val Loss: 1.0984, Val Acc: 61.36%
# Epoch [15/30], Train Loss: 0.9440, Train Acc: 66.47%, Val Loss: 1.0039, Val Acc: 62.50%
# Epoch [16/30], Train Loss: 0.9011, Train Acc: 67.79%, Val Loss: 1.0865, Val Acc: 60.80%
# Epoch [17/30], Train Loss: 0.8040, Train Acc: 70.91%, Val Loss: 1.0433, Val Acc: 60.23%
# Epoch [18/30], Train Loss: 0.8034, Train Acc: 70.07%, Val Loss: 0.9858, Val Acc: 67.05%
# Epoch [19/30], Train Loss: 0.8551, Train Acc: 70.79%, Val Loss: 1.1027, Val Acc: 63.64%
# Epoch [20/30], Train Loss: 0.8095, Train Acc: 70.79%, Val Loss: 1.2937, Val Acc: 56.82%
# Epoch [21/30], Train Loss: 0.7235, Train Acc: 74.28%, Val Loss: 1.4541, Val Acc: 65.34%
# Epoch [22/30], Train Loss: 0.7432, Train Acc: 74.64%, Val Loss: 1.2363, Val Acc: 67.05%
# Epoch [23/30], Train Loss: 0.6996, Train Acc: 77.04%, Val Loss: 1.4428, Val Acc: 63.64%
# Epoch [24/30], Train Loss: 0.6155, Train Acc: 79.09%, Val Loss: 1.1738, Val Acc: 60.80%
# Epoch [25/30], Train Loss: 0.6247, Train Acc: 80.17%, Val Loss: 1.0260, Val Acc: 68.18%
# Epoch [26/30], Train Loss: 0.6616, Train Acc: 78.73%, Val Loss: 1.0603, Val Acc: 64.20%
# Epoch [27/30], Train Loss: 0.6705, Train Acc: 76.80%, Val Loss: 0.9882, Val Acc: 67.05%
# Epoch [28/30], Train Loss: 0.6326, Train Acc: 80.17%, Val Loss: 1.1202, Val Acc: 66.48%
# Epoch [29/30], Train Loss: 0.5871, Train Acc: 79.69%, Val Loss: 0.9608, Val Acc: 67.05%
# Epoch [30/30], Train Loss: 0.5126, Train Acc: 82.09%, Val Loss: 0.9299, Val Acc: 69.32%
#               precision    recall  f1-score   support
#
#            0       0.81      0.65      0.72        40
#            1       0.74      0.62      0.68        32
#            2       0.62      0.66      0.64        32
#            3       0.82      0.82      0.82        39
#            4       0.60      0.78      0.68        37
#
#     accuracy                           0.71       180
#    macro avg       0.72      0.71      0.71       180
# weighted avg       0.72      0.71      0.71       180
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▃▃▄▄▄▅▅▅▆▆▆▆▆▆▇▆▇▇▇▇▇███▇███</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▅▅▅▄▄▄▄▄▃▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▆▅▅▆▆▆▆▇▇▇▇▇▇▇█▇▆▇█▇▇█▇████</td></tr><tr><td>val_loss</td><td>█▇▂▂▂▂▂▂▂▂▂▁▂▂▁▂▁▁▂▂▃▂▃▂▁▁▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>82.09135</td></tr><tr><td>train_loss</td><td>0.51264</td></tr><tr><td>val_accuracy</td><td>69.31818</td></tr><tr><td>val_loss</td><td>0.92986</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">neat-silence-44</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/n629qmx5' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/n629qmx5</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260119_014047-n629qmx5/logs</code>

# %% [markdown]
# ### Hyperparameteroptimisation

# %% [markdown]
# Sweep Konfigurationen (Hyperparameter Search-Space):

# %%
parameters_mlp = { 
    'model_type': {
        'value': 'MLP'},
    'epochs': {
        'value': 15}, 
    'batch_size': {
        'values': [16,64]},
    'learning_rate': {
        'values': [0.005,0.01]},  
    'hidden_dim': {
        'values': [32,64]}, 
    'dropout': {
        'values': [0.0,0.3]}
    }

# %%
sweep_config = {
    "method" : "random",
    "parameters" : parameters_mlp
}

# %%
sweep_id=wandb.sweep(sweep_config,project=WANDB_PROJECT)

# %%
wandb.agent(sweep_id, model_pipeline("MLP", sweep_config), count=10)

# %%
wandb.teardown()

# %% [markdown]
# ### Quellen <a id="quellen"></a>
#
# [1] ALBA und Civey, "Gut gemeint: Große Mehrheit trennt den Müll und schadet dennoch dem Klima", Pressemitteilung, 20.07.2022. (Online). Verfügbar: https://www.alba.info/unternehmen/newsroom/pressemitteilungen/detail/gut-gemeint-grosse-mehrheit-trennt-den-muell-und-schadet-dennoch-dem-klima/. (Zugriff: 10.01.2026).
#
# [2] L. Löwe, "Alles durcheinander: Die Unlust beim Mülltrennen", FR.de, 10.01.2019. (Online). Verfügbar: https://www.fr.de/ratgeber/wohnen/alles-durcheinander-unlust-beim-muelltrennen-11106084.html. (Zugriff: 15.01.2026).
