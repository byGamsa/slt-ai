# %% [markdown]
# # Image Classifier zur automatisierten Müllklassifizierung und Trennhilfe
#
# **Modul:** Selected Topics of AI <br>
# **Professor:** Prof. Dr. Johannes Maucher <br>
# **Bearbeitet von:** Lars Gerigk (lg107), Julia Ebert (je073), Joel Starkov (js486) <br>
# **Abgabe:** 28.01.2026 <br>

# %% [markdown]
# ## Inhaltsverzeichnis
#
# 1. Problemstellung & Zielsetzung<br>
#
#     1.1. Motivation & Problemanalyse <br>
#     1.2. Ziel <br>
#     1.3. Abgrenzung der Müllkategorien <br>
#
# 2. Installation & Setup <br>
#
#     2.1. Installation (otional) <br>
#     2.2. Imports<br>
#     2.3. Globale Konfigurationen & Utils<br>
#         2.3.1. Reproduzierbarkeit<br>
#         2.3.2. Device-Konfiguration <br>
#         2.3.3. Zentrale Hyperparameter Konfiguration <br>
#
# 10. Quellen
#
# <br>
#
# ---

# %% [markdown]
# ### 1. Problemstellung & Zielsetzung
# #### 1.1. Motivation & Problemanalyse <a id="motivation"></a>
#
# Die korrekte Trennung von Abfällen stellt für viele eine Herausforderung dar. Eine Umfrage von ALBA und Civey aus dem Jahr 2022 zeigt, dass nur 3,8% der Befragten Teilnehmer aus einer Stichprobengröße von 2.502 Menschen ihren Müll nicht trennen. Besonders hervorsticht, dass über 90% der Befragten, darauf achten Papier und Pappe vom Restmüll zu trennen. 87,3 % der Befragten trennen ihre Plastik(-verpackungen) vom Restmüll und 83,8 % trennen ihr Altglas vom Restmüll. Mit 64,4 % Müll trennen die Befragten am wenigsten von Biomüll und Restmüll. Diese Ergebnisse hören sich zunächst vielversprechend an. Allerdings täsuchen diese Ergebnisse, so der ALBA-Chef Eric Schweitzer. Eine Studie des Umweltbundesamtes zeigt auf, dass zwei Drittel des Inhalts der Restmülltonne, getrennt gesammelt und recycelt werden könnte. Zudem sagt Schweitzer aus, dass "Fehlerwürfe" von bis zu 30 Prozent keine Seltenheit ist. Somit werden Ressourcen folglich verbrannt, die die Gesamtkosten für Energie und die Produktion neuer Rohstoffe steigen für die Gesellschaft [1].
#
# Fehlwürfe in der Mülltrennung lassen sich unter anderem auf ein fehlendes grundlegendes Verständnis des Abfalltrennungssystems sowie auf eine unzureichende und nicht einheitliche Aufklärung zurückführen. Die bestehenden Trennregeln sind teilweise komplex und unterscheiden sich je nach Region, was die korrekte Zuordnung einzelner Abfallarten erschwert. Durch die entstandenen Unsicherheiten führen in der Praxis zu erhöhten Fehlwürfen und beeinträchtigen die Effizienz von Recyclingprozessen [2].
#
# Im Folgenden wird ein Anwendungsbeispiel für den Einsatz eines bildbasierten Klassifikationssystems an der Hochschule der Medien (kurz: HdM) vorgestellt. Ziel ist es, die Mülltrennung und damit die Recyclingqualität auf dem Campus zu verbessern. Zu diesem Zweck wird ein Image Classifier entwickelt, der anhand eines aufgenommenen Bildes eines Abfallobjekts dessen Kategorie erkennt und den Nutzer bei der korrekten Entsorgung unterstützt.
#
# Ein möglicher Ausblick besteht darin, Abfallbehälter mit einer integrierten Kamera sowie einem visuellen und auditiven Rückmeldesystem auszustatten. Nach der automatischen Klassifikation gibt das System an der jeweiligen Einwurföffnung ein Signal aus, das anzeigt, in welchen Behälter der Abfall entsorgt werden soll. Durch die Kombination aus visueller und auditiver Rückmeldung kann die Bedienung vereinfacht und gleichzeitig sprachliche sowie visuelle Barrieren reduziert werden. Auf diese Weise könnte das System dazu beitragen, Fehlwürfe zu verringern und die Mülltrennung im Hochschulalltag nachhaltig zu verbessern.

# %% [markdown]
# ### 1.2. Ziel
#
# Ziel dieses Projekts ist die Entwicklung eines Image Classifiers zur automatisierten Erkennung und Zuordnung von Abfallobjekten. Hierfür werden parallel zu den in der Vorlesung behandelten Konzepten und Modellen geeignete Architekturen ausgewählt, implementiert und an die Anforderungen des vorliegenden Anwendungsfalls angepasst. Die entwickelten Modelle werden trainiert, validiert und hinsichtlich ihrer Leistungsfähigkeit systematisch untersucht.
#
# Zur Bewertung der Modellgüte werden etablierte Metriken wie Accuracy, Precision, Recall und F1 Score herangezogen. Die Ergebnisse der einzelnen Modellvarianten werden anschließend miteinander verglichen, um den Einfluss unterschiedlicher Architekturen, Trainingsstrategien und Hyperparameter auf die Klassifikationsleistung zu analysieren. Auf diese Weise soll ein Modell identifiziert werden, das für die automatisierte Müllklassifikation eine hohe Erkennungsleistung sowie eine robuste Generalisierungsfähigkeit aufweist.
#
# Ziel der Vorgehensweise ist es, durch strukturierte Umsetzung, fundierte Evaluation und gezielte Anpassung der Modellarchitektur ein Klassifikationsmodell zu entwickeln, das einen Beitrag zur Reduktion von Fehlwürfen in der Mülltrennung leisten kann.

# %% [markdown]
# ### 1.3. Abgrenzung der Müllkategorien
#
# <b>Hinweis:</b> Wir wollen uns bewusst auf den typischen Müll beschränken, der im Alltag an der Hochschule der Medien anfällt. Daher beziehen wir bei der Klassifikation an der HdM vorhandenen Entsorgungsmöglichkeiten.
#
# <b>Unser Modell klassifiziert erkannte Objekte in eine der folgenden fünf Kategorien:</b>
#
# <table style="width:100%; border-collapse: collapse; margin-right:20px;">
#   <tr>
#     <th>Kategorie</th>
#     <th>Beschreibung</th>
#   </tr>
#
#   <tr>
#     <td>Pfand</td>
#     <td>
#       Diese Kategorie umfasst pfandpflichtige Getränkeverpackungen. Dazu zählen insbesondere:
#       <ul>
#         <li>Einweg Plastikflaschen</li>
#         <li>Sowohl mit als auch ohne sichtbare Pfandkennzeichnung</li>
#         <li>Auf Grund begrenzter Verfügbarkeit geeigneter Trainingsdaten werden zusätzlich Bilder aus Ländern ohne Pfandsystem verwendet</li>
#         <li>Getränkedosen</li>
#       </ul>
#       Glasflaschen werden bewusst nicht dieser Kategorie zugeordnet, obwohl sie ebenfalls pfandpflichtig sein können.
#       Der Grund hierfür liegt darin, dass Glasflaschen an der Hochschule der Medien nicht über den klassischen Pfandbehälter entsorgt werden.
#     </td>
#   </tr>
#
#   <tr>
#     <td>Restmüll</td>
#     <td>
#       In diese Kategorie fallen Abfälle, die weder recycelbar sind noch einer anderen Kategorie eindeutig zugeordnet werden können. Beispiele sind:
#       <ul>
#         <li>Stark verschmutzte oder beschichtete Materialien</li>
#         <li>Essensreste</li>
#         <li>Nicht trennbare Verbundmaterialien</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Papier</td>
#     <td>
#       Diese Kategorie umfasst saubere und trockene Papierprodukte, die für das Recycling geeignet sind. Dazu gehören:
#       <ul>
#         <li>Papierblätter und Hefte</li>
#         <li>Kartonverpackungen ohne starke Verschmutzung</li>
#         <li>Papiertüten</li>
#       </ul>
#       Nicht enthalten sind beschichtete oder stark verschmutzte Papiermaterialien, da diese nicht dem Papierrecycling zugeführt werden können.
#     </td>
#   </tr>
#
#   <tr>
#     <td>Verpackungen</td>
#     <td>
#       Diese Kategorie beinhaltet recycelbare Verpackungsmaterialien, zum Beispiel:
#       <ul>
#         <li>Kunststoffverpackungen von Lebensmitteln</li>
#         <li>Joghurtbecher, Folien und Plastikschalen</li>
#       </ul>
#     </td>
#   </tr>
#
#   <tr>
#     <td>Fremdmüll</td>
#     <td>
#       Für diese Kategorie sind alle Objekte vorgesehen, die nicht zu den oben genannten Müllarten gehören oder an der Hochschule der Medien nicht im regulären Müll entsorgt werden dürfen.
#       <ul>
#         <li>Batterien und Elektroschrott</li>
#         <li>Glasflaschen</li>
#         <li>Gegenstände, die kein Müll sind, zum Beispiel Taschen, Bücher oder Technik</li>
#       </ul>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### 2. Installation & Setup

# %% [markdown]
# #### 2.1. Installation (optional)
#
# Bevor der eigentliche Code ausgeführt wird, müssen alle notwendigen Dependecies installiert werden, die für das Laden der Daten, deren Analyse sowie das Training und die Auswertung der Modelle erforderlich sind. Sofern die genannten Pakete noch nicht installiert sind, können sie direkt innerhalb dieses Notebooks installiert werden. Für eine lokale Ausführung wird empfohlen, die Abhängigkeiten über eine Conda-Umgebung zu verwalten.

# %%
# %pip install numpy
# %pip install scipy
# %pip install matplotlib
# %pip install pandas
# %pip install scikit-learn
# %pip install torch
# %pip install torchvision
# %pip install wandb
# %pip install torchsummary
# %pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (1.16.0)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (2.9.1+cu128)
# Requirement already satisfied: filelock in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchvision in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (0.24.1+cu128)
# Requirement already satisfied: numpy in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.9.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torchvision) (2.9.1+cu128)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch==2.9.1->torchvision) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch==2.9.1->torchvision) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch==2.9.1->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch==2.9.1->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch==2.9.1->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch==2.9.1->torchvision) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from torch==2.9.1->torchvision) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from sympy>=1.13.3->torch==2.9.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from jinja2->torch==2.9.1->torchvision) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: wandb in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (0.23.1)
# Requirement already satisfied: click>=8.0.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (3.1.46)
# Requirement already satisfied: packaging in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (6.33.3)
# Requirement already satisfied: pydantic<3 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (2.12.5)
# Requirement already satisfied: pyyaml in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (2.49.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from requests<3,>=2.0.0->wandb) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from click>=8.0.1->wandb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchsummary in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\windows 11 pro\anaconda3\envs\torch-gpu\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 2.2. Imports
#
# In diesem Abschnitt werden alle grundlegenden Abhängigkeiten für die nachfolgenden Abschnitte zentral definiert und importiert.

# %%
import numpy as np
import scipy.io as io
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader, ConcatDataset


from torchvision import datasets, models, transforms
from torchsummary import summary

import wandb 
import itertools

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# #### 2.3. Globale Konfiguration & Utils
#
# In diesem Abschnitt werden zentrale Konfigurationsparameter sowie wiederverwendbare Hilfsfunktionen definiert, welche in den nachfolgenden Kapiteln verwendet werden.
#
# ##### 2.3.1 Reproduzierbarkeit
#
# Um verschiedene Ergebnisse zwischen unterschiedlichen Durchläufen zu verhindern und eine faire Vergleichbarkeit der untersuchten Modelle zu gewährleisten, werden alle relevanten Zufallsgeneratoren explizit bestimmt.

# %%
def set_seed(seed=23):
    np.random.seed(seed)
    torch.manual_seed(seed) 
    torch.cuda.manual_seed_all(seed)
    
    print(f"Random seed set to: {seed}")
    return torch.Generator().manual_seed(seed)

# %% [markdown]
# ##### 2.3.2. Device-Konfiguration
#
# Die ermittelte Rechenumgebung wird zentral gespeichert und in allen Trainings- und Evaltuationsschritten verwendet.

# %%
def get_device():
    if torch.cuda.is_available():
        device = "cuda"
    elif torch.backends.mps.is_available():
        device = "mps"
    else:
        device = "cpu"
        
    print(f"Using device: {device}")
    return device

# %% [markdown]
# ##### 2.3.3. Zentrale Hyperparameter Konfiguration

# %% [markdown]
# Zur systematischen Protokollierung von allen Experimenten, Hyperparametern und Ergebnissen wird in diesem Projekt das Tool Weights & Biases (kurz: wandb) eingesetzt.

# %%
WANDB_PROJECT = "Müll Klassifikation"

wandb.login()
print("Logged in to Weights & Biases")
# Out:
# wandb: Currently logged in as: gamsa (sltai) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Logged in to Weights & Biases

# %% [markdown]
# ##### 2.3.4. Allgemeine Konfigurationen

# %%
image_size = 32
num_workers = 2
channel = 3
extern_file_path = "./extern-data"
custom_file_path = "./custom-data"
all_file_path = "./all-data"

train_ratio = 0.7
seed = 23
generator = set_seed(seed)
device = get_device()
# Out:
# Random seed set to: 23
# Using device: cuda

# %% [markdown]
# ##### 2.3.5. Konfigurationen der Modelarchitekturen

# %% [markdown]
# Konfiguration für das **MLP**:

# %%
config_mlp = dict(
    model_type = 'MLP',
    batch_size = 16,
    learning_rate = 0.1,
    epochs = 30,
    hidden_dim = 512,
    dropout = 0.2
)

# %% [markdown]
# Konfiguration für das **CNN**:

# %%
config_cnn = dict(
    model_type = 'CNN',
    batch_size = 16,
    learning_rate = 0.01,
    epochs = 30,
    hidden_dim_1 = 1024, 
    dropout = 0.2
)

# %% [markdown]
# Konfiguration für das **Transfer Learning**:

# %%
config_transfer_vgg = {
    "scratch": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_FROM_SCRATCH',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "pretrained": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_PRETRAINED',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "finetune": dict(
        model_type = 'TRANSFER_VGG',
        model_subtype = 'TRAIN_FINETUNE',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 15, 
        hidden_dim = 128,
        dropout = 0.2,
    )
}

# %%
config_transfer_rn = {
    "scratch": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_FROM_SCRATCH',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "pretrained": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_PRETRAINED',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 30, 
        hidden_dim = 128,
        dropout = 0.2,
    ),
    "finetune": dict(
        model_type = 'TRANSFER_RN',
        model_subtype = 'TRAIN_FINETUNE',
        batch_size = 16,
        learning_rate = 1e-4,
        epochs = 15, 
        hidden_dim = 128,
        dropout = 0.2,
    )
}

# %% [markdown]
# ### 3. Datenerfassung & Aufbereitung
#
# In diesem Kapitel wird beschrieben, wie die für das Projekt verwendeten Bilddaten erhoben, organisiert und für die weitere Verarbeitung vorbereitet wurden.
#
# #### 3.1. Herkunft der Datensätze
#
# Um ein robustes und verallgemeinerungsfähiges Modell zu trainieren, ist eine ausreichend große und qualitativ hochwertige Datenbasis erforderlich. Für die Beschaffung öffentlich zugänglicher Trainingsdaten wurde die Online Plattform Kaggle genutzt, welche eine Vielzahl kuratierter Datensätze bereitstellt.
#
# #### 3.1.1. Externer Datensatz
#
# Zu Beginn haben wir uns dafür entschieden mit dem Datenset **"Garbage Classification"** von Mostafa Mohamed der Plattform Kaggle zu arbeiten. Jedoch zeigte sich schnell, dass die Klassenverteilung sehr unsausgeglichen war. Einige Kategorien waren so deutlich überpräsentiert, während andere nur sehr wenige Bilder enthielten, so dass unsere Modelle kaum bis garkeine Verbesserung der Accuracy in allen Durchläufen zeigten.
# <br>
# Um dieser Problematik entgegenzuwirken und eine bessere Grundlage für das Modelltraining zu schaffen, haben wir zusätzlich weitere Datensätze hinzugezogen.
#
# #### Die verwendeten Datensätze im Überblick:
#
# <table style="width:100%; border-collapse: collapse; margin-right:20px;">
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Quelle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Restmüll, Papier</td>
#       <td>
#         M. Abla, <i>Garbage Classification (12 classes)</i>, Kaggle dataset, 2020.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/mostafaabla/garbage-classification.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Pfandflaschen</td>
#       <td>
#         S. Kumar Sah, <i>Plastic Bottles Image Dataset</i>, Kaggle dataset, 2021.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/siddharthkumarsah/plastic-bottles-image-dataset.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Kaffeebecher (Kategorie: Verpackungen)</td>
#       <td>
#         V. Lanz, <i>Plastic and Paper Cups Synthetic Image Dataset</i>, Kaggle dataset, 2021.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/vencerlanz09/plastic-and-paper-cups-synthetic-image-dataset.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Plastik (Kategorie: Verpackungen)</td>
#       <td>
#         H. Kandoi, <i>Dataset for Visual Plastic Type Recognition</i>, Kaggle dataset, 2024.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/harshitkandoi7850/dataset-for-visual-plastic-type-recognition.<br>
#         Zugriff: 20.12.2025.<br><br>
#         N. Bagga, <i>Plastic Images</i>, Kaggle dataset, 2023.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/nandinibagga/plastic-images.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#     <tr>
#       <td>Dosen (Kategorie: Restmüll)</td>
#       <td>
#         T. Yasser, <i>Drinks Cans</i>, Kaggle dataset, 2023.<br>
#         Online verfügbar unter: https://www.kaggle.com/datasets/tarekyasser63/drinks-cans.<br>
#         Zugriff: 20.12.2025.
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# #### 3.1.2. Eigener Datensatz
#
# Ergänzend zu dem externen Datensatz wurde ein eigener Bilddatensatz erstellt, um die Trainingsdaten gezielt zu erweitern und an die spezifische Aufgabenstellung anzupassen. Hierfür wurden pro Kategorie etwa 200 eigene Bilder aufgenommen und in ein eigenes Datenset integriert.
#
# Die aufgenommenen Bilder wurden bewusst nicht unter idealisierten Bedingungen erstellt. Stattdessen wurde darauf geachtet, verschiedene Lichtverhältnisse, unterschiedliche Hintergrundstrukturen sowie teilweise Hände oder andere Objekte im Bild zuzulassen. Ziel dieser Vorgehensweise war es, ein möglichst realitätsnahes und vielfältiges Datenset zu erzeugen.
#
# Durch diese gezielte Variation lernt das Modell nicht nur idealisierte Beispielbilder, sondern wird bereits während des Trainings mit komplexeren und störbehafteten Szenen konfrontiert. Dies fördert die Robustheit des Modells gegenüber realen Einsatzbedingungen und verbessert seine Fähigkeit zur Generalisierung auf bisher unbekannte Bilder.
#
# #### 3.2. Zusammenführung und manuelle Strukturierung
#
# Ein besonderer Aufwand entstand bei der Verarbeitung plastikbezogener Daten. Da die meisten öffentlichen Datensätze dazu nicht aus Deutschland stammen und das Konzept von Pfandflaschen dort nicht existiert. <br> Daher mussten wir diese Bilder manuell durchsuchen und Plastikflaschen in eine eigene Kategorie Pfand einordnen, um alles optimal an unser Anwendungsszenario der HDM anzupassen.
# <br>
# Auch bei den den restlichen Datensätzen war eine manuelle Überprüfung notwendig, da viele Bilder für unser Szenario ungeignet waren, da sie nicht dem praktischen Anwendungsfall "Müll wird vor eine Kamera gehalten" entsprachen. Beispielsweise gab es Aufnahmen von Landstraßen, an deren Rändern Plastik in Gräben liegt oder Bilder von verstreutem Müll in Sträuchern und am Meer. Solche Bilder wurden konsequent aussortiert.
# <br><br>
# Nach dem Download der Datensätze wurden die Bilddaten manuell zusammengeführt und in eine einheitliche Ordnerstruktur überführt. Dabei wurde darauf geachtet, dass jede Klasse eine ähnliche Anzahl an Bildern enthält. Ziel war es, pro Kategorie etwa 2000 Bilder zu verwenden um eine gleichmäßige Klassenverteilung zu erreichen und damit optimale Voraussetzungen für das Training der Modelle zu schaffen.
#
# #### 3.3. Datensetanalyse
#
# !!!!
#
# #### 3.4. Ausgangsstruktur der Daten
#
# Wenn die Datensätze bereits vorab manuell in separate Trainings- und Validierungsordner aufgeteilt werden, entsteht ein höherer organisatorischer Aufwand und ein erhöhtes Risiko für inkonsistente Datenstrukturen. Stattdessen wurden in diesem Projekt alle Bilder in einer einheitlichen Verzeichnisstruktur abgelegt, bei der jede Klasse als eigenes Unterverzeichnis vorliegt. Die eigentliche Aufteilung in Trainings und Validierungsdaten erfolgt in diesem Jupyter Notebook.
#
# Zweitens ermöglicht die programmatische Aufteilung eine flexible Anpassung der Splitverhältnisse, ohne dass Dateien manuell verschoben oder dupliziert werden müssen. Drittens wird die Reproduzierbarkeit verbessert, da die Datenteilung durch einen festen Zufallsseed exakt wiederholbar durchgeführt werden kann.
#
# Im folgenden ist die Datenstruktur zu erkennen:
#
# Externer Bilddatensatz (Kaggle)
#
# ```
# extern-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```
#
#
# Eigener Bilddatensatz (selbst erhoben)
#
# ```
# custom-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```
#
# Alles Bilddatensätze (Kaggle + selbst erhoben)
#
# ```
# all-data/
#   other/
#   paper/
#   residual waste/
#   returnable bottle/
#   verpackungen/
# ```

# %% [markdown]
# ### 3.4. Datenaufbereitung
# #### 3.4.1. Import der Bilder

# %%
def load_data(file_path):
    full_dataset = datasets.ImageFolder(
        root=file_path
    )
    return full_dataset

# %% [markdown]
# #### 3.4.2. Bildverarbeitung
#
# In dieser Methode werden seperate Pipelines für Training und Validierung festgelegt. Dabei werden alle Bilder auf eine feste Größe skaliert und anschließend quadratisch aus der Mitte zugeschnitten und in ein für das Modell lesbares Tensor-Format umgewandelt.

# %%
def build_transforms(image_size):
    data_transforms = {
        'train': transforms.Compose([
            transforms.Resize(image_size),
            transforms.CenterCrop(image_size),
            transforms.RandomRotation(degrees=(0, 360)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ToTensor(),
        ]),
        'val': transforms.Compose([
            transforms.Resize(image_size),
            transforms.CenterCrop(image_size),
            transforms.ToTensor(),
        ])
    }
    return data_transforms

# %% [markdown]
# Mithilfe dieser Funktion wird eine zufällige Aufteilung der Indizes eines Datensatzes in die Gruppen "Training" und "Validierung" eingeteilt.

# %%
def split_indices(dataset, train_ratio):
    total_size = len(dataset)
    
    train_size = int(train_ratio * total_size)
    val_size = total_size - train_size
    
    train_indices, val_indices = random_split(
        range(total_size),
        [train_size, val_size],
        generator=generator
    )
    
    return train_indices, val_indices

# %% [markdown]
# Basiernd auf den Indizes der Methode davor werden hier die Datasets und Subsets der Trainings- und Validierungsdaten erstellt.

# %%
def build_dataset(file_path, data_transforms, train_indices, val_indices):
    train_dataset_base = datasets.ImageFolder(
        root=file_path,
        transform=data_transforms['train']
    )

    val_dataset_base = datasets.ImageFolder(
        root=file_path,
        transform=data_transforms['val']
    )

    train_dataset = torch.utils.data.Subset(
        train_dataset_base,
        train_indices
    )

    val_dataset = torch.utils.data.Subset(
        val_dataset_base,
        val_indices
    )

    return train_dataset, val_dataset

# %% [markdown]
# Anhand der Datasets werden hier die Dataloader erstellt. Dabei wird nicht nur das Datenset, sondern auch die Batchgröße und die Anzahl der Worker-Prozesse als Parameter übergeben.
#
# Dabei ist es besonders darauf zu achten, dass die Trainingsdaten in jeder Epoche neu gemischt werden (shuffle = True). Das verhindert, dass das Modell die Reihenfolge der Bilder auswendig lernt.
#
# Während der Validierung ist die Reihenfolge egal, daher kann auf das Mischen verzichtet werden.

# %%
def build_dataloaders(train_dataset, val_dataset, batch_size, num_workers):
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )

    return train_loader, val_loader

# %% [markdown]
# Diese Funktion ermittelt die Klassenverteilung des Datensatzes. Zuerst werden die Kategorienamen extrahiert. Danach iteriert die Funktion über alle Labels, ordnet diese ihren Klarnamen zu und zählt deren Häufigkeit in einem Dictionary.

# %%
def count_classes(dataset):
    img_classes = {}
    class_names = dataset.classes

    for _, label in dataset:
        class_name = class_names[int(label)]

        if class_name not in img_classes:
            img_classes[class_name] = 0

        img_classes[class_name] += 1

    return img_classes

# %% [markdown]
# Diese Methode ist die zentrale Steuerungseinheit für die gesamte Datenvorbereitung.
#
# Sie lädt zuerst die Datensätze anhand des mitgegebenen Filepaths und ermittelt bereits zu Beginn die Anzahl der Bilder, die Anzahl der Klassen, die Namen der Klassen und die Klassenverteilung. Diese werden zu Beginn ausgegeben, sodass man frühzeitig die Daten kontrollieren und Ungleichgewichte erkennen kann.
#
# Anschließend werden die oben bereits beschriebenen Funktionen aufgerufen um die Daten zu transformieren und zu splitten. Danach werden die Datasets und Dataloaders erstellt.
#
# Zuletzt wird als Sicherheitscheck die Batchgröße, Bildform und Beispiellabels ausgegeben, um so überprüfen zu können, ob die Funktionen erfolgreich aufgerufen wurden.
#
# Zudem wird hier bereits der erste Bilddatensatz geladen (extern-data)

# %%
def prepare_data(file_path):
    full_dataset = load_data(file_path)
    class_count = len(full_dataset.classes)
    image_count = len(full_dataset)
    image_classes = count_classes(full_dataset)

    print("\n=== Datensatzübersicht ===")
    print(f"Anzahl Bilder gesamt: {image_count}")
    print(f"Anzahl Klassen: {class_count}")
    print(f"Klassen: {full_dataset.classes}")

    print("\nKlassenverteilung (gesamt):")
    for cls, cnt in image_classes.items():
        print(f"  {cls:<20}: {cnt}")

    data_transforms = build_transforms(image_size)

    train_indices, val_indices = split_indices(
        full_dataset,
        train_ratio
    )

    train_dataset, val_dataset = build_dataset(
        file_path,
        data_transforms,
        train_indices,
        val_indices,
    )

    train_loader, val_loader = build_dataloaders(
        train_dataset,
        val_dataset,
        config_mlp['batch_size'],
        num_workers
    )

    return full_dataset, train_loader, val_loader, class_count, image_classes

extern_full_dataset, extern_train_loader, extern_val_loader, extern_class_count, extern_image_classes = prepare_data(extern_file_path)

images, labels = next(iter(extern_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {images.shape[0]}")
print(f"Bildform          : {tuple(images.shape[1:])}")
print(f"Label-Beispiel    : {labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 10391
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 2145
#   paper               : 1941
#   residual waste      : 2291
#   returnable bottle   : 2013
#   unauthorized waste  : 2001
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [4, 0, 0, 3, 2, 2, 3, 2, 2, 3, 2, 2, 0, 0, 4, 2]

# %% [markdown]
# Laden des zweiten Bilddatensatzes (custom-data)

# %%
custom_full_dataset, custom_train_loader, custom_val_loader, custom_class_count, custom_image_classes = prepare_data(custom_file_path)

custom_images, custom_labels = next(iter(custom_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {custom_images.shape[0]}")
print(f"Bildform          : {tuple(custom_images.shape[1:])}")
print(f"Label-Beispiel    : {custom_labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 1196
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 237
#   paper               : 247
#   residual waste      : 222
#   returnable bottle   : 244
#   unauthorized waste  : 246
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [3, 1, 0, 2, 0, 2, 0, 0, 3, 2, 4, 1, 2, 1, 0, 2]

# %% [markdown]
# Laden des dritten Bilddatensatzes (all-data)

# %%
all_full_dataset, all_train_loader, all_val_loader, all_class_count, all_image_classes = prepare_data(all_file_path)

all_images, all_labels = next(iter(all_train_loader))

print("\n=== Trainingsbatch ===")
print(f"Batchgröße        : {all_images.shape[0]}")
print(f"Bildform          : {tuple(all_images.shape[1:])}")
print(f"Label-Beispiel    : {all_labels.tolist()}")
# Out:
# === Datensatzübersicht ===
# Anzahl Bilder gesamt: 11587
# Anzahl Klassen: 5
# Klassen: ['packaging', 'paper', 'residual waste', 'returnable bottle', 'unauthorized waste']
#
# Klassenverteilung (gesamt):
#   packaging           : 2382
#   paper               : 2188
#   residual waste      : 2513
#   returnable bottle   : 2257
#   unauthorized waste  : 2247
#
# === Trainingsbatch ===
# Batchgröße        : 16
# Bildform          : (3, 32, 32)
# Label-Beispiel    : [3, 0, 0, 3, 4, 0, 2, 2, 4, 3, 1, 3, 2, 0, 1, 1]

# %% [markdown]
# Ähnlich zu der Funktion oben zählt diese Funktion wie viele Bilder jeder Klasse in einem bestimmten Subset eines Datensatzes enthalten sind. Dabei wird ebenfalls ein Wörterbuch mit allen Klassennamen und dem Startwert 0 erstellt.
#
# Anschließend werden alle Indizes in dem Subset durchgegangen. Für jedes Bild wird das zugehörige Label angeschaut und der Zähler der passenden Klasse wird um 1 erhöht.

# %%
def count_classes_subset(subset, class_names):
    counts = {name: 0 for name in class_names}
    for idx in subset.indices:
        _, label = subset.dataset.samples[idx]
        counts[class_names[label]] += 1
    return counts

# %% [markdown]
# Diese Funktion visualisiert eine Klassenverteilung als Balkendiagramm.
#
# Sie erstellt zuerst eine neue Grafik und zeichnet danach für jede Klasse einen Balken, dessen Höhe der Anzahl der Bilder entspricht. Titel sowie Beschriftungen für x- und y-Achse werden ebenfalls gesetzt. Zuletzt wird das Diagramm angezeigt.

# %%
def print_class_distribution(img_classes, title, xlabel, ylabel):
    plt.figure(figsize=(10,5))
    plt.bar(img_classes.keys(), img_classes.values())
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %% [markdown]
# Zählen und Visualisieren der Extern-Subsets.

# %%
# --- Train ---
train_dist = count_classes_subset(extern_train_loader.dataset, extern_full_dataset.classes)
print_class_distribution(
    train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
val_dist = count_classes_subset(extern_val_loader.dataset, extern_full_dataset.classes)
print_class_distribution(
    val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %% [markdown]
# Zählen und Visualisieren der Custom-Subsets.

# %%
# --- Train ---
custom_train_dist = count_classes_subset(custom_train_loader.dataset, custom_full_dataset.classes)
print_class_distribution(
    custom_train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
custom_val_dist = count_classes_subset(custom_val_loader.dataset, custom_full_dataset.classes)
print_class_distribution(
    custom_val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %% [markdown]
# Zählen und Visualisieren der All-Subsets.

# %%
# --- Train ---
all_train_dist = count_classes_subset(all_train_loader.dataset, all_full_dataset.classes)
print_class_distribution(
    all_train_dist,
    title="Klassenverteilung - Training",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# --- Validation ---
all_val_dist = count_classes_subset(all_val_loader.dataset, all_full_dataset.classes)
print_class_distribution(
    all_val_dist,
    title="Klassenverteilung - Validation",
    xlabel="Klasse",
    ylabel="Anzahl Bilder"
)

# %% [markdown]
# Hier werden zufällige Bilder aus einem Datenset inklusive ihrer Klassennamen visualisiert.

# %%
def show_random_samples(dataset): 
    figure = plt.figure(figsize=(12, 10))
    cols, rows = 6, 1
    class_names = extern_full_dataset.classes  

    for i in range(1, rows * cols + 1):
        sample_idx = torch.randint(len(dataset), size=(1,)).item()
        img, label = dataset[sample_idx]

        img = img.permute(1, 2, 0)
        class_name = class_names[int(label)]

        figure.add_subplot(rows, cols, i)
        plt.axis("off")
        plt.title(class_name)
        plt.imshow(img)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Anzeige zufälliger Bilder des Extern-Datasets

# %%
# --- Train ---
show_random_samples(extern_train_loader.dataset)

# --- Validation ---
show_random_samples(extern_val_loader.dataset)

# %% [markdown]
# Anzeige zufälliger Bilder des Custom-Datasets

# %%
show_random_samples(custom_train_loader.dataset)
show_random_samples(custom_val_loader.dataset)

# %% [markdown]
# Anzeige zufälliger Bilder des All-Datasets

# %%
show_random_samples(all_train_loader.dataset)
show_random_samples(all_val_loader.dataset)

# %% [markdown]
# ## Architekturen definieren
#
# 1. MLP
# 3. CNN - Eigenen Feature Extractor und Classifier
# 4. Komplexes CNN
# 2. Transfer Learning <br>
#     2.1. From scratch <br>
#     2.2. Pretrained<br>
#     2.3. Fine Tune <br>

# %% [markdown]
# ### Multi Layer Perceptron

# %% [markdown]
# Die Klasse `MLP` implementiert ein **Multilayer Perceptron (MLP)** zur Klassifikation von Bilddaten.
# Das Modell besteht aus einer vollständig verbundenen Hidden-Schicht mit Dropout-Regularisierung
# sowie einer Ausgabeschicht zur Vorhersage der Klassenwahrscheinlichkeiten.
#
# Die Implementierung basiert auf **PyTorch** und erbt von `torch.nn.Module`.
#
# ---
#
# ##### Zweck
#
# Das MLP dient als **einfaches neuronales Basismodell**, um Bilddaten nach vorheriger
# Serialisierung (Flattening) zu klassifizieren.
# Es eignet sich insbesondere:
# - als Vergleichsmodell zu komplexeren Architekturen (z. B. CNNs),
# - für Experimente mit Fully-Connected-Netzen,
# - für kleinere Datensätze oder als Lernbeispiel.
#
# ---

# %%
class MLP(nn.Module):
    def __init__(self, config):
        super(MLP, self).__init__()
        self.d1 = nn.Linear(channel * image_size * image_size, config.hidden_dim)
        self.dropout = nn.Dropout(p=config.dropout)
        self.d2 = nn.Linear(config.hidden_dim, extern_class_count)
    
    def forward(self, x):
        x = x.flatten(start_dim = 1) #serialize 3dim input

        x = self.d1(x)
        x = torch.relu(x)
        x = self.dropout(x)

        raw_scores = self.d2(x)
        # output_predictions = torch.softmax(raw_scores , dim=1)   

        return raw_scores

# %% [markdown]
# ### CNN

# %% [markdown]
# Die Klasse `CNN` implementiert ein **Convolutional Neural Network (CNN)** zur Bildklassifikation.
# Das Modell nutzt mehrere Faltungs- und Pooling-Schichten zur Extraktion räumlicher Merkmale
# sowie vollständig verbundene Schichten zur Klassifikation.
#
# Die Implementierung basiert auf **PyTorch** und erbt von `torch.nn.Module`.
#
# ---
#
# #### Zweck
#
# Das CNN ist für die **automatische Merkmalsextraktion aus Bilddaten** konzipiert.
# Im Gegensatz zu einem MLP nutzt es die räumliche Struktur der Bilder und eignet sich daher
# besonders gut für visuelle Klassifikationsaufgaben.
#
# Typische Einsatzbereiche:
# - Bildklassifikation
# - Vergleich mit einfacheren Baseline-Modellen (z. B. MLP)
# - Experimente mit Regularisierung (Dropout, Batch Normalization)
#
# ---

# %%
class CNN(nn.Module):
    def __init__(self, config):
        super(CNN, self).__init__()
        self.drop=nn.Dropout2d(config.dropout)
        self.dropfc=nn.Dropout(config.dropout)
        self.conv1 = nn.Conv2d(channel, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(512*2*2, config.hidden_dim_1)
        self.fc2 = nn.Linear(config.hidden_dim_1, extern_class_count)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.drop(self.conv1(x)))))
        x = self.pool(F.relu(self.bn2(self.drop(self.conv2(x)))))
        x = self.pool(F.relu(self.bn3(self.drop(self.conv3(x)))))
        x = self.pool(F.relu(self.bn4(self.drop(self.conv4(x)))))
        x = x.view(-1, 512*2*2)
        x = F.relu(self.dropfc(self.fc1(x)))
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Transfer Learning
#
# ### VGG16 Model

# %% [markdown]
# Die Klasse `VGG16` implementiert ein **auf VGG16 basierendes Convolutional Neural Network**
# für die Bildklassifikation. Je nach Konfiguration kann das Modell
# - **von Grund auf neu trainiert**,
# - **als eingefrorenes, vortrainiertes Modell genutzt**
# - oder **feinjustiert (Fine-Tuning)** werden.
#
# Die Implementierung nutzt das vortrainierte **VGG16-Modell aus `torchvision.models`**
# und passt die Architektur an die Zielklassen des Datensatzes an.
#
# ---
#
# #### Zweck
#
# Dieses Modell dient zur **leistungsstarken Bildklassifikation** unter Nutzung von
# **Transfer Learning**. Durch die Wiederverwendung vortrainierter Gewichte
# (konzipiert für ImageNet) kann auch bei kleineren Datensätzen eine hohe
# Generalisierungsleistung erreicht werden.
#
# Typische Einsatzszenarien:
# - Transfer Learning
# - Fine-Tuning vortrainierter CNNs
# - Vergleich mit selbst implementierten CNN-Architekturen
#
# ---

# %%
class VGG16(nn.Module):
    def __init__(self, config):
        super(VGG16, self).__init__()
        self.config = config
        
        if config.model_subtype == "TRAIN_FROM_SCRATCH":
            self.model = models.vgg16(pretrained=False)
            for param in self.model.parameters():
                param.requires_grad = True
        elif config.model_subtype == "TRAIN_PRETRAINED":
            self.model = models.vgg16(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = False
        elif config.model_subtype == "TRAIN_FINETUNE":
            self.model = models.vgg16(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = True
        else:
            raise ValueError(f"Unknown model_subtype {config.model_subtype}")
        
        self.model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

        self.model.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, config.hidden_dim),
            nn.ReLU(),
            nn.Dropout(config.dropout),
            nn.Linear(config.hidden_dim, extern_class_count)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### ResNet50
#
# Die Klasse `ResNet50` implementiert ein **auf ResNet50 basierendes Deep Convolutional Neural Network**
# zur Bildklassifikation. Ähnlich zur `VGG16`-Klasse nutzt dieses Modell **Transfer Learning**
# und erlaubt verschiedene Trainingsstrategien, unterscheidet sich jedoch grundlegend in seiner
# Architektur durch die Verwendung von **Residual Connections**.
#
# Die Implementierung basiert auf dem vortrainierten **ResNet50-Modell aus `torchvision.models`**.
#
# ---
#
# #### Zweck
#
# Das ResNet50-Modell wird eingesetzt, um:
# - die Leistungsfähigkeit moderner, tiefer CNN-Architekturen zu evaluieren,
# - **VGG16 und ResNet50 direkt miteinander zu vergleichen**,
# - die Auswirkungen von Architekturentscheidungen (Tiefe, Residual Connections)
#   auf Trainingsstabilität und Generalisierung zu analysieren.
#
# Insbesondere steht hier der **Vergleich zwischen klassischen CNNs (VGG16) und Residual Networks**
# im Fokus der Untersuchung.
#
# ---

# %%
class ResNet50(nn.Module):
    def __init__(self, config):
        super(ResNet50, self).__init__()
        self.config = config
        
        if config.model_subtype == "TRAIN_FROM_SCRATCH":
            self.model = models.resnet50(pretrained=False) 
            for param in self.model.parameters():
                param.requires_grad = True

        elif config.model_subtype == "TRAIN_PRETRAINED":
            self.model = models.resnet50(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = False

        elif config.model_subtype == "TRAIN_FINETUNE":
            self.model = models.resnet50(pretrained=True)
            for param in self.model.parameters():
                param.requires_grad = True
        else:
            raise ValueError(f"Unknown model_subtype {config.model_subtype}")

        num_ftrs = self.model.fc.in_features 

        self.model.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(num_ftrs, config.hidden_dim), 
            nn.ReLU(),
            nn.Dropout(config.dropout),
            nn.Linear(config.hidden_dim, extern_class_count)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Funktion `get_model`
#
# Die Funktion `get_model` ist eine **zentrale Factory-Funktion** zur Initialisierung
# von Modellen, Optimierern und Verlustfunktionen.
# Sie kapselt die gesamte Modellkonfiguration und stellt sicher, dass
# alle Experimente konsistent und vergleichbar durchgeführt werden.
#
# ---
#
# #### Zweck
#
# Diese Funktion dient dazu:
# - unterschiedliche Modellarchitekturen **einheitlich zu initialisieren**,
# - passende Optimierer abhängig vom Modelltyp zu wählen,
# - eine gemeinsame Verlustfunktion zu definieren,
# - die Modelle automatisch auf das Zielgerät (CPU/GPU) zu verschieben,
# - eine übersichtliche Modellzusammenfassung auszugeben.
#
# Dadurch wird ein **fairer Vergleich zwischen MLP, CNN, VGG16 und ResNet50**
# ermöglicht, ohne Code-Duplikation oder inkonsistente Trainingspipelines.
#
# ---

# %%
def get_model(config):
    print(config)
    if config.model_type == "MLP":
        model = MLP(config) 
        optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "CNN":
        model = CNN(config) 
        optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "TRANSFER_VGG":
        model = VGG16(config);  
        optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()

    elif config.model_type == "TRANSFER_RN":
        model = ResNet50(config);  
        optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
        loss_fn = nn.CrossEntropyLoss()
    else:
        raise ValueError(f"Unknown model_type {config.model_type}")
    
    model = model.to(device)
    summary(model, input_size=(channel, image_size, image_size))

    return model, optimizer, loss_fn

# %% [markdown]
# #### Trainings Funktionen

# %%
def get_accuracy(output, target, batch_size):
    prediction=torch.max(output, 1)[1].view(target.size())
    corrects = (prediction.data == target.data).sum()
    accuracy = 100.0 * corrects / batch_size
    return accuracy.item()

# %%
def train_step(model, config, optimizer, loss_fn, train_loader): 
    loss_value = 0.0
    accuracy_value = 0.0


    for i, (images, labels) in enumerate(train_loader):
        model.train()

        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = loss_fn(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_value += loss.detach().item()
        accuracy_value += get_accuracy(outputs, labels, config.batch_size)

    loss_avg = loss_value / i
    accuracy_avg = accuracy_value / i

    return loss_avg, accuracy_avg

# %%
def val_step(model, config, loss_fn, val_loader):
    loss_value = 0.0
    accuracy_value = 0.0

    with torch.no_grad():
        for i, (images, labels) in enumerate(val_loader):
            model.eval()

            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = loss_fn(outputs, labels)

            loss_value += loss.detach().item()
            accuracy_value += get_accuracy(outputs, labels, config.batch_size)

    loss_avg = loss_value / i
    accuracy_avg = accuracy_value / i

    return loss_avg, accuracy_avg

# %%
def print_results(num_epochs, train_accuracy, val_accuracy, model, val_loader, full_dataset):

    # print training and validation accuracy plot
    plt.figure(figsize=(12,8))
    plt.plot(range(num_epochs),train_accuracy,"r",label="training accuracy")
    plt.plot(range(num_epochs),val_accuracy,"b",label="validation accuracy")
    plt.xlabel("epoch")
    plt.grid(True)
    plt.legend()
    plt.show()

    # evaluate on validation set
    y_true = []
    y_pred = []

    model.eval()
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # print classification report 
    print(classification_report(y_true, y_pred))

    # print confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=full_dataset.classes, yticklabels=full_dataset.classes)
    plt.xlabel('Vorhergesagte Klasse (Prediction)')
    plt.ylabel('Wahre Klasse (True Label)')
    plt.title('Confusion Matrix: Was wird womit verwechselt?')
    plt.show()

# %%
def run_training_loop(name, model, config, optimizer, loss_fn, train_loader, val_loader, full_dataset ):
    print(f"Start training for {name} with {config.epochs} epochs...") 
    
    model = model.to(device) 

    history = {
        'train_loss': [],
        'train_accuracy': [],
        'val_loss': [],
        'val_accuracy': []
    }

    for epoch in range(config.epochs):
        
        train_loss_avg, train_accuracy_avg = train_step(model, config, optimizer, loss_fn, train_loader)
        val_loss_avg, val_accuracy_avg = val_step(model, config, loss_fn, val_loader)

        history['train_loss'].append(train_loss_avg)
        history['train_accuracy'].append(train_accuracy_avg)
        history['val_loss'].append(val_loss_avg)
        history['val_accuracy'].append(val_accuracy_avg)

        print(f"Epoch [{epoch+1}/{config.epochs}], "
              f"Train Loss: {train_loss_avg:.4f}, Train Acc: {train_accuracy_avg:.2f}%, "
              f"Val Loss: {val_loss_avg:.4f}, Val Acc: {val_accuracy_avg:.2f}%")
        
    
        wandb.log({
            "train_loss": train_loss_avg,
            "train_accuracy": train_accuracy_avg,
            "val_loss": val_loss_avg,
            "val_accuracy": val_accuracy_avg
        })
    
    print_results(config.epochs, history['train_accuracy'], history['val_accuracy'], model, val_loader , full_dataset)

# %%
def model_pipeline(name, config=None):
    
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config
        print(f"Running model pipeline: {name}, with config: {config}")

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, extern_train_loader, extern_val_loader, extern_full_dataset)

# %%
model_pipeline("MLP", config_mlp)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_204250-8fnvbuxp</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8fnvbuxp' target="_blank">wise-fire-86</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8fnvbuxp' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8fnvbuxp</a>
# {'model_type': 'MLP', 'batch_size': 16, 'learning_rate': 0.1, 'epochs': 30, 'hidden_dim': 512, 'dropout': 0.2}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]       1,573,376
#            Dropout-2                  [-1, 512]               0
#             Linear-3                    [-1, 5]           2,565
# ================================================================
# Total params: 1,575,941
# Trainable params: 1,575,941
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.01
# Params size (MB): 6.01
# Estimated Total Size (MB): 6.03
# ----------------------------------------------------------------
# Start training for MLP with 30 epochs...
# Epoch [1/30], Train Loss: 1.6155, Train Acc: 23.87%, Val Loss: 1.5887, Val Acc: 25.29%
# Epoch [2/30], Train Loss: 1.5863, Train Acc: 26.23%, Val Loss: 1.5708, Val Acc: 30.99%
# Epoch [3/30], Train Loss: 1.5784, Train Acc: 26.69%, Val Loss: 1.5466, Val Acc: 25.32%
# Epoch [4/30], Train Loss: 1.5685, Train Acc: 27.96%, Val Loss: 1.8047, Val Acc: 23.97%
# Epoch [5/30], Train Loss: 1.5623, Train Acc: 28.84%, Val Loss: 1.4993, Val Acc: 34.76%
# Epoch [6/30], Train Loss: 1.5326, Train Acc: 31.83%, Val Loss: 1.5118, Val Acc: 32.38%
# Epoch [7/30], Train Loss: 1.5436, Train Acc: 30.99%, Val Loss: 1.5572, Val Acc: 29.77%
# Epoch [8/30], Train Loss: 1.5386, Train Acc: 30.73%, Val Loss: 1.6407, Val Acc: 27.19%
# Epoch [9/30], Train Loss: 1.5398, Train Acc: 31.25%, Val Loss: 1.4925, Val Acc: 35.12%
# Epoch [10/30], Train Loss: 1.5310, Train Acc: 31.51%, Val Loss: 1.4953, Val Acc: 32.80%
# Epoch [11/30], Train Loss: 1.5229, Train Acc: 31.64%, Val Loss: 1.4852, Val Acc: 33.99%
# Epoch [12/30], Train Loss: 1.5273, Train Acc: 32.35%, Val Loss: 1.4890, Val Acc: 34.41%
# Epoch [13/30], Train Loss: 1.5224, Train Acc: 32.97%, Val Loss: 1.4570, Val Acc: 35.21%
# Epoch [14/30], Train Loss: 1.5187, Train Acc: 33.00%, Val Loss: 1.4913, Val Acc: 34.54%
# Epoch [15/30], Train Loss: 1.5221, Train Acc: 32.39%, Val Loss: 1.5795, Val Acc: 32.15%
# Epoch [16/30], Train Loss: 1.5197, Train Acc: 32.68%, Val Loss: 1.4880, Val Acc: 33.67%
# Epoch [17/30], Train Loss: 1.5101, Train Acc: 32.74%, Val Loss: 1.4849, Val Acc: 33.47%
# Epoch [18/30], Train Loss: 1.5167, Train Acc: 33.45%, Val Loss: 1.4880, Val Acc: 34.83%
# Epoch [19/30], Train Loss: 1.5091, Train Acc: 33.82%, Val Loss: 1.5367, Val Acc: 31.38%
# Epoch [20/30], Train Loss: 1.4983, Train Acc: 33.71%, Val Loss: 1.4991, Val Acc: 32.67%
# Epoch [21/30], Train Loss: 1.5086, Train Acc: 32.27%, Val Loss: 1.5235, Val Acc: 31.77%
# Epoch [22/30], Train Loss: 1.5016, Train Acc: 33.98%, Val Loss: 1.4873, Val Acc: 34.63%
# Epoch [23/30], Train Loss: 1.4991, Train Acc: 33.77%, Val Loss: 1.4562, Val Acc: 35.86%
# Epoch [24/30], Train Loss: 1.4978, Train Acc: 33.11%, Val Loss: 1.5562, Val Acc: 32.22%
# Epoch [25/30], Train Loss: 1.4934, Train Acc: 34.26%, Val Loss: 1.4380, Val Acc: 36.98%
# Epoch [26/30], Train Loss: 1.4984, Train Acc: 33.22%, Val Loss: 1.4688, Val Acc: 35.57%
# Epoch [27/30], Train Loss: 1.4945, Train Acc: 32.67%, Val Loss: 1.4727, Val Acc: 36.69%
# Epoch [28/30], Train Loss: 1.4908, Train Acc: 34.09%, Val Loss: 1.5471, Val Acc: 32.38%
# Epoch [29/30], Train Loss: 1.4900, Train Acc: 34.15%, Val Loss: 1.4523, Val Acc: 36.63%
# Epoch [30/30], Train Loss: 1.4945, Train Acc: 34.43%, Val Loss: 1.4934, Val Acc: 34.02%
#               precision    recall  f1-score   support
#
#            0       0.66      0.27      0.38       661
#            1       0.10      0.00      0.01       565
#            2       0.59      0.18      0.28       721
#            3       0.24      0.96      0.39       580
#            4       0.65      0.32      0.43       591
#
#     accuracy                           0.34      3118
#    macro avg       0.45      0.35      0.30      3118
# weighted avg       0.46      0.34      0.30      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▃▄▄▆▆▆▆▆▆▇▇▇▇▇▇▇██▇██▇█▇▇███</td></tr><tr><td>train_loss</td><td>█▆▆▅▅▃▄▄▄▃▃▃▃▃▃▃▂▂▂▁▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▅▂▁▇▆▄▃▇▆▆▇▇▇▅▆▆▇▅▆▅▇▇▅█▇█▆█▆</td></tr><tr><td>val_loss</td><td>▄▄▃█▂▂▃▅▂▂▂▂▁▂▄▂▂▂▃▂▃▂▁▃▁▂▂▃▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>34.43007</td></tr><tr><td>train_loss</td><td>1.49445</td></tr><tr><td>val_accuracy</td><td>34.02062</td></tr><tr><td>val_loss</td><td>1.49335</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wise-fire-86</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8fnvbuxp' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/8fnvbuxp</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_204250-8fnvbuxp\logs</code>

# %%
model_pipeline("CNN", config_cnn)
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_210044-0i7x2v30</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/0i7x2v30' target="_blank">noble-bush-87</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/0i7x2v30' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/0i7x2v30</a>
# {'model_type': 'CNN', 'batch_size': 16, 'learning_rate': 0.01, 'epochs': 30, 'hidden_dim_1': 1024, 'dropout': 0.2}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#          Dropout2d-2           [-1, 64, 32, 32]               0
#        BatchNorm2d-3           [-1, 64, 32, 32]             128
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          Dropout2d-6          [-1, 128, 16, 16]               0
#        BatchNorm2d-7          [-1, 128, 16, 16]             256
#          MaxPool2d-8            [-1, 128, 8, 8]               0
#             Conv2d-9            [-1, 256, 8, 8]         295,168
#         Dropout2d-10            [-1, 256, 8, 8]               0
#       BatchNorm2d-11            [-1, 256, 8, 8]             512
#         MaxPool2d-12            [-1, 256, 4, 4]               0
#            Conv2d-13            [-1, 512, 4, 4]       1,180,160
#         Dropout2d-14            [-1, 512, 4, 4]               0
#       BatchNorm2d-15            [-1, 512, 4, 4]           1,024
#         MaxPool2d-16            [-1, 512, 2, 2]               0
#            Linear-17                 [-1, 1024]       2,098,176
#           Dropout-18                 [-1, 1024]               0
#            Linear-19                    [-1, 5]           5,125
# ================================================================
# Total params: 3,656,197
# Trainable params: 3,656,197
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.06
# Params size (MB): 13.95
# Estimated Total Size (MB): 17.02
# ----------------------------------------------------------------
# Start training for CNN with 30 epochs...
# Epoch [1/30], Train Loss: 1.4536, Train Acc: 38.17%, Val Loss: 1.4644, Val Acc: 37.50%
# Epoch [2/30], Train Loss: 1.3155, Train Acc: 47.45%, Val Loss: 1.3520, Val Acc: 45.26%
# Epoch [3/30], Train Loss: 1.2562, Train Acc: 50.48%, Val Loss: 1.2429, Val Acc: 50.55%
# Epoch [4/30], Train Loss: 1.2236, Train Acc: 52.19%, Val Loss: 1.3080, Val Acc: 46.49%
# Epoch [5/30], Train Loss: 1.2018, Train Acc: 52.78%, Val Loss: 1.3312, Val Acc: 49.36%
# Epoch [6/30], Train Loss: 1.1762, Train Acc: 54.25%, Val Loss: 1.2205, Val Acc: 51.32%
# Epoch [7/30], Train Loss: 1.1641, Train Acc: 54.78%, Val Loss: 1.1785, Val Acc: 53.54%
# Epoch [8/30], Train Loss: 1.1583, Train Acc: 54.82%, Val Loss: 1.2909, Val Acc: 49.29%
# Epoch [9/30], Train Loss: 1.1407, Train Acc: 55.89%, Val Loss: 1.0828, Val Acc: 59.73%
# Epoch [10/30], Train Loss: 1.1306, Train Acc: 56.04%, Val Loss: 1.1649, Val Acc: 55.77%
# Epoch [11/30], Train Loss: 1.1079, Train Acc: 57.45%, Val Loss: 1.0972, Val Acc: 60.02%
# Epoch [12/30], Train Loss: 1.1023, Train Acc: 57.60%, Val Loss: 1.1161, Val Acc: 56.80%
# Epoch [13/30], Train Loss: 1.0972, Train Acc: 57.23%, Val Loss: 1.1443, Val Acc: 55.19%
# Epoch [14/30], Train Loss: 1.0899, Train Acc: 57.94%, Val Loss: 1.0572, Val Acc: 60.99%
# Epoch [15/30], Train Loss: 1.0782, Train Acc: 58.78%, Val Loss: 1.0773, Val Acc: 59.57%
# Epoch [16/30], Train Loss: 1.0712, Train Acc: 58.55%, Val Loss: 1.1143, Val Acc: 57.60%
# Epoch [17/30], Train Loss: 1.0588, Train Acc: 59.33%, Val Loss: 1.1620, Val Acc: 57.35%
# Epoch [18/30], Train Loss: 1.0507, Train Acc: 59.47%, Val Loss: 1.0261, Val Acc: 61.76%
# Epoch [19/30], Train Loss: 1.0406, Train Acc: 60.77%, Val Loss: 0.9949, Val Acc: 64.11%
# Epoch [20/30], Train Loss: 1.0394, Train Acc: 60.75%, Val Loss: 1.0565, Val Acc: 60.86%
# Epoch [21/30], Train Loss: 1.0382, Train Acc: 60.61%, Val Loss: 1.1214, Val Acc: 58.44%
# Epoch [22/30], Train Loss: 1.0283, Train Acc: 60.37%, Val Loss: 1.0163, Val Acc: 62.89%
# Epoch [23/30], Train Loss: 1.0139, Train Acc: 61.18%, Val Loss: 1.0203, Val Acc: 61.73%
# Epoch [24/30], Train Loss: 1.0117, Train Acc: 61.41%, Val Loss: 1.0443, Val Acc: 61.31%
# Epoch [25/30], Train Loss: 1.0049, Train Acc: 61.50%, Val Loss: 1.0179, Val Acc: 62.11%
# Epoch [26/30], Train Loss: 0.9957, Train Acc: 62.65%, Val Loss: 1.0139, Val Acc: 62.69%
# Epoch [27/30], Train Loss: 0.9962, Train Acc: 62.29%, Val Loss: 0.9902, Val Acc: 64.08%
# Epoch [28/30], Train Loss: 0.9866, Train Acc: 62.31%, Val Loss: 0.9696, Val Acc: 65.24%
# Epoch [29/30], Train Loss: 0.9944, Train Acc: 61.72%, Val Loss: 0.9457, Val Acc: 65.75%
# Epoch [30/30], Train Loss: 0.9817, Train Acc: 63.06%, Val Loss: 0.9842, Val Acc: 64.18%
#               precision    recall  f1-score   support
#
#            0       0.55      0.72      0.62       661
#            1       0.64      0.61      0.63       565
#            2       0.73      0.50      0.59       721
#            3       0.79      0.70      0.74       580
#            4       0.57      0.68      0.62       591
#
#     accuracy                           0.64      3118
#    macro avg       0.66      0.64      0.64      3118
# weighted avg       0.66      0.64      0.64      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▃▄▄▅▄▇▆▇▆▅▇▆▆▆▇█▇▆▇▇▇▇▇████</td></tr><tr><td>val_loss</td><td>█▆▅▆▆▅▄▆▃▄▃▃▄▃▃▃▄▂▂▂▃▂▂▂▂▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>63.06443</td></tr><tr><td>train_loss</td><td>0.98174</td></tr><tr><td>val_accuracy</td><td>64.17526</td></tr><tr><td>val_loss</td><td>0.98419</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">noble-bush-87</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/0i7x2v30' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/0i7x2v30</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_210044-0i7x2v30\logs</code>

# %%
model_pipeline("Transfer Learning - From Scratch", config_transfer_vgg["scratch"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_212048-zk88xqug</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/zk88xqug' target="_blank">fearless-sea-88</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/zk88xqug' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/zk88xqug</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FROM_SCRATCH', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - From Scratch with 30 epochs...
# Epoch [1/30], Train Loss: 1.5972, Train Acc: 23.62%, Val Loss: 1.5121, Val Acc: 31.19%
# Epoch [2/30], Train Loss: 1.4835, Train Acc: 30.86%, Val Loss: 1.4962, Val Acc: 27.22%
# Epoch [3/30], Train Loss: 1.4141, Train Acc: 36.10%, Val Loss: 1.3739, Val Acc: 40.72%
# Epoch [4/30], Train Loss: 1.3464, Train Acc: 40.34%, Val Loss: 1.3322, Val Acc: 41.37%
# Epoch [5/30], Train Loss: 1.2840, Train Acc: 46.15%, Val Loss: 1.2620, Val Acc: 47.58%
# Epoch [6/30], Train Loss: 1.2241, Train Acc: 50.77%, Val Loss: 1.2191, Val Acc: 50.19%
# Epoch [7/30], Train Loss: 1.1841, Train Acc: 53.46%, Val Loss: 1.3813, Val Acc: 53.19%
# Epoch [8/30], Train Loss: 1.1436, Train Acc: 56.61%, Val Loss: 1.1299, Val Acc: 58.09%
# Epoch [9/30], Train Loss: 1.0988, Train Acc: 58.59%, Val Loss: 1.1290, Val Acc: 57.96%
# Epoch [10/30], Train Loss: 1.0726, Train Acc: 60.24%, Val Loss: 1.1059, Val Acc: 58.28%
# Epoch [11/30], Train Loss: 1.0424, Train Acc: 60.70%, Val Loss: 1.0441, Val Acc: 61.57%
# Epoch [12/30], Train Loss: 1.0175, Train Acc: 61.69%, Val Loss: 1.0031, Val Acc: 62.44%
# Epoch [13/30], Train Loss: 1.0107, Train Acc: 62.68%, Val Loss: 0.9687, Val Acc: 64.18%
# Epoch [14/30], Train Loss: 0.9800, Train Acc: 63.53%, Val Loss: 0.9759, Val Acc: 63.76%
# Epoch [15/30], Train Loss: 0.9482, Train Acc: 64.79%, Val Loss: 0.9431, Val Acc: 66.46%
# Epoch [16/30], Train Loss: 0.9426, Train Acc: 64.98%, Val Loss: 0.9595, Val Acc: 63.66%
# Epoch [17/30], Train Loss: 0.9184, Train Acc: 65.65%, Val Loss: 0.9098, Val Acc: 66.37%
# Epoch [18/30], Train Loss: 0.8959, Train Acc: 66.81%, Val Loss: 0.9439, Val Acc: 65.85%
# Epoch [19/30], Train Loss: 0.8824, Train Acc: 67.29%, Val Loss: 0.8672, Val Acc: 68.46%
# Epoch [20/30], Train Loss: 0.8743, Train Acc: 67.50%, Val Loss: 0.9977, Val Acc: 63.14%
# Epoch [21/30], Train Loss: 0.8596, Train Acc: 68.38%, Val Loss: 0.9079, Val Acc: 67.53%
# Epoch [22/30], Train Loss: 0.8220, Train Acc: 68.98%, Val Loss: 0.9033, Val Acc: 68.62%
# Epoch [23/30], Train Loss: 0.8326, Train Acc: 69.77%, Val Loss: 0.8483, Val Acc: 69.56%
# Epoch [24/30], Train Loss: 0.7927, Train Acc: 71.16%, Val Loss: 0.8748, Val Acc: 67.59%
# Epoch [25/30], Train Loss: 0.7955, Train Acc: 70.80%, Val Loss: 0.8101, Val Acc: 70.88%
# Epoch [26/30], Train Loss: 0.7733, Train Acc: 71.42%, Val Loss: 0.8026, Val Acc: 70.72%
# Epoch [27/30], Train Loss: 0.7613, Train Acc: 72.58%, Val Loss: 0.8799, Val Acc: 68.52%
# Epoch [28/30], Train Loss: 0.7525, Train Acc: 72.66%, Val Loss: 0.8159, Val Acc: 71.10%
# Epoch [29/30], Train Loss: 0.7342, Train Acc: 73.11%, Val Loss: 0.8041, Val Acc: 69.62%
# Epoch [30/30], Train Loss: 0.7220, Train Acc: 73.69%, Val Loss: 0.8609, Val Acc: 70.55%
#               precision    recall  f1-score   support
#
#            0       0.76      0.59      0.66       661
#            1       0.71      0.70      0.70       565
#            2       0.63      0.76      0.69       721
#            3       0.70      0.90      0.79       580
#            4       0.78      0.56      0.66       591
#
#     accuracy                           0.70      3118
#    macro avg       0.72      0.70      0.70      3118
# weighted avg       0.71      0.70      0.70      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▃▃▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>train_loss</td><td>█▇▇▆▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▂▁▃▃▄▅▅▆▆▆▆▇▇▇▇▇▇▇█▇▇██▇██████</td></tr><tr><td>val_loss</td><td>██▇▆▆▅▇▄▄▄▃▃▃▃▂▃▂▂▂▃▂▂▁▂▁▁▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>73.69218</td></tr><tr><td>train_loss</td><td>0.722</td></tr><tr><td>val_accuracy</td><td>70.55412</td></tr><tr><td>val_loss</td><td>0.86087</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fearless-sea-88</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/zk88xqug' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/zk88xqug</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_212048-zk88xqug\logs</code>

# %%
model_pipeline("Transfer Learning - Pretrained", config_transfer_vgg["pretrained"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_213837-s7khki8d</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/s7khki8d' target="_blank">zesty-haze-89</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/s7khki8d' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/s7khki8d</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_PRETRAINED', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 30, 'hidden_dim': 128, 'dropout': 0.2}
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 66,309
# Non-trainable params: 14,714,688
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - Pretrained with 30 epochs...
# Epoch [1/30], Train Loss: 1.4829, Train Acc: 38.45%, Val Loss: 1.3709, Val Acc: 43.14%
# Epoch [2/30], Train Loss: 1.3098, Train Acc: 49.22%, Val Loss: 1.2848, Val Acc: 46.33%
# Epoch [3/30], Train Loss: 1.2479, Train Acc: 52.11%, Val Loss: 1.2285, Val Acc: 49.81%
# Epoch [4/30], Train Loss: 1.2158, Train Acc: 52.82%, Val Loss: 1.1924, Val Acc: 51.61%
# Epoch [5/30], Train Loss: 1.1784, Train Acc: 54.42%, Val Loss: 1.1880, Val Acc: 51.55%
# Epoch [6/30], Train Loss: 1.1622, Train Acc: 55.30%, Val Loss: 1.1595, Val Acc: 53.51%
# Epoch [7/30], Train Loss: 1.1520, Train Acc: 55.23%, Val Loss: 1.1503, Val Acc: 54.09%
# Epoch [8/30], Train Loss: 1.1415, Train Acc: 56.04%, Val Loss: 1.1338, Val Acc: 55.12%
# Epoch [9/30], Train Loss: 1.1306, Train Acc: 56.88%, Val Loss: 1.1224, Val Acc: 55.41%
# Epoch [10/30], Train Loss: 1.1068, Train Acc: 57.42%, Val Loss: 1.1126, Val Acc: 56.35%
# Epoch [11/30], Train Loss: 1.1141, Train Acc: 57.59%, Val Loss: 1.1204, Val Acc: 55.70%
# Epoch [12/30], Train Loss: 1.0994, Train Acc: 58.07%, Val Loss: 1.1055, Val Acc: 56.41%
# Epoch [13/30], Train Loss: 1.1105, Train Acc: 57.16%, Val Loss: 1.0951, Val Acc: 56.57%
# Epoch [14/30], Train Loss: 1.0887, Train Acc: 58.48%, Val Loss: 1.1043, Val Acc: 56.64%
# Epoch [15/30], Train Loss: 1.0817, Train Acc: 59.02%, Val Loss: 1.0950, Val Acc: 57.25%
# Epoch [16/30], Train Loss: 1.0738, Train Acc: 59.25%, Val Loss: 1.0890, Val Acc: 57.28%
# Epoch [17/30], Train Loss: 1.0664, Train Acc: 59.26%, Val Loss: 1.0720, Val Acc: 58.70%
# Epoch [18/30], Train Loss: 1.0642, Train Acc: 58.92%, Val Loss: 1.0757, Val Acc: 58.41%
# Epoch [19/30], Train Loss: 1.0668, Train Acc: 59.21%, Val Loss: 1.0651, Val Acc: 58.83%
# Epoch [20/30], Train Loss: 1.0683, Train Acc: 58.91%, Val Loss: 1.0720, Val Acc: 58.25%
# Epoch [21/30], Train Loss: 1.0534, Train Acc: 60.05%, Val Loss: 1.0619, Val Acc: 58.96%
# Epoch [22/30], Train Loss: 1.0526, Train Acc: 59.65%, Val Loss: 1.0547, Val Acc: 59.44%
# Epoch [23/30], Train Loss: 1.0512, Train Acc: 58.98%, Val Loss: 1.0579, Val Acc: 58.60%
# Epoch [24/30], Train Loss: 1.0482, Train Acc: 59.42%, Val Loss: 1.0494, Val Acc: 59.18%
# Epoch [25/30], Train Loss: 1.0369, Train Acc: 60.15%, Val Loss: 1.0454, Val Acc: 59.34%
# Epoch [26/30], Train Loss: 1.0158, Train Acc: 61.15%, Val Loss: 1.0383, Val Acc: 59.86%
# Epoch [27/30], Train Loss: 1.0303, Train Acc: 60.44%, Val Loss: 1.0241, Val Acc: 61.05%
# Epoch [28/30], Train Loss: 1.0309, Train Acc: 60.74%, Val Loss: 1.0362, Val Acc: 59.89%
# Epoch [29/30], Train Loss: 1.0153, Train Acc: 60.96%, Val Loss: 1.0306, Val Acc: 60.37%
# Epoch [30/30], Train Loss: 1.0107, Train Acc: 61.33%, Val Loss: 1.0394, Val Acc: 59.89%
#               precision    recall  f1-score   support
#
#            0       0.62      0.46      0.52       661
#            1       0.61      0.60      0.60       565
#            2       0.67      0.66      0.66       721
#            3       0.63      0.63      0.63       580
#            4       0.49      0.64      0.55       591
#
#     accuracy                           0.60      3118
#    macro avg       0.60      0.60      0.59      3118
# weighted avg       0.60      0.60      0.60      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇█▇▇▇██████</td></tr><tr><td>train_loss</td><td>█▅▅▄▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▄▄▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>val_loss</td><td>█▆▅▄▄▄▄▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>61.32985</td></tr><tr><td>train_loss</td><td>1.01074</td></tr><tr><td>val_accuracy</td><td>59.89046</td></tr><tr><td>val_loss</td><td>1.03941</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">zesty-haze-89</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/s7khki8d' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/s7khki8d</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_213837-s7khki8d\logs</code>

# %%
model_pipeline("Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_215727-51roh1tt</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/51roh1tt' target="_blank">ruby-fire-90</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/51roh1tt' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/51roh1tt</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Transfer Learning - Finetune with 15 epochs...
# Epoch [1/15], Train Loss: 1.1482, Train Acc: 55.69%, Val Loss: 0.9300, Val Acc: 66.53%
# Epoch [2/15], Train Loss: 0.8917, Train Acc: 67.81%, Val Loss: 0.9465, Val Acc: 67.14%
# Epoch [3/15], Train Loss: 0.7831, Train Acc: 71.23%, Val Loss: 0.7209, Val Acc: 75.35%
# Epoch [4/15], Train Loss: 0.7174, Train Acc: 73.91%, Val Loss: 0.8664, Val Acc: 73.84%
# Epoch [5/15], Train Loss: 0.6653, Train Acc: 76.07%, Val Loss: 0.6415, Val Acc: 76.90%
# Epoch [6/15], Train Loss: 0.6028, Train Acc: 78.57%, Val Loss: 0.6545, Val Acc: 78.93%
# Epoch [7/15], Train Loss: 0.5705, Train Acc: 79.30%, Val Loss: 0.6375, Val Acc: 78.48%
# Epoch [8/15], Train Loss: 0.5402, Train Acc: 80.40%, Val Loss: 0.6049, Val Acc: 79.67%
# Epoch [9/15], Train Loss: 0.5117, Train Acc: 81.64%, Val Loss: 0.6040, Val Acc: 79.38%
# Epoch [10/15], Train Loss: 0.4713, Train Acc: 83.04%, Val Loss: 0.5978, Val Acc: 80.57%
# Epoch [11/15], Train Loss: 0.4522, Train Acc: 83.74%, Val Loss: 0.6448, Val Acc: 78.67%
# Epoch [12/15], Train Loss: 0.4389, Train Acc: 84.75%, Val Loss: 0.6298, Val Acc: 79.35%
# Epoch [13/15], Train Loss: 0.4014, Train Acc: 86.00%, Val Loss: 0.6724, Val Acc: 78.35%
# Epoch [14/15], Train Loss: 0.3783, Train Acc: 86.22%, Val Loss: 0.5830, Val Acc: 81.64%
# Epoch [15/15], Train Loss: 0.3729, Train Acc: 87.10%, Val Loss: 0.7456, Val Acc: 77.93%
#               precision    recall  f1-score   support
#
#            0       0.82      0.71      0.76       661
#            1       0.92      0.68      0.78       565
#            2       0.87      0.74      0.80       721
#            3       0.69      0.95      0.80       580
#            4       0.68      0.82      0.74       591
#
#     accuracy                           0.78      3118
#    macro avg       0.79      0.78      0.78      3118
# weighted avg       0.80      0.78      0.78      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▄▅▆▆▆▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▅▄▆▇▇▇▇█▇▇▆█▆</td></tr><tr><td>val_loss</td><td>██▄▆▂▂▂▁▁▁▂▂▃▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>87.10077</td></tr><tr><td>train_loss</td><td>0.3729</td></tr><tr><td>val_accuracy</td><td>77.9317</td></tr><tr><td>val_loss</td><td>0.74556</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ruby-fire-90</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/51roh1tt' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/51roh1tt</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_215727-51roh1tt\logs</code>

# %%
def custom_model_pipeline(name, config):
    
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, custom_train_loader, custom_val_loader, custom_full_dataset)

# %%
custom_model_pipeline("Custom Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_220728-rnt5t3s7</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rnt5t3s7' target="_blank">chocolate-tree-91</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rnt5t3s7' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rnt5t3s7</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Custom Transfer Learning - Finetune with 15 epochs...
# Epoch [1/15], Train Loss: 1.6215, Train Acc: 26.56%, Val Loss: 1.6057, Val Acc: 36.65%
# Epoch [2/15], Train Loss: 1.5254, Train Acc: 34.01%, Val Loss: 1.5177, Val Acc: 41.48%
# Epoch [3/15], Train Loss: 1.4371, Train Acc: 43.75%, Val Loss: 1.3395, Val Acc: 51.42%
# Epoch [4/15], Train Loss: 1.2999, Train Acc: 48.44%, Val Loss: 1.3227, Val Acc: 48.58%
# Epoch [5/15], Train Loss: 1.2555, Train Acc: 51.80%, Val Loss: 1.2585, Val Acc: 50.57%
# Epoch [6/15], Train Loss: 1.2249, Train Acc: 52.16%, Val Loss: 1.1389, Val Acc: 59.38%
# Epoch [7/15], Train Loss: 1.1134, Train Acc: 59.01%, Val Loss: 1.2129, Val Acc: 55.40%
# Epoch [8/15], Train Loss: 1.0613, Train Acc: 60.58%, Val Loss: 1.1060, Val Acc: 63.07%
# Epoch [9/15], Train Loss: 0.9844, Train Acc: 65.26%, Val Loss: 1.0760, Val Acc: 63.64%
# Epoch [10/15], Train Loss: 0.9119, Train Acc: 67.31%, Val Loss: 1.1969, Val Acc: 59.94%
# Epoch [11/15], Train Loss: 0.8191, Train Acc: 71.03%, Val Loss: 1.1693, Val Acc: 62.78%
# Epoch [12/15], Train Loss: 0.7934, Train Acc: 71.88%, Val Loss: 1.0399, Val Acc: 63.35%
# Epoch [13/15], Train Loss: 0.7027, Train Acc: 74.16%, Val Loss: 1.1386, Val Acc: 62.78%
# Epoch [14/15], Train Loss: 0.6817, Train Acc: 76.20%, Val Loss: 1.0319, Val Acc: 67.61%
# Epoch [15/15], Train Loss: 0.6734, Train Acc: 77.16%, Val Loss: 1.0992, Val Acc: 65.06%
#               precision    recall  f1-score   support
#
#            0       0.47      0.64      0.54        72
#            1       0.64      0.64      0.64        66
#            2       0.76      0.68      0.72        79
#            3       0.72      0.69      0.71        68
#            4       0.67      0.54      0.60        74
#
#     accuracy                           0.64       359
#    macro avg       0.65      0.64      0.64       359
# weighted avg       0.65      0.64      0.64       359
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▃▄▄▅▅▆▆▇▇▇███</td></tr><tr><td>train_loss</td><td>█▇▇▆▅▅▄▄▃▃▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▄▄▄▆▅▇▇▆▇▇▇█▇</td></tr><tr><td>val_loss</td><td>█▇▅▅▄▂▃▂▂▃▃▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>77.16346</td></tr><tr><td>train_loss</td><td>0.67338</td></tr><tr><td>val_accuracy</td><td>65.05682</td></tr><tr><td>val_loss</td><td>1.09919</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">chocolate-tree-91</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rnt5t3s7' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rnt5t3s7</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_220728-rnt5t3s7\logs</code>

# %% [markdown]
# ## Alle Daten

# %%
def all_model_pipeline(name, config):
    with wandb.init(project=WANDB_PROJECT, config=config):
        config = wandb.config

        model, optimizer, loss_fn = get_model(config)

        run_training_loop(name, model, config, optimizer, loss_fn, all_train_loader, all_val_loader, all_full_dataset)

# %%
all_model_pipeline("Custom Transfer Learning - Finetune", config_transfer_vgg["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_221113-6ags26kc</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6ags26kc' target="_blank">volcanic-vortex-92</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6ags26kc' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6ags26kc</a>
# {'model_type': 'TRANSFER_VGG', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,792
#               ReLU-2           [-1, 64, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          36,928
#               ReLU-4           [-1, 64, 32, 32]               0
#          MaxPool2d-5           [-1, 64, 16, 16]               0
#             Conv2d-6          [-1, 128, 16, 16]          73,856
#               ReLU-7          [-1, 128, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]         147,584
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#            Conv2d-15            [-1, 256, 8, 8]         590,080
#              ReLU-16            [-1, 256, 8, 8]               0
#         MaxPool2d-17            [-1, 256, 4, 4]               0
#            Conv2d-18            [-1, 512, 4, 4]       1,180,160
#              ReLU-19            [-1, 512, 4, 4]               0
#            Conv2d-20            [-1, 512, 4, 4]       2,359,808
#              ReLU-21            [-1, 512, 4, 4]               0
#            Conv2d-22            [-1, 512, 4, 4]       2,359,808
#              ReLU-23            [-1, 512, 4, 4]               0
#         MaxPool2d-24            [-1, 512, 2, 2]               0
#            Conv2d-25            [-1, 512, 2, 2]       2,359,808
#              ReLU-26            [-1, 512, 2, 2]               0
#            Conv2d-27            [-1, 512, 2, 2]       2,359,808
#              ReLU-28            [-1, 512, 2, 2]               0
#            Conv2d-29            [-1, 512, 2, 2]       2,359,808
#              ReLU-30            [-1, 512, 2, 2]               0
#         MaxPool2d-31            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 5]             645
#               VGG-38                    [-1, 5]               0
# ================================================================
# Total params: 14,780,997
# Trainable params: 14,780,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.47
# Params size (MB): 56.39
# Estimated Total Size (MB): 60.86
# ----------------------------------------------------------------
# Start training for Custom Transfer Learning - Finetune with 15 epochs...
# Epoch [1/15], Train Loss: 1.2468, Train Acc: 50.19%, Val Loss: 1.0069, Val Acc: 62.67%
# Epoch [2/15], Train Loss: 0.9723, Train Acc: 63.81%, Val Loss: 0.8600, Val Acc: 68.20%
# Epoch [3/15], Train Loss: 0.8790, Train Acc: 67.72%, Val Loss: 0.7711, Val Acc: 72.21%
# Epoch [4/15], Train Loss: 0.8112, Train Acc: 70.52%, Val Loss: 0.7816, Val Acc: 71.43%
# Epoch [5/15], Train Loss: 0.7631, Train Acc: 72.23%, Val Loss: 0.7189, Val Acc: 73.85%
# Epoch [6/15], Train Loss: 0.7247, Train Acc: 73.22%, Val Loss: 0.7557, Val Acc: 72.55%
# Epoch [7/15], Train Loss: 0.6745, Train Acc: 75.88%, Val Loss: 0.7180, Val Acc: 74.54%
# Epoch [8/15], Train Loss: 0.6277, Train Acc: 77.61%, Val Loss: 0.7251, Val Acc: 73.96%
# Epoch [9/15], Train Loss: 0.5986, Train Acc: 78.06%, Val Loss: 0.6274, Val Acc: 77.51%
# Epoch [10/15], Train Loss: 0.5669, Train Acc: 79.89%, Val Loss: 0.6484, Val Acc: 77.79%
# Epoch [11/15], Train Loss: 0.5422, Train Acc: 80.27%, Val Loss: 0.6657, Val Acc: 76.73%
# Epoch [12/15], Train Loss: 0.5082, Train Acc: 81.35%, Val Loss: 0.6358, Val Acc: 78.57%
# Epoch [13/15], Train Loss: 0.4778, Train Acc: 82.86%, Val Loss: 0.6445, Val Acc: 77.62%
# Epoch [14/15], Train Loss: 0.4519, Train Acc: 83.92%, Val Loss: 0.6174, Val Acc: 79.41%
# Epoch [15/15], Train Loss: 0.4312, Train Acc: 84.89%, Val Loss: 0.6878, Val Acc: 78.34%
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74       698
#            1       0.69      0.93      0.79       650
#            2       0.82      0.76      0.79       723
#            3       0.84      0.89      0.87       709
#            4       0.82      0.64      0.72       697
#
#     accuracy                           0.78      3477
#    macro avg       0.79      0.78      0.78      3477
# weighted avg       0.79      0.78      0.78      3477
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▅▅▅▆▆▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▃▃▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▅▆▅▆▆▇▇▇█▇██</td></tr><tr><td>val_loss</td><td>█▅▄▄▃▃▃▃▁▂▂▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>84.89377</td></tr><tr><td>train_loss</td><td>0.43116</td></tr><tr><td>val_accuracy</td><td>78.34101</td></tr><tr><td>val_loss</td><td>0.68784</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">volcanic-vortex-92</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6ags26kc' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6ags26kc</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_221113-6ags26kc\logs</code>

# %% [markdown]
# ## Finetuning with Custom Data and ResNet50

# %%
custom_model_pipeline("Custom Data Transfer Learning with ResNet50", config_transfer_rn["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_222139-259z8xe5</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/259z8xe5' target="_blank">sandy-vortex-93</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/259z8xe5' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/259z8xe5</a>
# {'model_type': 'TRANSFER_RN', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to C:\Users\Windows 11 Pro/.cache\torch\hub\checkpoints\resnet50-0676ba61.pth
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100.0%
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]           4,096
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-12            [-1, 256, 8, 8]             512
#            Conv2d-13            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-14            [-1, 256, 8, 8]             512
#              ReLU-15            [-1, 256, 8, 8]               0
#        Bottleneck-16            [-1, 256, 8, 8]               0
#            Conv2d-17             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-18             [-1, 64, 8, 8]             128
#              ReLU-19             [-1, 64, 8, 8]               0
#            Conv2d-20             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-21             [-1, 64, 8, 8]             128
#              ReLU-22             [-1, 64, 8, 8]               0
#            Conv2d-23            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-24            [-1, 256, 8, 8]             512
#              ReLU-25            [-1, 256, 8, 8]               0
#        Bottleneck-26            [-1, 256, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-28             [-1, 64, 8, 8]             128
#              ReLU-29             [-1, 64, 8, 8]               0
#            Conv2d-30             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-31             [-1, 64, 8, 8]             128
#              ReLU-32             [-1, 64, 8, 8]               0
#            Conv2d-33            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-34            [-1, 256, 8, 8]             512
#              ReLU-35            [-1, 256, 8, 8]               0
#        Bottleneck-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 128, 8, 8]          32,768
#       BatchNorm2d-38            [-1, 128, 8, 8]             256
#              ReLU-39            [-1, 128, 8, 8]               0
#            Conv2d-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#            Conv2d-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#            Conv2d-45            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-46            [-1, 512, 4, 4]           1,024
#              ReLU-47            [-1, 512, 4, 4]               0
#        Bottleneck-48            [-1, 512, 4, 4]               0
#            Conv2d-49            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#            Conv2d-52            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-53            [-1, 128, 4, 4]             256
#              ReLU-54            [-1, 128, 4, 4]               0
#            Conv2d-55            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 512, 4, 4]           1,024
#              ReLU-57            [-1, 512, 4, 4]               0
#        Bottleneck-58            [-1, 512, 4, 4]               0
#            Conv2d-59            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-60            [-1, 128, 4, 4]             256
#              ReLU-61            [-1, 128, 4, 4]               0
#            Conv2d-62            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-63            [-1, 128, 4, 4]             256
#              ReLU-64            [-1, 128, 4, 4]               0
#            Conv2d-65            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-66            [-1, 512, 4, 4]           1,024
#              ReLU-67            [-1, 512, 4, 4]               0
#        Bottleneck-68            [-1, 512, 4, 4]               0
#            Conv2d-69            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-70            [-1, 128, 4, 4]             256
#              ReLU-71            [-1, 128, 4, 4]               0
#            Conv2d-72            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-73            [-1, 128, 4, 4]             256
#              ReLU-74            [-1, 128, 4, 4]               0
#            Conv2d-75            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-76            [-1, 512, 4, 4]           1,024
#              ReLU-77            [-1, 512, 4, 4]               0
#        Bottleneck-78            [-1, 512, 4, 4]               0
#            Conv2d-79            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-80            [-1, 256, 4, 4]             512
#              ReLU-81            [-1, 256, 4, 4]               0
#            Conv2d-82            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-83            [-1, 256, 2, 2]             512
#              ReLU-84            [-1, 256, 2, 2]               0
#            Conv2d-85           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-86           [-1, 1024, 2, 2]           2,048
#            Conv2d-87           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-88           [-1, 1024, 2, 2]           2,048
#              ReLU-89           [-1, 1024, 2, 2]               0
#        Bottleneck-90           [-1, 1024, 2, 2]               0
#            Conv2d-91            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-92            [-1, 256, 2, 2]             512
#              ReLU-93            [-1, 256, 2, 2]               0
#            Conv2d-94            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#            Conv2d-97           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-98           [-1, 1024, 2, 2]           2,048
#              ReLU-99           [-1, 1024, 2, 2]               0
#       Bottleneck-100           [-1, 1024, 2, 2]               0
#           Conv2d-101            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-102            [-1, 256, 2, 2]             512
#             ReLU-103            [-1, 256, 2, 2]               0
#           Conv2d-104            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-105            [-1, 256, 2, 2]             512
#             ReLU-106            [-1, 256, 2, 2]               0
#           Conv2d-107           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-108           [-1, 1024, 2, 2]           2,048
#             ReLU-109           [-1, 1024, 2, 2]               0
#       Bottleneck-110           [-1, 1024, 2, 2]               0
#           Conv2d-111            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-112            [-1, 256, 2, 2]             512
#             ReLU-113            [-1, 256, 2, 2]               0
#           Conv2d-114            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-115            [-1, 256, 2, 2]             512
#             ReLU-116            [-1, 256, 2, 2]               0
#           Conv2d-117           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-118           [-1, 1024, 2, 2]           2,048
#             ReLU-119           [-1, 1024, 2, 2]               0
#       Bottleneck-120           [-1, 1024, 2, 2]               0
#           Conv2d-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#           Conv2d-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#           Conv2d-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
#             ReLU-129           [-1, 1024, 2, 2]               0
#       Bottleneck-130           [-1, 1024, 2, 2]               0
#           Conv2d-131            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-132            [-1, 256, 2, 2]             512
#             ReLU-133            [-1, 256, 2, 2]               0
#           Conv2d-134            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-135            [-1, 256, 2, 2]             512
#             ReLU-136            [-1, 256, 2, 2]               0
#           Conv2d-137           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-138           [-1, 1024, 2, 2]           2,048
#             ReLU-139           [-1, 1024, 2, 2]               0
#       Bottleneck-140           [-1, 1024, 2, 2]               0
#           Conv2d-141            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-142            [-1, 512, 2, 2]           1,024
#             ReLU-143            [-1, 512, 2, 2]               0
#           Conv2d-144            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-145            [-1, 512, 1, 1]           1,024
#             ReLU-146            [-1, 512, 1, 1]               0
#           Conv2d-147           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 1, 1]           4,096
#           Conv2d-149           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 1, 1]           4,096
#             ReLU-151           [-1, 2048, 1, 1]               0
#       Bottleneck-152           [-1, 2048, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-154            [-1, 512, 1, 1]           1,024
#             ReLU-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-157            [-1, 512, 1, 1]           1,024
#             ReLU-158            [-1, 512, 1, 1]               0
#           Conv2d-159           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 1, 1]           4,096
#             ReLU-161           [-1, 2048, 1, 1]               0
#       Bottleneck-162           [-1, 2048, 1, 1]               0
#           Conv2d-163            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-164            [-1, 512, 1, 1]           1,024
#             ReLU-165            [-1, 512, 1, 1]               0
#           Conv2d-166            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-167            [-1, 512, 1, 1]           1,024
#             ReLU-168            [-1, 512, 1, 1]               0
#           Conv2d-169           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 1, 1]           4,096
#             ReLU-171           [-1, 2048, 1, 1]               0
#       Bottleneck-172           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#          Flatten-174                 [-1, 2048]               0
#           Linear-175                  [-1, 128]         262,272
#             ReLU-176                  [-1, 128]               0
#          Dropout-177                  [-1, 128]               0
#           Linear-178                    [-1, 5]             645
#           ResNet-179                    [-1, 5]               0
# ================================================================
# Total params: 23,770,949
# Trainable params: 23,770,949
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.88
# Params size (MB): 90.68
# Estimated Total Size (MB): 96.57
# ----------------------------------------------------------------
# Start training for Custom Data Transfer Learning with ResNet50 with 15 epochs...
# Epoch [1/15], Train Loss: 1.6305, Train Acc: 23.80%, Val Loss: 3.8764, Val Acc: 30.97%
# Epoch [2/15], Train Loss: 1.5496, Train Acc: 33.89%, Val Loss: 2.1274, Val Acc: 39.77%
# Epoch [3/15], Train Loss: 1.4677, Train Acc: 38.58%, Val Loss: 8.2703, Val Acc: 32.39%
# Epoch [4/15], Train Loss: 1.3811, Train Acc: 42.91%, Val Loss: 1.8373, Val Acc: 38.07%
# Epoch [5/15], Train Loss: 1.3135, Train Acc: 49.28%, Val Loss: 1.5818, Val Acc: 48.58%
# Epoch [6/15], Train Loss: 1.2693, Train Acc: 52.16%, Val Loss: 1.7106, Val Acc: 34.38%
# Epoch [7/15], Train Loss: 1.2060, Train Acc: 54.33%, Val Loss: 1.3099, Val Acc: 51.14%
# Epoch [8/15], Train Loss: 1.1677, Train Acc: 55.17%, Val Loss: 1.2391, Val Acc: 56.53%
# Epoch [9/15], Train Loss: 1.0639, Train Acc: 60.34%, Val Loss: 1.3457, Val Acc: 56.25%
# Epoch [10/15], Train Loss: 1.0867, Train Acc: 60.22%, Val Loss: 1.5288, Val Acc: 51.14%
# Epoch [11/15], Train Loss: 1.0295, Train Acc: 63.10%, Val Loss: 1.1269, Val Acc: 59.94%
# Epoch [12/15], Train Loss: 1.0041, Train Acc: 63.46%, Val Loss: 1.1349, Val Acc: 58.52%
# Epoch [13/15], Train Loss: 0.9622, Train Acc: 63.10%, Val Loss: 1.0938, Val Acc: 61.65%
# Epoch [14/15], Train Loss: 0.8927, Train Acc: 66.59%, Val Loss: 1.1396, Val Acc: 60.80%
# Epoch [15/15], Train Loss: 0.8797, Train Acc: 68.15%, Val Loss: 1.0508, Val Acc: 63.07%
#               precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53        72
#            1       0.55      0.47      0.51        66
#            2       0.80      0.70      0.74        79
#            3       0.65      0.66      0.66        68
#            4       0.54      0.74      0.63        74
#
#     accuracy                           0.62       359
#    macro avg       0.62      0.61      0.61       359
# weighted avg       0.63      0.62      0.62       359
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▃▄▅▅▆▆▇▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▅▄▄▃▃▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▁▃▅▂▅▇▇▅▇▇███</td></tr><tr><td>val_loss</td><td>▄▂█▂▂▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>68.14904</td></tr><tr><td>train_loss</td><td>0.87971</td></tr><tr><td>val_accuracy</td><td>63.06818</td></tr><tr><td>val_loss</td><td>1.05082</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sandy-vortex-93</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/259z8xe5' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/259z8xe5</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_222139-259z8xe5\logs</code>

# %%
all_model_pipeline("All Data Transfer Learning with ResNet50", config_transfer_rn["finetune"])
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_222530-rwgfy300</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rwgfy300' target="_blank">neat-firebrand-94</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rwgfy300' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rwgfy300</a>
# {'model_type': 'TRANSFER_RN', 'model_subtype': 'TRAIN_FINETUNE', 'batch_size': 16, 'learning_rate': 0.0001, 'epochs': 15, 'hidden_dim': 128, 'dropout': 0.2}
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]           4,096
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-12            [-1, 256, 8, 8]             512
#            Conv2d-13            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-14            [-1, 256, 8, 8]             512
#              ReLU-15            [-1, 256, 8, 8]               0
#        Bottleneck-16            [-1, 256, 8, 8]               0
#            Conv2d-17             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-18             [-1, 64, 8, 8]             128
#              ReLU-19             [-1, 64, 8, 8]               0
#            Conv2d-20             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-21             [-1, 64, 8, 8]             128
#              ReLU-22             [-1, 64, 8, 8]               0
#            Conv2d-23            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-24            [-1, 256, 8, 8]             512
#              ReLU-25            [-1, 256, 8, 8]               0
#        Bottleneck-26            [-1, 256, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]          16,384
#       BatchNorm2d-28             [-1, 64, 8, 8]             128
#              ReLU-29             [-1, 64, 8, 8]               0
#            Conv2d-30             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-31             [-1, 64, 8, 8]             128
#              ReLU-32             [-1, 64, 8, 8]               0
#            Conv2d-33            [-1, 256, 8, 8]          16,384
#       BatchNorm2d-34            [-1, 256, 8, 8]             512
#              ReLU-35            [-1, 256, 8, 8]               0
#        Bottleneck-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 128, 8, 8]          32,768
#       BatchNorm2d-38            [-1, 128, 8, 8]             256
#              ReLU-39            [-1, 128, 8, 8]               0
#            Conv2d-40            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#            Conv2d-43            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-44            [-1, 512, 4, 4]           1,024
#            Conv2d-45            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-46            [-1, 512, 4, 4]           1,024
#              ReLU-47            [-1, 512, 4, 4]               0
#        Bottleneck-48            [-1, 512, 4, 4]               0
#            Conv2d-49            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-50            [-1, 128, 4, 4]             256
#              ReLU-51            [-1, 128, 4, 4]               0
#            Conv2d-52            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-53            [-1, 128, 4, 4]             256
#              ReLU-54            [-1, 128, 4, 4]               0
#            Conv2d-55            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-56            [-1, 512, 4, 4]           1,024
#              ReLU-57            [-1, 512, 4, 4]               0
#        Bottleneck-58            [-1, 512, 4, 4]               0
#            Conv2d-59            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-60            [-1, 128, 4, 4]             256
#              ReLU-61            [-1, 128, 4, 4]               0
#            Conv2d-62            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-63            [-1, 128, 4, 4]             256
#              ReLU-64            [-1, 128, 4, 4]               0
#            Conv2d-65            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-66            [-1, 512, 4, 4]           1,024
#              ReLU-67            [-1, 512, 4, 4]               0
#        Bottleneck-68            [-1, 512, 4, 4]               0
#            Conv2d-69            [-1, 128, 4, 4]          65,536
#       BatchNorm2d-70            [-1, 128, 4, 4]             256
#              ReLU-71            [-1, 128, 4, 4]               0
#            Conv2d-72            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-73            [-1, 128, 4, 4]             256
#              ReLU-74            [-1, 128, 4, 4]               0
#            Conv2d-75            [-1, 512, 4, 4]          65,536
#       BatchNorm2d-76            [-1, 512, 4, 4]           1,024
#              ReLU-77            [-1, 512, 4, 4]               0
#        Bottleneck-78            [-1, 512, 4, 4]               0
#            Conv2d-79            [-1, 256, 4, 4]         131,072
#       BatchNorm2d-80            [-1, 256, 4, 4]             512
#              ReLU-81            [-1, 256, 4, 4]               0
#            Conv2d-82            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-83            [-1, 256, 2, 2]             512
#              ReLU-84            [-1, 256, 2, 2]               0
#            Conv2d-85           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-86           [-1, 1024, 2, 2]           2,048
#            Conv2d-87           [-1, 1024, 2, 2]         524,288
#       BatchNorm2d-88           [-1, 1024, 2, 2]           2,048
#              ReLU-89           [-1, 1024, 2, 2]               0
#        Bottleneck-90           [-1, 1024, 2, 2]               0
#            Conv2d-91            [-1, 256, 2, 2]         262,144
#       BatchNorm2d-92            [-1, 256, 2, 2]             512
#              ReLU-93            [-1, 256, 2, 2]               0
#            Conv2d-94            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-95            [-1, 256, 2, 2]             512
#              ReLU-96            [-1, 256, 2, 2]               0
#            Conv2d-97           [-1, 1024, 2, 2]         262,144
#       BatchNorm2d-98           [-1, 1024, 2, 2]           2,048
#              ReLU-99           [-1, 1024, 2, 2]               0
#       Bottleneck-100           [-1, 1024, 2, 2]               0
#           Conv2d-101            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-102            [-1, 256, 2, 2]             512
#             ReLU-103            [-1, 256, 2, 2]               0
#           Conv2d-104            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-105            [-1, 256, 2, 2]             512
#             ReLU-106            [-1, 256, 2, 2]               0
#           Conv2d-107           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-108           [-1, 1024, 2, 2]           2,048
#             ReLU-109           [-1, 1024, 2, 2]               0
#       Bottleneck-110           [-1, 1024, 2, 2]               0
#           Conv2d-111            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-112            [-1, 256, 2, 2]             512
#             ReLU-113            [-1, 256, 2, 2]               0
#           Conv2d-114            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-115            [-1, 256, 2, 2]             512
#             ReLU-116            [-1, 256, 2, 2]               0
#           Conv2d-117           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-118           [-1, 1024, 2, 2]           2,048
#             ReLU-119           [-1, 1024, 2, 2]               0
#       Bottleneck-120           [-1, 1024, 2, 2]               0
#           Conv2d-121            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-122            [-1, 256, 2, 2]             512
#             ReLU-123            [-1, 256, 2, 2]               0
#           Conv2d-124            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-125            [-1, 256, 2, 2]             512
#             ReLU-126            [-1, 256, 2, 2]               0
#           Conv2d-127           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-128           [-1, 1024, 2, 2]           2,048
#             ReLU-129           [-1, 1024, 2, 2]               0
#       Bottleneck-130           [-1, 1024, 2, 2]               0
#           Conv2d-131            [-1, 256, 2, 2]         262,144
#      BatchNorm2d-132            [-1, 256, 2, 2]             512
#             ReLU-133            [-1, 256, 2, 2]               0
#           Conv2d-134            [-1, 256, 2, 2]         589,824
#      BatchNorm2d-135            [-1, 256, 2, 2]             512
#             ReLU-136            [-1, 256, 2, 2]               0
#           Conv2d-137           [-1, 1024, 2, 2]         262,144
#      BatchNorm2d-138           [-1, 1024, 2, 2]           2,048
#             ReLU-139           [-1, 1024, 2, 2]               0
#       Bottleneck-140           [-1, 1024, 2, 2]               0
#           Conv2d-141            [-1, 512, 2, 2]         524,288
#      BatchNorm2d-142            [-1, 512, 2, 2]           1,024
#             ReLU-143            [-1, 512, 2, 2]               0
#           Conv2d-144            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-145            [-1, 512, 1, 1]           1,024
#             ReLU-146            [-1, 512, 1, 1]               0
#           Conv2d-147           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 1, 1]           4,096
#           Conv2d-149           [-1, 2048, 1, 1]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 1, 1]           4,096
#             ReLU-151           [-1, 2048, 1, 1]               0
#       Bottleneck-152           [-1, 2048, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-154            [-1, 512, 1, 1]           1,024
#             ReLU-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-157            [-1, 512, 1, 1]           1,024
#             ReLU-158            [-1, 512, 1, 1]               0
#           Conv2d-159           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 1, 1]           4,096
#             ReLU-161           [-1, 2048, 1, 1]               0
#       Bottleneck-162           [-1, 2048, 1, 1]               0
#           Conv2d-163            [-1, 512, 1, 1]       1,048,576
#      BatchNorm2d-164            [-1, 512, 1, 1]           1,024
#             ReLU-165            [-1, 512, 1, 1]               0
#           Conv2d-166            [-1, 512, 1, 1]       2,359,296
#      BatchNorm2d-167            [-1, 512, 1, 1]           1,024
#             ReLU-168            [-1, 512, 1, 1]               0
#           Conv2d-169           [-1, 2048, 1, 1]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 1, 1]           4,096
#             ReLU-171           [-1, 2048, 1, 1]               0
#       Bottleneck-172           [-1, 2048, 1, 1]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#          Flatten-174                 [-1, 2048]               0
#           Linear-175                  [-1, 128]         262,272
#             ReLU-176                  [-1, 128]               0
#          Dropout-177                  [-1, 128]               0
#           Linear-178                    [-1, 5]             645
#           ResNet-179                    [-1, 5]               0
# ================================================================
# Total params: 23,770,949
# Trainable params: 23,770,949
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.88
# Params size (MB): 90.68
# Estimated Total Size (MB): 96.57
# ----------------------------------------------------------------
# Start training for All Data Transfer Learning with ResNet50 with 15 epochs...
# Epoch [1/15], Train Loss: 1.2946, Train Acc: 48.90%, Val Loss: 1.0597, Val Acc: 60.74%
# Epoch [2/15], Train Loss: 1.0997, Train Acc: 58.05%, Val Loss: 0.9316, Val Acc: 66.27%
# Epoch [3/15], Train Loss: 1.0260, Train Acc: 62.65%, Val Loss: 0.8687, Val Acc: 68.26%
# Epoch [4/15], Train Loss: 0.9543, Train Acc: 65.13%, Val Loss: 0.8390, Val Acc: 70.62%
# Epoch [5/15], Train Loss: 0.9249, Train Acc: 66.01%, Val Loss: 0.8004, Val Acc: 70.54%
# Epoch [6/15], Train Loss: 0.8914, Train Acc: 67.55%, Val Loss: 0.8123, Val Acc: 70.56%
# Epoch [7/15], Train Loss: 0.8576, Train Acc: 68.90%, Val Loss: 0.7126, Val Acc: 74.88%
# Epoch [8/15], Train Loss: 0.8176, Train Acc: 70.13%, Val Loss: 0.6991, Val Acc: 74.63%
# Epoch [9/15], Train Loss: 0.7973, Train Acc: 71.05%, Val Loss: 0.6997, Val Acc: 74.57%
# Epoch [10/15], Train Loss: 0.7616, Train Acc: 73.00%, Val Loss: 0.6777, Val Acc: 75.72%
# Epoch [11/15], Train Loss: 0.7480, Train Acc: 73.70%, Val Loss: 0.6867, Val Acc: 75.14%
# Epoch [12/15], Train Loss: 0.7189, Train Acc: 73.54%, Val Loss: 0.6903, Val Acc: 75.69%
# Epoch [13/15], Train Loss: 0.7131, Train Acc: 74.32%, Val Loss: 0.6726, Val Acc: 75.49%
# Epoch [14/15], Train Loss: 0.6796, Train Acc: 75.27%, Val Loss: 0.6834, Val Acc: 76.15%
# Epoch [15/15], Train Loss: 0.6525, Train Acc: 76.87%, Val Loss: 0.6145, Val Acc: 78.63%
#               precision    recall  f1-score   support
#
#            0       0.70      0.75      0.72       698
#            1       0.84      0.79      0.82       650
#            2       0.75      0.78      0.77       723
#            3       0.86      0.89      0.87       709
#            4       0.78      0.71      0.75       697
#
#     accuracy                           0.79      3477
#    macro avg       0.79      0.78      0.79      3477
# weighted avg       0.79      0.79      0.79      3477
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▄▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▃▃▃▂▂▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▅▅▅▇▆▆▇▇▇▇▇█</td></tr><tr><td>val_loss</td><td>█▆▅▅▄▄▃▂▂▂▂▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>76.86512</td></tr><tr><td>train_loss</td><td>0.65246</td></tr><tr><td>val_accuracy</td><td>78.62903</td></tr><tr><td>val_loss</td><td>0.61453</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">neat-firebrand-94</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rwgfy300' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/rwgfy300</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_222530-rwgfy300\logs</code>

# %% [markdown]
# ### Hyperparameteroptimisation

# %% [markdown]
# Sweep Konfigurationen (Hyperparameter Search-Space):

# %%
parameters_mlp = { 
    'model_type': {
        'value': 'MLP'},
    'epochs': {
        'value': 15}, 
    'batch_size': {
        'value': 16},
    'learning_rate': {
        'values': [0.005,0.01,0.1]},  
    'hidden_dim': {
        'values': [32,64,128,256,512]}, 
    'dropout': {
        'values': [0.0,0.1,0.2,0.3,0.4]}
    }

# %%
sweep_config = {
    "method" : "random",
    "parameters" : parameters_mlp
}

# %%
sweep_id=wandb.sweep(sweep_config,project=WANDB_PROJECT)
# Out:
# Create sweep with ID: gdpvhlxh
# Sweep URL: https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh

# %%
wandb.agent(sweep_id, function=lambda: model_pipeline("MLP"), count=10)
# Out:
# wandb: Agent Starting Run: 1s5wsbei with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0.1
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 32
# wandb: 	learning_rate: 0.01
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_231802-1s5wsbei</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/1s5wsbei' target="_blank">lemon-sweep-1</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/1s5wsbei' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/1s5wsbei</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0.1, 'epochs': 15, 'hidden_dim': 32, 'learning_rate': 0.01, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0.1, 'epochs': 15, 'hidden_dim': 32, 'learning_rate': 0.01, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 32]          98,336
#            Dropout-2                   [-1, 32]               0
#             Linear-3                    [-1, 5]             165
# ================================================================
# Total params: 98,501
# Trainable params: 98,501
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.38
# Estimated Total Size (MB): 0.39
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5704, Train Acc: 27.55%, Val Loss: 1.5545, Val Acc: 31.93%
# Epoch [2/15], Train Loss: 1.5031, Train Acc: 33.08%, Val Loss: 1.4635, Val Acc: 34.73%
# Epoch [3/15], Train Loss: 1.4702, Train Acc: 35.56%, Val Loss: 1.4314, Val Acc: 34.70%
# Epoch [4/15], Train Loss: 1.4449, Train Acc: 38.12%, Val Loss: 1.4479, Val Acc: 34.63%
# Epoch [5/15], Train Loss: 1.4322, Train Acc: 39.22%, Val Loss: 1.3911, Val Acc: 43.36%
# Epoch [6/15], Train Loss: 1.4138, Train Acc: 40.25%, Val Loss: 1.3827, Val Acc: 42.85%
# Epoch [7/15], Train Loss: 1.4048, Train Acc: 40.58%, Val Loss: 1.3665, Val Acc: 43.62%
# Epoch [8/15], Train Loss: 1.3931, Train Acc: 41.45%, Val Loss: 1.3894, Val Acc: 42.30%
# Epoch [9/15], Train Loss: 1.3833, Train Acc: 42.40%, Val Loss: 1.3678, Val Acc: 44.30%
# Epoch [10/15], Train Loss: 1.3780, Train Acc: 42.73%, Val Loss: 1.3504, Val Acc: 44.33%
# Epoch [11/15], Train Loss: 1.3729, Train Acc: 42.90%, Val Loss: 1.3480, Val Acc: 46.68%
# Epoch [12/15], Train Loss: 1.3687, Train Acc: 42.86%, Val Loss: 1.3546, Val Acc: 42.14%
# Epoch [13/15], Train Loss: 1.3663, Train Acc: 42.79%, Val Loss: 1.3395, Val Acc: 43.78%
# Epoch [14/15], Train Loss: 1.3579, Train Acc: 43.69%, Val Loss: 1.3370, Val Acc: 45.43%
# Epoch [15/15], Train Loss: 1.3539, Train Acc: 43.71%, Val Loss: 1.3371, Val Acc: 45.17%
#               precision    recall  f1-score   support
#
#            0       0.70      0.27      0.39       661
#            1       0.39      0.49      0.43       565
#            2       0.64      0.27      0.38       721
#            3       0.36      0.85      0.51       580
#            4       0.53      0.43      0.48       591
#
#     accuracy                           0.45      3118
#    macro avg       0.52      0.46      0.44      3118
# weighted avg       0.53      0.45      0.43      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▄▆▆▇▇▇▇██████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▂▂▆▆▇▆▇▇█▆▇▇▇</td></tr><tr><td>val_loss</td><td>█▅▄▅▃▂▂▃▂▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>43.7087</td></tr><tr><td>train_loss</td><td>1.35386</td></tr><tr><td>val_accuracy</td><td>45.16753</td></tr><tr><td>val_loss</td><td>1.33709</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lemon-sweep-1</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/1s5wsbei' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/1s5wsbei</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_231802-1s5wsbei\logs</code>
# wandb: Agent Starting Run: g4c9wu5p with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.01
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_232816-g4c9wu5p</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/g4c9wu5p' target="_blank">swept-sweep-2</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/g4c9wu5p' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/g4c9wu5p</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0, 'epochs': 15, 'hidden_dim': 256, 'learning_rate': 0.01, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0, 'epochs': 15, 'hidden_dim': 256, 'learning_rate': 0.01, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 256]         786,688
#            Dropout-2                  [-1, 256]               0
#             Linear-3                    [-1, 5]           1,285
# ================================================================
# Total params: 787,973
# Trainable params: 787,973
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 3.01
# Estimated Total Size (MB): 3.02
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5465, Train Acc: 30.49%, Val Loss: 1.5318, Val Acc: 30.38%
# Epoch [2/15], Train Loss: 1.4867, Train Acc: 33.91%, Val Loss: 1.5129, Val Acc: 30.77%
# Epoch [3/15], Train Loss: 1.4571, Train Acc: 36.54%, Val Loss: 1.5274, Val Acc: 31.83%
# Epoch [4/15], Train Loss: 1.4264, Train Acc: 39.17%, Val Loss: 1.4286, Val Acc: 36.21%
# Epoch [5/15], Train Loss: 1.4066, Train Acc: 40.43%, Val Loss: 1.3666, Val Acc: 45.01%
# Epoch [6/15], Train Loss: 1.3855, Train Acc: 41.99%, Val Loss: 1.3463, Val Acc: 45.72%
# Epoch [7/15], Train Loss: 1.3724, Train Acc: 42.73%, Val Loss: 1.3952, Val Acc: 42.30%
# Epoch [8/15], Train Loss: 1.3606, Train Acc: 43.86%, Val Loss: 1.3452, Val Acc: 44.56%
# Epoch [9/15], Train Loss: 1.3580, Train Acc: 44.12%, Val Loss: 1.3479, Val Acc: 41.85%
# Epoch [10/15], Train Loss: 1.3476, Train Acc: 44.29%, Val Loss: 1.3136, Val Acc: 47.68%
# Epoch [11/15], Train Loss: 1.3410, Train Acc: 45.11%, Val Loss: 1.3504, Val Acc: 44.91%
# Epoch [12/15], Train Loss: 1.3316, Train Acc: 45.94%, Val Loss: 1.3564, Val Acc: 42.59%
# Epoch [13/15], Train Loss: 1.3274, Train Acc: 45.57%, Val Loss: 1.3113, Val Acc: 48.84%
# Epoch [14/15], Train Loss: 1.3227, Train Acc: 46.75%, Val Loss: 1.2902, Val Acc: 47.26%
# Epoch [15/15], Train Loss: 1.3178, Train Acc: 46.70%, Val Loss: 1.3239, Val Acc: 46.07%
#               precision    recall  f1-score   support
#
#            0       0.55      0.40      0.46       661
#            1       0.31      0.75      0.44       565
#            2       0.68      0.19      0.30       721
#            3       0.56      0.57      0.56       580
#            4       0.57      0.47      0.52       591
#
#     accuracy                           0.46      3118
#    macro avg       0.53      0.47      0.46      3118
# weighted avg       0.54      0.46      0.45      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▄▅▅▆▆▇▇▇▇█▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▂▃▇▇▆▆▅█▇▆█▇▇</td></tr><tr><td>val_loss</td><td>█▇█▅▃▃▄▃▃▂▃▃▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>46.69604</td></tr><tr><td>train_loss</td><td>1.31784</td></tr><tr><td>val_accuracy</td><td>46.06959</td></tr><tr><td>val_loss</td><td>1.32386</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">swept-sweep-2</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/g4c9wu5p' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/g4c9wu5p</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_232816-g4c9wu5p\logs</code>
# wandb: Agent Starting Run: jzmdhggd with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0.1
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 32
# wandb: 	learning_rate: 0.005
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_233853-jzmdhggd</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/jzmdhggd' target="_blank">hearty-sweep-3</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/jzmdhggd' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/jzmdhggd</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0.1, 'epochs': 15, 'hidden_dim': 32, 'learning_rate': 0.005, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0.1, 'epochs': 15, 'hidden_dim': 32, 'learning_rate': 0.005, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 32]          98,336
#            Dropout-2                   [-1, 32]               0
#             Linear-3                    [-1, 5]             165
# ================================================================
# Total params: 98,501
# Trainable params: 98,501
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.38
# Estimated Total Size (MB): 0.39
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5631, Train Acc: 28.84%, Val Loss: 1.5554, Val Acc: 29.25%
# Epoch [2/15], Train Loss: 1.5075, Train Acc: 32.57%, Val Loss: 1.5051, Val Acc: 32.09%
# Epoch [3/15], Train Loss: 1.4845, Train Acc: 33.95%, Val Loss: 1.4517, Val Acc: 34.15%
# Epoch [4/15], Train Loss: 1.4667, Train Acc: 34.51%, Val Loss: 1.4464, Val Acc: 34.60%
# Epoch [5/15], Train Loss: 1.4547, Train Acc: 35.96%, Val Loss: 1.4285, Val Acc: 36.76%
# Epoch [6/15], Train Loss: 1.4433, Train Acc: 37.33%, Val Loss: 1.4085, Val Acc: 37.08%
# Epoch [7/15], Train Loss: 1.4256, Train Acc: 38.38%, Val Loss: 1.4107, Val Acc: 41.20%
# Epoch [8/15], Train Loss: 1.4234, Train Acc: 39.28%, Val Loss: 1.4005, Val Acc: 43.23%
# Epoch [9/15], Train Loss: 1.4149, Train Acc: 39.96%, Val Loss: 1.3834, Val Acc: 41.78%
# Epoch [10/15], Train Loss: 1.4024, Train Acc: 40.86%, Val Loss: 1.3886, Val Acc: 42.78%
# Epoch [11/15], Train Loss: 1.3954, Train Acc: 41.12%, Val Loss: 1.3806, Val Acc: 42.98%
# Epoch [12/15], Train Loss: 1.3913, Train Acc: 42.10%, Val Loss: 1.3571, Val Acc: 44.62%
# Epoch [13/15], Train Loss: 1.3830, Train Acc: 42.07%, Val Loss: 1.3544, Val Acc: 45.33%
# Epoch [14/15], Train Loss: 1.3788, Train Acc: 42.58%, Val Loss: 1.3331, Val Acc: 46.10%
# Epoch [15/15], Train Loss: 1.3748, Train Acc: 42.48%, Val Loss: 1.3538, Val Acc: 45.46%
#               precision    recall  f1-score   support
#
#            0       0.59      0.31      0.41       661
#            1       0.43      0.24      0.31       565
#            2       0.51      0.48      0.49       721
#            3       0.37      0.76      0.50       580
#            4       0.48      0.47      0.48       591
#
#     accuracy                           0.45      3118
#    macro avg       0.48      0.45      0.44      3118
# weighted avg       0.48      0.45      0.44      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▄▄▅▅▆▆▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▃▃▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▃▃▄▄▆▇▆▇▇▇███</td></tr><tr><td>val_loss</td><td>█▆▅▅▄▃▃▃▃▃▂▂▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>42.48348</td></tr><tr><td>train_loss</td><td>1.37483</td></tr><tr><td>val_accuracy</td><td>45.45747</td></tr><tr><td>val_loss</td><td>1.35385</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hearty-sweep-3</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/jzmdhggd' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/jzmdhggd</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_233853-jzmdhggd\logs</code>
# wandb: Agent Starting Run: 6g3drooc with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0.4
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 512
# wandb: 	learning_rate: 0.1
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260120_234947-6g3drooc</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6g3drooc' target="_blank">frosty-sweep-4</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6g3drooc' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6g3drooc</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0.4, 'epochs': 15, 'hidden_dim': 512, 'learning_rate': 0.1, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0.4, 'epochs': 15, 'hidden_dim': 512, 'learning_rate': 0.1, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]       1,573,376
#            Dropout-2                  [-1, 512]               0
#             Linear-3                    [-1, 5]           2,565
# ================================================================
# Total params: 1,575,941
# Trainable params: 1,575,941
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.01
# Params size (MB): 6.01
# Estimated Total Size (MB): 6.03
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.6283, Train Acc: 22.85%, Val Loss: 1.6027, Val Acc: 24.23%
# Epoch [2/15], Train Loss: 1.6033, Train Acc: 24.60%, Val Loss: 1.5984, Val Acc: 25.97%
# Epoch [3/15], Train Loss: 1.5876, Train Acc: 25.21%, Val Loss: 1.5677, Val Acc: 28.22%
# Epoch [4/15], Train Loss: 1.5786, Train Acc: 26.29%, Val Loss: 1.5298, Val Acc: 34.47%
# Epoch [5/15], Train Loss: 1.5734, Train Acc: 26.38%, Val Loss: 1.5689, Val Acc: 29.22%
# Epoch [6/15], Train Loss: 1.5764, Train Acc: 27.53%, Val Loss: 1.5409, Val Acc: 29.48%
# Epoch [7/15], Train Loss: 1.5657, Train Acc: 27.37%, Val Loss: 1.5366, Val Acc: 31.67%
# Epoch [8/15], Train Loss: 1.5581, Train Acc: 27.51%, Val Loss: 1.6066, Val Acc: 33.25%
# Epoch [9/15], Train Loss: 1.5603, Train Acc: 27.57%, Val Loss: 1.5227, Val Acc: 32.99%
# Epoch [10/15], Train Loss: 1.5735, Train Acc: 26.78%, Val Loss: 1.5037, Val Acc: 36.08%
# Epoch [11/15], Train Loss: 1.5607, Train Acc: 27.64%, Val Loss: 1.5271, Val Acc: 30.83%
# Epoch [12/15], Train Loss: 1.5625, Train Acc: 27.73%, Val Loss: 1.5161, Val Acc: 33.18%
# Epoch [13/15], Train Loss: 1.5703, Train Acc: 27.04%, Val Loss: 1.5517, Val Acc: 28.38%
# Epoch [14/15], Train Loss: 1.5704, Train Acc: 27.09%, Val Loss: 1.5399, Val Acc: 29.74%
# Epoch [15/15], Train Loss: 1.5596, Train Acc: 27.63%, Val Loss: 1.5515, Val Acc: 28.83%
#               precision    recall  f1-score   support
#
#            0       0.75      0.21      0.32       661
#            1       0.23      0.21      0.22       565
#            2       0.24      0.02      0.03       721
#            3       0.24      0.92      0.38       580
#            4       0.68      0.16      0.26       591
#
#     accuracy                           0.29      3118
#    macro avg       0.43      0.30      0.24      3118
# weighted avg       0.43      0.29      0.23      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▄▆▆█▇██▇██▇▇█</td></tr><tr><td>train_loss</td><td>█▆▄▃▃▃▂▁▁▃▁▁▂▂▁</td></tr><tr><td>val_accuracy</td><td>▁▂▃▇▄▄▅▆▆█▅▆▃▄▄</td></tr><tr><td>val_loss</td><td>█▇▅▃▅▄▃█▂▁▃▂▄▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>27.62941</td></tr><tr><td>train_loss</td><td>1.55964</td></tr><tr><td>val_accuracy</td><td>28.83376</td></tr><tr><td>val_loss</td><td>1.5515</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">frosty-sweep-4</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6g3drooc' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/6g3drooc</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260120_234947-6g3drooc\logs</code>
# wandb: Agent Starting Run: w7ki2jjn with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0.3
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.01
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260121_000038-w7ki2jjn</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w7ki2jjn' target="_blank">glorious-sweep-5</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w7ki2jjn' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w7ki2jjn</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0.3, 'epochs': 15, 'hidden_dim': 64, 'learning_rate': 0.01, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0.3, 'epochs': 15, 'hidden_dim': 64, 'learning_rate': 0.01, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 64]         196,672
#            Dropout-2                   [-1, 64]               0
#             Linear-3                    [-1, 5]             325
# ================================================================
# Total params: 196,997
# Trainable params: 196,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.75
# Estimated Total Size (MB): 0.76
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5654, Train Acc: 28.28%, Val Loss: 1.4956, Val Acc: 33.34%
# Epoch [2/15], Train Loss: 1.5067, Train Acc: 32.24%, Val Loss: 1.4639, Val Acc: 34.63%
# Epoch [3/15], Train Loss: 1.4796, Train Acc: 34.98%, Val Loss: 1.4358, Val Acc: 38.79%
# Epoch [4/15], Train Loss: 1.4595, Train Acc: 36.30%, Val Loss: 1.4331, Val Acc: 35.66%
# Epoch [5/15], Train Loss: 1.4480, Train Acc: 38.09%, Val Loss: 1.4020, Val Acc: 41.62%
# Epoch [6/15], Train Loss: 1.4358, Train Acc: 38.96%, Val Loss: 1.3956, Val Acc: 42.27%
# Epoch [7/15], Train Loss: 1.4278, Train Acc: 39.83%, Val Loss: 1.4445, Val Acc: 36.82%
# Epoch [8/15], Train Loss: 1.4130, Train Acc: 40.69%, Val Loss: 1.3780, Val Acc: 43.65%
# Epoch [9/15], Train Loss: 1.4062, Train Acc: 41.37%, Val Loss: 1.4053, Val Acc: 41.72%
# Epoch [10/15], Train Loss: 1.4026, Train Acc: 41.77%, Val Loss: 1.3502, Val Acc: 44.52%
# Epoch [11/15], Train Loss: 1.3954, Train Acc: 42.00%, Val Loss: 1.3524, Val Acc: 46.23%
# Epoch [12/15], Train Loss: 1.3868, Train Acc: 42.22%, Val Loss: 1.3660, Val Acc: 42.72%
# Epoch [13/15], Train Loss: 1.3810, Train Acc: 42.79%, Val Loss: 1.3411, Val Acc: 48.84%
# Epoch [14/15], Train Loss: 1.3778, Train Acc: 43.17%, Val Loss: 1.3278, Val Acc: 46.30%
# Epoch [15/15], Train Loss: 1.3740, Train Acc: 42.57%, Val Loss: 1.3133, Val Acc: 48.45%
#               precision    recall  f1-score   support
#
#            0       0.63      0.30      0.41       661
#            1       0.40      0.53      0.46       565
#            2       0.59      0.41      0.48       721
#            3       0.43      0.72      0.53       580
#            4       0.51      0.49      0.50       591
#
#     accuracy                           0.48      3118
#    macro avg       0.51      0.49      0.48      3118
# weighted avg       0.52      0.48      0.48      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▄▅▆▆▆▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▂▃▂▅▅▃▆▅▆▇▅█▇█</td></tr><tr><td>val_loss</td><td>█▇▆▆▄▄▆▃▅▂▃▃▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>42.56608</td></tr><tr><td>train_loss</td><td>1.37396</td></tr><tr><td>val_accuracy</td><td>48.45361</td></tr><tr><td>val_loss</td><td>1.31331</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glorious-sweep-5</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w7ki2jjn' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/w7ki2jjn</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260121_000038-w7ki2jjn\logs</code>
# wandb: Agent Starting Run: e73dd4e8 with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 32
# wandb: 	learning_rate: 0.1
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260121_001214-e73dd4e8</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/e73dd4e8' target="_blank">still-sweep-6</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/e73dd4e8' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/e73dd4e8</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0, 'epochs': 15, 'hidden_dim': 32, 'learning_rate': 0.1, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0, 'epochs': 15, 'hidden_dim': 32, 'learning_rate': 0.1, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 32]          98,336
#            Dropout-2                   [-1, 32]               0
#             Linear-3                    [-1, 5]             165
# ================================================================
# Total params: 98,501
# Trainable params: 98,501
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.38
# Estimated Total Size (MB): 0.39
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.6225, Train Acc: 20.87%, Val Loss: 1.6154, Val Acc: 23.26%
# Epoch [2/15], Train Loss: 1.6036, Train Acc: 22.55%, Val Loss: 1.6075, Val Acc: 24.52%
# Epoch [3/15], Train Loss: 1.5880, Train Acc: 24.45%, Val Loss: 1.5752, Val Acc: 24.32%
# Epoch [4/15], Train Loss: 1.5895, Train Acc: 24.23%, Val Loss: 1.5805, Val Acc: 27.58%
# Epoch [5/15], Train Loss: 1.5815, Train Acc: 24.11%, Val Loss: 1.5678, Val Acc: 24.45%
# Epoch [6/15], Train Loss: 1.5806, Train Acc: 24.38%, Val Loss: 1.5673, Val Acc: 27.90%
# Epoch [7/15], Train Loss: 1.5779, Train Acc: 25.07%, Val Loss: 1.5715, Val Acc: 23.74%
# Epoch [8/15], Train Loss: 1.5790, Train Acc: 24.82%, Val Loss: 1.5820, Val Acc: 26.32%
# Epoch [9/15], Train Loss: 1.5773, Train Acc: 24.88%, Val Loss: 1.5636, Val Acc: 24.94%
# Epoch [10/15], Train Loss: 1.5933, Train Acc: 24.02%, Val Loss: 1.5773, Val Acc: 26.87%
# Epoch [11/15], Train Loss: 1.5744, Train Acc: 24.86%, Val Loss: 1.5645, Val Acc: 27.93%
# Epoch [12/15], Train Loss: 1.5775, Train Acc: 24.52%, Val Loss: 1.5720, Val Acc: 27.13%
# Epoch [13/15], Train Loss: 1.5747, Train Acc: 24.34%, Val Loss: 1.5745, Val Acc: 27.87%
# Epoch [14/15], Train Loss: 1.5722, Train Acc: 24.77%, Val Loss: 1.5659, Val Acc: 25.23%
# Epoch [15/15], Train Loss: 1.5742, Train Acc: 24.89%, Val Loss: 1.5731, Val Acc: 26.87%
#               precision    recall  f1-score   support
#
#            0       0.73      0.21      0.33       661
#            1       0.00      0.00      0.00       565
#            2       0.24      0.96      0.38       721
#            3       0.00      0.00      0.00       580
#            4       0.00      0.00      0.00       591
#
#     accuracy                           0.27      3118
#    macro avg       0.19      0.23      0.14      3118
# weighted avg       0.21      0.27      0.16      3118
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Windows 11 Pro\anaconda3\envs\torch-gpu\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▄▇▇▆▇███▆█▇▇▇█</td></tr><tr><td>train_loss</td><td>█▅▃▃▂▂▂▂▂▄▁▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▃▇▃█▂▆▄▆█▇█▄▆</td></tr><tr><td>val_loss</td><td>█▇▃▃▂▁▂▃▁▃▁▂▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>24.88987</td></tr><tr><td>train_loss</td><td>1.57418</td></tr><tr><td>val_accuracy</td><td>26.86856</td></tr><tr><td>val_loss</td><td>1.57307</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">still-sweep-6</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/e73dd4e8' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/e73dd4e8</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260121_001214-e73dd4e8\logs</code>
# wandb: Agent Starting Run: 11l7bc96 with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0.2
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 128
# wandb: 	learning_rate: 0.1
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260121_002357-11l7bc96</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/11l7bc96' target="_blank">logical-sweep-7</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/11l7bc96' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/11l7bc96</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0.2, 'epochs': 15, 'hidden_dim': 128, 'learning_rate': 0.1, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0.2, 'epochs': 15, 'hidden_dim': 128, 'learning_rate': 0.1, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 128]         393,344
#            Dropout-2                  [-1, 128]               0
#             Linear-3                    [-1, 5]             645
# ================================================================
# Total params: 393,989
# Trainable params: 393,989
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 1.50
# Estimated Total Size (MB): 1.52
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.6156, Train Acc: 22.81%, Val Loss: 1.5859, Val Acc: 23.97%
# Epoch [2/15], Train Loss: 1.5838, Train Acc: 26.02%, Val Loss: 1.5875, Val Acc: 26.58%
# Epoch [3/15], Train Loss: 1.5611, Train Acc: 28.14%, Val Loss: 1.5436, Val Acc: 32.28%
# Epoch [4/15], Train Loss: 1.5591, Train Acc: 28.12%, Val Loss: 1.5378, Val Acc: 31.67%
# Epoch [5/15], Train Loss: 1.5450, Train Acc: 30.00%, Val Loss: 1.5172, Val Acc: 30.99%
# Epoch [6/15], Train Loss: 1.5467, Train Acc: 29.60%, Val Loss: 1.4819, Val Acc: 36.76%
# Epoch [7/15], Train Loss: 1.5400, Train Acc: 31.37%, Val Loss: 1.5205, Val Acc: 31.60%
# Epoch [8/15], Train Loss: 1.5343, Train Acc: 31.73%, Val Loss: 1.7299, Val Acc: 31.48%
# Epoch [9/15], Train Loss: 1.5473, Train Acc: 29.85%, Val Loss: 1.5625, Val Acc: 26.45%
# Epoch [10/15], Train Loss: 1.5284, Train Acc: 31.84%, Val Loss: 1.5145, Val Acc: 31.77%
# Epoch [11/15], Train Loss: 1.5422, Train Acc: 30.71%, Val Loss: 1.5205, Val Acc: 32.86%
# Epoch [12/15], Train Loss: 1.5378, Train Acc: 30.75%, Val Loss: 1.5017, Val Acc: 35.60%
# Epoch [13/15], Train Loss: 1.5319, Train Acc: 30.73%, Val Loss: 1.5624, Val Acc: 35.73%
# Epoch [14/15], Train Loss: 1.5367, Train Acc: 30.58%, Val Loss: 1.5139, Val Acc: 30.61%
# Epoch [15/15], Train Loss: 1.5331, Train Acc: 30.71%, Val Loss: 1.4731, Val Acc: 36.18%
#               precision    recall  f1-score   support
#
#            0       0.67      0.25      0.37       661
#            1       0.23      0.03      0.06       565
#            2       0.49      0.28      0.36       721
#            3       0.26      0.90      0.41       580
#            4       0.56      0.36      0.44       591
#
#     accuracy                           0.36      3118
#    macro avg       0.44      0.37      0.32      3118
# weighted avg       0.45      0.36      0.33      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▅▅▇▆██▆█▇▇▇▇▇</td></tr><tr><td>train_loss</td><td>█▅▄▃▂▂▂▁▃▁▂▂▁▂▁</td></tr><tr><td>val_accuracy</td><td>▁▂▆▅▅█▅▅▂▅▆▇▇▅█</td></tr><tr><td>val_loss</td><td>▄▄▃▃▂▁▂█▃▂▂▂▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>30.71311</td></tr><tr><td>train_loss</td><td>1.53314</td></tr><tr><td>val_accuracy</td><td>36.17912</td></tr><tr><td>val_loss</td><td>1.47306</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">logical-sweep-7</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/11l7bc96' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/11l7bc96</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260121_002357-11l7bc96\logs</code>
# wandb: Agent Starting Run: ighns1de with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0.3
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 512
# wandb: 	learning_rate: 0.01
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260121_003453-ighns1de</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ighns1de' target="_blank">eager-sweep-8</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ighns1de' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ighns1de</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0.3, 'epochs': 15, 'hidden_dim': 512, 'learning_rate': 0.01, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0.3, 'epochs': 15, 'hidden_dim': 512, 'learning_rate': 0.01, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]       1,573,376
#            Dropout-2                  [-1, 512]               0
#             Linear-3                    [-1, 5]           2,565
# ================================================================
# Total params: 1,575,941
# Trainable params: 1,575,941
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.01
# Params size (MB): 6.01
# Estimated Total Size (MB): 6.03
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5494, Train Acc: 29.68%, Val Loss: 1.5363, Val Acc: 32.06%
# Epoch [2/15], Train Loss: 1.4964, Train Acc: 33.01%, Val Loss: 1.4542, Val Acc: 37.66%
# Epoch [3/15], Train Loss: 1.4607, Train Acc: 36.61%, Val Loss: 1.4546, Val Acc: 36.63%
# Epoch [4/15], Train Loss: 1.4341, Train Acc: 38.46%, Val Loss: 1.4519, Val Acc: 38.43%
# Epoch [5/15], Train Loss: 1.4183, Train Acc: 40.17%, Val Loss: 1.3889, Val Acc: 43.33%
# Epoch [6/15], Train Loss: 1.4025, Train Acc: 41.26%, Val Loss: 1.3650, Val Acc: 44.36%
# Epoch [7/15], Train Loss: 1.3929, Train Acc: 41.69%, Val Loss: 1.3658, Val Acc: 44.30%
# Epoch [8/15], Train Loss: 1.3809, Train Acc: 42.17%, Val Loss: 1.3485, Val Acc: 47.74%
# Epoch [9/15], Train Loss: 1.3756, Train Acc: 42.68%, Val Loss: 1.3321, Val Acc: 49.32%
# Epoch [10/15], Train Loss: 1.3651, Train Acc: 43.68%, Val Loss: 1.3587, Val Acc: 44.14%
# Epoch [11/15], Train Loss: 1.3607, Train Acc: 44.00%, Val Loss: 1.3266, Val Acc: 46.49%
# Epoch [12/15], Train Loss: 1.3530, Train Acc: 44.40%, Val Loss: 1.3287, Val Acc: 44.78%
# Epoch [13/15], Train Loss: 1.3488, Train Acc: 44.30%, Val Loss: 1.3384, Val Acc: 43.91%
# Epoch [14/15], Train Loss: 1.3466, Train Acc: 45.53%, Val Loss: 1.3290, Val Acc: 44.30%
# Epoch [15/15], Train Loss: 1.3408, Train Acc: 44.66%, Val Loss: 1.3519, Val Acc: 43.36%
#               precision    recall  f1-score   support
#
#            0       0.71      0.28      0.40       661
#            1       0.38      0.38      0.38       565
#            2       0.43      0.44      0.44       721
#            3       0.56      0.40      0.47       580
#            4       0.35      0.67      0.46       591
#
#     accuracy                           0.43      3118
#    macro avg       0.48      0.43      0.43      3118
# weighted avg       0.49      0.43      0.43      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▄▅▆▆▆▇▇▇▇█▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▂▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▃▄▆▆▆▇█▆▇▆▆▆▆</td></tr><tr><td>val_loss</td><td>█▅▅▅▃▂▂▂▁▂▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>44.65859</td></tr><tr><td>train_loss</td><td>1.34084</td></tr><tr><td>val_accuracy</td><td>43.3634</td></tr><tr><td>val_loss</td><td>1.35186</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-sweep-8</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ighns1de' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/ighns1de</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260121_003453-ighns1de\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: vih3c7k6 with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0.1
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.01
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260121_004539-vih3c7k6</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/vih3c7k6' target="_blank">vivid-sweep-9</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/vih3c7k6' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/vih3c7k6</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0.1, 'epochs': 15, 'hidden_dim': 64, 'learning_rate': 0.01, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0.1, 'epochs': 15, 'hidden_dim': 64, 'learning_rate': 0.01, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 64]         196,672
#            Dropout-2                   [-1, 64]               0
#             Linear-3                    [-1, 5]             325
# ================================================================
# Total params: 196,997
# Trainable params: 196,997
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.75
# Estimated Total Size (MB): 0.76
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5568, Train Acc: 28.95%, Val Loss: 1.5688, Val Acc: 30.12%
# Epoch [2/15], Train Loss: 1.4979, Train Acc: 33.01%, Val Loss: 1.4543, Val Acc: 39.27%
# Epoch [3/15], Train Loss: 1.4642, Train Acc: 36.19%, Val Loss: 1.4362, Val Acc: 39.40%
# Epoch [4/15], Train Loss: 1.4396, Train Acc: 38.48%, Val Loss: 1.4165, Val Acc: 39.40%
# Epoch [5/15], Train Loss: 1.4196, Train Acc: 40.45%, Val Loss: 1.4188, Val Acc: 40.56%
# Epoch [6/15], Train Loss: 1.4036, Train Acc: 40.85%, Val Loss: 1.3637, Val Acc: 45.07%
# Epoch [7/15], Train Loss: 1.3927, Train Acc: 41.92%, Val Loss: 1.3567, Val Acc: 46.55%
# Epoch [8/15], Train Loss: 1.3827, Train Acc: 43.10%, Val Loss: 1.3791, Val Acc: 41.82%
# Epoch [9/15], Train Loss: 1.3766, Train Acc: 42.68%, Val Loss: 1.4132, Val Acc: 39.76%
# Epoch [10/15], Train Loss: 1.3692, Train Acc: 43.71%, Val Loss: 1.3487, Val Acc: 45.81%
# Epoch [11/15], Train Loss: 1.3606, Train Acc: 44.01%, Val Loss: 1.3905, Val Acc: 38.89%
# Epoch [12/15], Train Loss: 1.3600, Train Acc: 43.72%, Val Loss: 1.3505, Val Acc: 43.46%
# Epoch [13/15], Train Loss: 1.3545, Train Acc: 44.75%, Val Loss: 1.3113, Val Acc: 47.74%
# Epoch [14/15], Train Loss: 1.3446, Train Acc: 45.25%, Val Loss: 1.3161, Val Acc: 46.71%
# Epoch [15/15], Train Loss: 1.3402, Train Acc: 45.29%, Val Loss: 1.3337, Val Acc: 46.30%
#               precision    recall  f1-score   support
#
#            0       0.51      0.41      0.46       661
#            1       0.44      0.21      0.28       565
#            2       0.63      0.40      0.48       721
#            3       0.40      0.70      0.51       580
#            4       0.42      0.60      0.49       591
#
#     accuracy                           0.46      3118
#    macro avg       0.48      0.46      0.45      3118
# weighted avg       0.49      0.46      0.45      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▃▄▅▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▂▂▂▂▂▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▅▅▅▇█▆▅▇▄▆██▇</td></tr><tr><td>val_loss</td><td>█▅▄▄▄▂▂▃▄▂▃▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>45.29185</td></tr><tr><td>train_loss</td><td>1.34021</td></tr><tr><td>val_accuracy</td><td>46.2951</td></tr><tr><td>val_loss</td><td>1.33368</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vivid-sweep-9</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/vih3c7k6' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/vih3c7k6</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260121_004539-vih3c7k6\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 9gbm2tcc with config:
# wandb: 	batch_size: 16
# wandb: 	dropout: 0
# wandb: 	epochs: 15
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.01
# wandb: 	model_type: MLP
# Ignoring project 'Müll Klassifikation' when running a sweep.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>c:\Users\Windows 11 Pro\OneDrive\6. Semester\Ausgewählte Anwendungen der KI\slt-ai\wandb\run-20260121_005617-9gbm2tcc</code>
# Syncing run <strong><a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/9gbm2tcc' target="_blank">magic-sweep-10</a></strong> to <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View project at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a>
#  View sweep at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/sweeps/gdpvhlxh</a>
#  View run at <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/9gbm2tcc' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/9gbm2tcc</a>
# Running model pipeline: MLP, with config: {'batch_size': 16, 'dropout': 0, 'epochs': 15, 'hidden_dim': 256, 'learning_rate': 0.01, 'model_type': 'MLP'}
# {'batch_size': 16, 'dropout': 0, 'epochs': 15, 'hidden_dim': 256, 'learning_rate': 0.01, 'model_type': 'MLP'}
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 256]         786,688
#            Dropout-2                  [-1, 256]               0
#             Linear-3                    [-1, 5]           1,285
# ================================================================
# Total params: 787,973
# Trainable params: 787,973
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 3.01
# Estimated Total Size (MB): 3.02
# ----------------------------------------------------------------
# Start training for MLP with 15 epochs...
# Epoch [1/15], Train Loss: 1.5484, Train Acc: 29.90%, Val Loss: 1.6208, Val Acc: 26.93%
# Epoch [2/15], Train Loss: 1.4891, Train Acc: 33.19%, Val Loss: 1.4768, Val Acc: 35.02%
# Epoch [3/15], Train Loss: 1.4562, Train Acc: 36.52%, Val Loss: 1.4156, Val Acc: 41.27%
# Epoch [4/15], Train Loss: 1.4273, Train Acc: 39.54%, Val Loss: 1.4399, Val Acc: 36.76%
# Epoch [5/15], Train Loss: 1.4064, Train Acc: 40.51%, Val Loss: 1.3636, Val Acc: 42.53%
# Epoch [6/15], Train Loss: 1.3913, Train Acc: 41.42%, Val Loss: 1.3703, Val Acc: 43.72%
# Epoch [7/15], Train Loss: 1.3746, Train Acc: 43.09%, Val Loss: 1.3738, Val Acc: 40.59%
# Epoch [8/15], Train Loss: 1.3682, Train Acc: 42.95%, Val Loss: 1.3438, Val Acc: 46.39%
# Epoch [9/15], Train Loss: 1.3551, Train Acc: 44.11%, Val Loss: 1.3314, Val Acc: 47.42%
# Epoch [10/15], Train Loss: 1.3445, Train Acc: 44.99%, Val Loss: 1.3165, Val Acc: 49.61%
# Epoch [11/15], Train Loss: 1.3418, Train Acc: 44.53%, Val Loss: 1.2934, Val Acc: 49.97%
# Epoch [12/15], Train Loss: 1.3315, Train Acc: 45.02%, Val Loss: 1.3586, Val Acc: 44.72%
# Epoch [13/15], Train Loss: 1.3274, Train Acc: 45.62%, Val Loss: 1.3419, Val Acc: 42.82%
# Epoch [14/15], Train Loss: 1.3247, Train Acc: 46.41%, Val Loss: 1.3613, Val Acc: 43.52%
# Epoch [15/15], Train Loss: 1.3186, Train Acc: 46.20%, Val Loss: 1.2958, Val Acc: 47.26%
#               precision    recall  f1-score   support
#
#            0       0.45      0.43      0.44       661
#            1       0.47      0.33      0.39       565
#            2       0.38      0.67      0.49       721
#            3       0.64      0.45      0.52       580
#            4       0.60      0.43      0.50       591
#
#     accuracy                           0.47      3118
#    macro avg       0.51      0.46      0.47      3118
# weighted avg       0.50      0.47      0.47      3118
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>▁▂▄▅▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▂▂▂▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▅▄▆▆▅▇▇██▆▆▆▇</td></tr><tr><td>val_loss</td><td>█▅▄▄▃▃▃▂▂▁▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_accuracy</td><td>46.20044</td></tr><tr><td>train_loss</td><td>1.31864</td></tr><tr><td>val_accuracy</td><td>47.2616</td></tr><tr><td>val_loss</td><td>1.29578</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">magic-sweep-10</strong> at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/9gbm2tcc' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation/runs/9gbm2tcc</a><br> View project at: <a href='https://wandb.ai/sltai/M%C3%BCll%20Klassifikation' target="_blank">https://wandb.ai/sltai/M%C3%BCll%20Klassifikation</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260121_005617-9gbm2tcc\logs</code>

# %%
wandb.teardown()

# %% [markdown]
# ### Quellen <a id="quellen"></a>
#
# [1] ALBA und Civey, "Gut gemeint: Große Mehrheit trennt den Müll und schadet dennoch dem Klima", Pressemitteilung, 20.07.2022. (Online). Verfügbar: https://www.alba.info/unternehmen/newsroom/pressemitteilungen/detail/gut-gemeint-grosse-mehrheit-trennt-den-muell-und-schadet-dennoch-dem-klima/. (Zugriff: 10.01.2026).
#
# [2] L. Löwe, "Alles durcheinander: Die Unlust beim Mülltrennen", FR.de, 10.01.2019. (Online). Verfügbar: https://www.fr.de/ratgeber/wohnen/alles-durcheinander-unlust-beim-muelltrennen-11106084.html. (Zugriff: 15.01.2026).
